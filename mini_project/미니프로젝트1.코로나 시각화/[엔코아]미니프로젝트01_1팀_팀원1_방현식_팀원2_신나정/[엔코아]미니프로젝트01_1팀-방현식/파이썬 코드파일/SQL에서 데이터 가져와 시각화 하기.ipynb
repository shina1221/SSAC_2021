# %%
import pandas as pd
import pymysql

data = pd.read_excel("./코로나 지역별 누적인구.xlsx")

# %%
#SQL데이터 불러오기 ,튜플 -> 리스트 변환
# 지역 and 누적 확진자수
conn = pymysql.connect(host = '127.0.0.1', user = 'root' , password = 'root', db = 'coronadb')
cur = conn.cursor()
cur.execute("SELECT * FROM corona19;")
fetchall = cur.fetchall()

local = []
for i in fetchall:
    local.append(i)
local
# Out:
# [('검역자세히', '5,738'),
#  ('제주', '2,494'),
#  ('서울', '76,245'),
#  ('인천', '11,305'),
#  ('광주', '3,920'),
#  ('광주', '3,920'),
#  ('경북', '6,802'),
#  ('부산', '10,999'),
#  ('대구', '13,192'),
#  ('강원', '5,242'),
#  ('경기', '68,158'),
#  ('전남', '2,479'),
#  ('충북', '4,953'),
#  ('충남', '6,547'),
#  ('충남', '6,547'),
#  ('대전', '5,413'),
#  ('세종', '944'),
#  ('전북', '3,396'),
#  ('경남', '9,615'),
#  ('울산', '3,997')]

# %%
#데이터 프레임 만들기
col_name = ['지역', '누적_인구']
localdp = pd.DataFrame(local, columns=col_name)

# %%
#데이터 확인 중복이 있다.
localdp
# Out:
#        지역   누적_인구
# 0   검역자세히   5,738
# 1      제주   2,494
# 2      서울  76,245
# 3      인천  11,305
# 4      광주   3,920
# 5      광주   3,920
# 6      경북   6,802
# 7      부산  10,999
# 8      대구  13,192
# 9      강원   5,242
# 10     경기  68,158
# 11     전남   2,479
# 12     충북   4,953
# 13     충남   6,547
# 14     충남   6,547
# 15     대전   5,413
# 16     세종     944
# 17     전북   3,396
# 18     경남   9,615
# 19     울산   3,997

# %%
#중복 행 없애주기
localdp=localdp.drop([0],axis = 0)
localdp=localdp.drop([4],axis = 0)
localdp=localdp.drop([14],axis = 0)
#인덱스 다시 잡아주기
localdp=localdp.set_index('지역')
localdp=localdp.reset_index(drop = False)

localdp

# %%
# 없어진 열 확인
n=len(localdp)
print(f'인덱스 총 개수는 {n}개 입니다')
# Out:
#     지역   누적_인구
# 0   제주   2,494
# 1   서울  76,245
# 2   인천  11,305
# 3   광주   3,920
# 4   경북   6,802
# 5   부산  10,999
# 6   대구  13,192
# 7   강원   5,242
# 8   경기  68,158
# 9   전남   2,479
# 10  충북   4,953
# 11  충남   6,547
# 12  대전   5,413
# 13  세종     944
# 14  전북   3,396
# 15  경남   9,615
# 16  울산   3,997
#
# 인덱스 총 개수는 17개 입니다

# %%
places = []
for i in localdp['지역']:
    places.append(i)
print(places)
# Out:
# ['제주', '서울', '인천', '광주', '경북', '부산', '대구', '강원', '경기', '전남', '충북', '충남', '대전', '세종', '전북', '경남', '울산']

# %%
# googlemaps를 사용하기위한 라이브러리 다운
# !pip install -U googlemaps

# %%
import googlemaps
import pandas as pd

my_key = "AIzaSyCwsP9RBvIKTMKdLOilSob3R_4dhaJO6iQ"
maps = googlemaps.Client(key=my_key)  # my key값 입력
lat = []  #위도
lng = []  #경도

# 위치를 찾을 장소나 주소를 넣어준다.
places = ['제주시', '서울특별시', '인천광역시', '광주광역시', '경상북도', '부산광역시', '대구', '강원', '경기도', '전라남도',\
          '충정북도', '충정남도', '대전광역시', '세종특별자치시청', '전라북도', '경상남도', '울산광역시']

i=0
for place in places:   
    i = i + 1
    try:
        print("%d번 인덱스에서 %s의 위치를 찾고있습니다"%(i, place))
        geo_location = maps.geocode(place)[0].get('geometry')
        lat.append(geo_location['location']['lat'])
        lng.append(geo_location['location']['lng'])
        

    except:
        lat.append('')
        lng.append('')
        print("%d번 인덱스 위치를 찾는데 실패했습니다."%(i))


# 데이터프레임만들어 출력하기
df = pd.DataFrame({'위도':lat, '경도':lng}, index=places)
print(df)
# Out:
# 1번 인덱스에서 제주시의 위치를 찾고있습니다
# 2번 인덱스에서 서울특별시의 위치를 찾고있습니다
# 3번 인덱스에서 인천광역시의 위치를 찾고있습니다
# 4번 인덱스에서 광주광역시의 위치를 찾고있습니다
# 5번 인덱스에서 경상북도의 위치를 찾고있습니다
# 6번 인덱스에서 부산광역시의 위치를 찾고있습니다
# 7번 인덱스에서 대구의 위치를 찾고있습니다
# 8번 인덱스에서 강원의 위치를 찾고있습니다
# 9번 인덱스에서 경기도의 위치를 찾고있습니다
# 10번 인덱스에서 전라남도의 위치를 찾고있습니다
# 11번 인덱스에서 충정북도의 위치를 찾고있습니다
# 12번 인덱스에서 충정남도의 위치를 찾고있습니다
# 13번 인덱스에서 대전광역시의 위치를 찾고있습니다
# 14번 인덱스에서 세종특별자치시청의 위치를 찾고있습니다
# 15번 인덱스에서 전라북도의 위치를 찾고있습니다
# 16번 인덱스에서 경상남도의 위치를 찾고있습니다
# 17번 인덱스에서 울산광역시의 위치를 찾고있습니다
#                  위도          경도
# 제주시       33.499621  126.531188
# 서울특별시     37.566535  126.977969
# 인천광역시     37.456256  126.705206
# 광주광역시     35.159545  126.852601
# 경상북도      36.491900  128.888900
# 부산광역시     35.179554  129.075642
# 대구        35.871435  128.601445
# 강원        37.822800  128.155500
# 경기도       37.413800  127.518300
# 전라남도      34.867900  126.991000
# 충정북도      36.800000  127.700000
# 충정남도      36.518400  126.800000
# 대전광역시     36.350412  127.384547
# 세종특별자치시청  36.480132  127.288765
# ...

# %%
location_df=df
location_df.head()
# Out:
#               위도          경도
# 제주시    33.499621  126.531188
# 서울특별시  37.566535  126.977969
# 인천광역시  37.456256  126.705206
# 광주광역시  35.159545  126.852601
# 경상북도   36.491900  128.888900

# %%
#이름 바꾸기
name = ['제주시', '서울특별시', '인천광역시', '광주광역시', '경상북도', '부산광역시', '대구', '강원', '경기도', '전라남도','충정북도', '충정남도', '대전광역시', '세종특별자치시청', '전라북도', '경상남도', '울산광역시']

localdp['지역']=name

# %%
#데이터 프레임 합치기
location_data = pd.merge( localdp,location_df, how = 'right', left_on = '지역',right_index = True)

location_data
# Out:
#           지역   누적_인구         위도          경도
# 0        제주시   2,494  33.499621  126.531188
# 1      서울특별시  76,245  37.566535  126.977969
# 2      인천광역시  11,305  37.456256  126.705206
# 3      광주광역시   3,920  35.159545  126.852601
# 4       경상북도   6,802  36.491900  128.888900
# 5      부산광역시  10,999  35.179554  129.075642
# 6         대구  13,192  35.871435  128.601445
# 7         강원   5,242  37.822800  128.155500
# 8        경기도  68,158  37.413800  127.518300
# 9       전라남도   2,479  34.867900  126.991000
# 10      충정북도   4,953  36.800000  127.700000
# 11      충정남도   6,547  36.518400  126.800000
# 12     대전광역시   5,413  36.350412  127.384547
# 13  세종특별자치시청     944  36.480132  127.288765
# 14      전라북도   3,396  35.717500  127.153000
# 15      경상남도   9,615  35.460600  128.213200
# 16     울산광역시   3,997  35.538377  129.311360

# %%
# location_data.to_excel('../미니프로젝트/지역_인구_위도_경도.xlsx',index=False)

# %%
location_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17 entries, 0 to 16
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      17 non-null     object
#  1   누적_인구   17 non-null     object
#  2   위도      17 non-null     float64
#  3   경도      17 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 680.0+ bytes

# %%
#누적_인구 타입변환 object => int 
for i in localdp['누적_인구']:
    a=i.replace(',','')
    print(a,end = ',')
# Out:
# 2494,76245,11305,3920,6802,10999,13192,5242,68158,2479,4953,6547,5413,944,3396,9615,3997,

# %%
# 컬럼 값 바꾸기
int_v = [2494,76245,11305,3920,6802,10999,13192,5242,68158,2479,4953,6547,5413,944,3396,9615,3997]
localdp['누적_인구'] = int_v

# %%
# 바뀌것 확인하기
localdp
# Out:
#           지역  누적_인구
# 0        제주시   2494
# 1      서울특별시  76245
# 2      인천광역시  11305
# 3      광주광역시   3920
# 4       경상북도   6802
# 5      부산광역시  10999
# 6         대구  13192
# 7         강원   5242
# 8        경기도  68158
# 9       전라남도   2479
# 10      충정북도   4953
# 11      충정남도   6547
# 12     대전광역시   5413
# 13  세종특별자치시청    944
# 14      전라북도   3396
# 15      경상남도   9615
# 16     울산광역시   3997

# %%
# 데이터 프레임 합쳐주기
location_data = pd.merge( localdp,location_df, how = 'right', left_on = '지역',right_index = True)
location_data
# Out:
#           지역  누적_인구         위도          경도
# 0        제주시   2494  33.499621  126.531188
# 1      서울특별시  76245  37.566535  126.977969
# 2      인천광역시  11305  37.456256  126.705206
# 3      광주광역시   3920  35.159545  126.852601
# 4       경상북도   6802  36.491900  128.888900
# 5      부산광역시  10999  35.179554  129.075642
# 6         대구  13192  35.871435  128.601445
# 7         강원   5242  37.822800  128.155500
# 8        경기도  68158  37.413800  127.518300
# 9       전라남도   2479  34.867900  126.991000
# 10      충정북도   4953  36.800000  127.700000
# 11      충정남도   6547  36.518400  126.800000
# 12     대전광역시   5413  36.350412  127.384547
# 13  세종특별자치시청    944  36.480132  127.288765
# 14      전라북도   3396  35.717500  127.153000
# 15      경상남도   9615  35.460600  128.213200
# 16     울산광역시   3997  35.538377  129.311360

# %%
# 지도 라이브러리

#!pip install folium

# %%
#지도 표시해보기
import folium

대한민국_가운데 = [36.523522, 127.732926]
대한민국 = folium.Map(location = 대한민국_가운데, zoom_start = 6)

for i in range(len(location_data)):
    name = location_data ['지역'][i]         # 지역 위치
    count = location_data ['누적_인구'][i]   # 인구수
    size = int(count)**0.38
    long = float(location_data['위도'][i])      
    lat = float(location_data['경도'][i])       
    folium.CircleMarker([long,lat], radius = size, color='brown', fill = True,fill_color = 'coral',fill_opacity = 0.2, popup=name).add_to(대한민국)
    
대한민국
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# 결론: 데이터를 통해 코로나 누적 확진자 수를 한번에 알 수 있게 되었고 이를 통해 
#       우리는 서울과 경기 지역에서 특히 마스크를 잘 쓰며 조심히 다녀야 합니다.
