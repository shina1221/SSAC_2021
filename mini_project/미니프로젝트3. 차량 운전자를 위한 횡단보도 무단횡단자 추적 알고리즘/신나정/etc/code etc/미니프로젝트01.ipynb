# %%
"""
주제+1: 횡단보도가 아닌 곳에서 무단횡단하는 사람 검출
         https://www.youtube.com/watch?v=OiPm7g4v5kk
         
주제+2: 블랙박스 기준으로 본인차량 빨간불일때 움직이는지 검출
"""

# %%
#미니프로젝트 
"""
주제 횡단보도에 빨간불일때 사람이나 객체가 있는지 없는지 검출
     사람 최우선
     그 이후 시간이 되면 그외 객체(개)
     
#반대로 생각해서 블랙박스 앞의 신호등이 초록불일 때 횡단보도에서 움직이는 사람 검출
 개까지 포함해야 하나 
 

데이터 : https://www.youtube.com/watch?v=kev0t8OGW0w 초록불에 사람 걷는것
         https://www.youtube.com/watch?v=GPqO7dI94aI 초록불에 사람 걷는것, 빨간불에 멈춘것
         https://www.youtube.com/watch?v=YEH2Ie8b6gQ 차량신호등 초록불에 사람 걷는것
         강사님한테 횡단보도 데이터 문의 고정된 횡단보도 데이터 문의

#차량신호등 우선 기준 이후 추가적으로 보행신호등으로 정확도를 높이는 방향으로 


우리가 필요한 조건을 설정해서 촬영
- 횡단보도만 보이는 영상으로 본인이 촬영

블랙박스 기준이 아닌 횡단보도 영상 찾기가 생각보다 데이터 찾기가 힘듬
"""

"""
신호등 색

의문) 다차로에 있는 다른 신호등은 어떻게 구분하는가

횡단보도 구분
횡단보도 신호등 구분
차량 신호등 구분

사람 구분

#횡단보도 신호등이 빨간불일 때 구분 or조건
#차량 신호등이 초록불일 때 구분


#신호등이 
#횡단보도 신호등이 초록불일 때 구분 or조건
#차량 신호등이 초록불일 때 구분


"""

#영상읽기
cv2.Videocapture()로 영상읽기

#343-344p 신호등 구분
https://www.koreascience.or.kr/article/JAKO201810866006695.pdf

디스크립터 기준 사람 찾기
-match함수로부터 좋은 매칭점 찾기


-걷는사람 인식은 쉬운데 hog 


#146p HSV색상으로 마스킹
-cv2.bitwise 연산으로

#모션감지 ccTV코드 응용

# %%
#미니프로젝트 
"""
주제 횡단보도에 빨간불일때 사람이나 객체가 있는지 없는지 검출
     사람 최우선
     그 이후 시간이 되면 그외 객체(개)
     
#반대로 생각해서 블랙박스 앞의 신호등이 초록불일 때 횡단보도에서 움직이는 사람 검출
 개까지 포함해야 하나 
 
데이터 : https://www.youtube.com/watch?v=kev0t8OGW0w 초록불에 사람 걷는것
         https://www.youtube.com/watch?v=GPqO7dI94aI 초록불에 사람 걷는것, 빨간불에 멈춘것
         https://www.youtube.com/watch?v=YEH2Ie8b6gQ 차량신호등 초록불에 사람 걷는것
         강사님한테 횡단보도 데이터 문의 고정된 횡단보도 데이터 문의
         ROI기준으로 검출해볼 것
         데이터셋 제공 사이트 알고 있는지 

#차량신호등 우선 기준 이후 추가적으로 보행신호등으로 정확도를 높이는 방향으로 

옵션)
우리가 필요한 조건을 설정해서 촬영
- 횡단보도만 보이는 영상으로 본인이 촬영
"""

"""
횡단보도 검출
351p 카메라로 객체매칭하는 것만 검출
#how

410 hog 알고리즘으로 사람검출 

272 허프원변환 동전 동그라미 검출로 신호등 
동그라미는 동전카운팅 할때 

146 HSV색상으로 마스킹
-cv2.bitwise 연산으로 빨간불인지 초록불인지 검출

횡단보도 위에 사람이 걷고 있는지 판단하는 여부

횡단보도 픽셀 바로 위에 있는 사람객체 픽셀
혹은 횡단보도 픽셀에 겹치는 사람픽셀 좌표의 유무 구분

혹은 횡단보도의 가로에 해당하는 좌표(가장 하단에 있는 좌표부터 세로 +a길이)
기준으로 해당 범위내에 있는 사람 객체 유무 구분
ROI기준 검출

이건 어떻게 하는것이 좋을까요


0.보행자 인식 박두레
1.신호등 인식 오재동
2.횡단보도 인식 신나정

조건에 의한 무단횡단자 검출은 위의 조건이 충족되고 난 이후에 실행

opencv로 비슷한 것들을 검출할 수 있는 소스를 찾아볼것

5시 즈음 재확인
관련 자료가 어느정도 확보되었는지 확인하실 예정

# %%
"""
의문 다차로에 있는 다른 신호등은 어떻게 구분하는가

횡단보도 구분
횡단보도 신호등 구분
차량 신호등 구분
사람 구분

#횡단보도 신호등이 빨간불일 때 구분 or조건
#차량 신호등이 초록불일 때 구분

#횡단보도 신호등이 초록불일 때 구분 or조건
#차량 신호등이 초록불일 때 구분


"""

# %%
"""
추가 변경
횡단보도 검출이 안되서
사람 객체의 이동 방향을 검출하는 알고리즘으로 small task 변경
"""

# %%
#영상읽기
cv2.Videocapture()로 영상읽기

#343-344p 신호등 구분
디스크립터 기준 사람 찾기
-match함수로부터 좋은 매칭점 찾기

#146p HSV색상으로 마스킹
-cv2.bitwise 연산으로

# %%
#모션감지 cctv
"""
이전과 이후의 두 프레임 영상에서 단순히 차이를 구해서는 움직임을 감지할 수 없음.
카메라를 고정한 책상이나 건물이 미세하게 떨리기도 하고 카메라의 이미지 센서(CCD)한계 떄문에 영상간의 차이는 반드시 항상 발생
따라서 세 프레임 a,b,c를 순차적으로 얻어와 a와 b의 차이, b와 c의 차이가 모두 발견되는
경우에 한해서 움직임이 있는 것으로 판단
"""
import cv2
import numpy as np

#감도 설정(카메라 품질에 따라 조정 필요)
thresh = 25    # 달라진 픽셀 값 기준치 설정
max_diff = 5   # 달라진 픽셀 갯수 기준치 설정

#카메라 캡션 장치 준비
a,b,c = None, None, None
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 480) #프레임 폭을 480으로 설정
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 320) #프레임 높이를 320으로 설정

if cap.isOpened():
    ret, a = cap.read() # a프레임 읽기
    ret, b = cap.read() # b프레임 읽기
    
    while ret:
        ret, c = cap.read() #c프레임 읽기
        draw = c.copy() #출력 영상에 사용할 복제본 
        if not ret:
            break

        #3개의 영상을 그레이 스케일로 변경
        a_gray = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
        b_gray = cv2.cvtColor(b, cv2.COLOR_BGR2GRAY)
        c_gray = cv2.cvtColor(c, cv2.COLOR_BGR2GRAY)

        # a-b, b-c 절대 값 차 구하기 
        diff1 = cv2.absdiff(a_gray, b_gray)
        diff2 = cv2.absdiff(b_gray, c_gray)

        # 스레시홀드로 기준치 이내의 차이는 무시
        ret, diff1_t = cv2.threshold(diff1, thresh, 255, cv2.THRESH_BINARY)
        ret, diff2_t = cv2.threshold(diff2, thresh, 255, cv2.THRESH_BINARY)
        
        # 두 차이에 대해서 AND 연산, 두 영상의 차이가 모두 발견된 경우
        diff = cv2.bitwise_and(diff1_t, diff2_t)
        
        #열림 연산으로 노이즈 제거
        k = cv2.getStructuringElement(cv2.MORPH_CROSS, (3,3))
        diff = cv2.morphologyEx(diff, cv2.MORPH_OPEN, k)

        #차이가 발생한 픽셀이 개수 판단후 사각형 그리기
        diff_cnt = cv2.countNonZero(diff)
        if diff_cnt > max_diff:
            nzero = np.nonzero(diff)
            cv2.rectangle(draw, (min(nzero[1]), min(nzero[0])), \
            (max(nzero[1]), max(nzero[0])), (0,255,0), 2)
            cv2.putText(draw, 'Motion Detected', (10,30), \
                       cv2.FONT_HERSHEY_DUPLEX, 0.5, (0,0,255))

        #컬러 스케일 영상과 스레시홀드 영상을 통합해서 출력
        stacked = np.hstack((draw, cv2.cvtColor(diff, cv2.COLOR_GRAY2BGR)))
        cv2.imshow('motion sensor', stacked)

        #다음 비교를 위해 영상 순서 정리
        a=b
        b=c

        if cv2.waitKey(1) & 0xFF == 27:
            cv2.destroyAllWindows()
            break

# %%
#데이터
"""
특정 영역만 추출


"""
"""
cv2.selectROI([win_name,], img[, showCrossHair=True, fromCenter=False])
  -win_name:ROI 선택을 진행할 창의 이름, str
  -img:ROI 선택을 진행할 이미지, Numpy ndarray
  -showCrossHair:선택 영역 중심에 십자 모양 표시 여부
  -fromCenter:마우스 시작 지점을 영역의 중심으로 지정
  -ret:선택한 영역 좌표와 크기(x,y,w,h), 선택을 취소한 경우 모두 0 
"""

#select ROI로 관심영역 지정
import cv2,  numpy as np

img = cv2.imread('./img/sunset.jpg')
x,y,w,h = cv2.selectROI('img', img, False)
if w and h:
    roi = img[y:y+h, x:x+w]
    cv2.imshow('cropped', roi)
    cv2.moveWindow('cropped', 0, 0)
    cv2.imwrite('./img/cropped2.jpg', roi)
cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2, numpy as np

video_file='C:/Users/admin/Desktop/traffic.mp4'
cap = cv2.VideoCapture(video_file)
if cap.isOpened():
    while True:
        ret, img = cap.read()
        if ret:
            cv2.imshow(video_file, img)
            cv2.waitKey(2)
            if cv2.waitKey(1) != -1: #아무키나 누르면
                cv2.imwrite('C:/Users/admin/Desktop/traffic photo.jpg', img)
                break
        else:
            break
    
else:
    print('cant open video')
cap.release()
cv2.destroyAllWindows()

# %%
#select ROI로 관심영역 지정
import cv2,  numpy as np

img=cv2.imread('C:/Users/admin/Desktop/traffic photo.jpg')
x,y,w,h = cv2.selectROI('img', img, False)
if w and h:
    roi = img[y:y+h, x:x+w]
    cv2.imshow('cropped', roi)
    cv2.moveWindow('cropped', 0, 0)
    cv2.imwrite('C:/Users/admin/Desktop/cropped2.jpg', roi)
cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
"""
• filename : 비디오 파일 이름 (e.g. 'video.mp4')
• fourcc : fourcc (e.g. cv2.VideoWriter_fourcc(*'DIVX'))
• fps : 초당 프레임 수 (e.g. 30)
• frameSize : 프레임 크기. (width, height) 튜플.
• isColor : 컬러 영상이면 True, 그렇지않으면 False. 기본값은 True입니다.
• retval : cv2.VideoWriter 객체
"""

# %%
import cv2, numpy as np

img=cv2.imread('C:/Users/admin/Desktop/traffic photo.jpg')
x,y,w,h = cv2.selectROI('img', img, False)
#화면크기를 위해 확인
roi = img[y:y+h, x:x+w]
print('shape',roi.shape, roi.shape[0], roi.shape[1])
video_file='C:/Users/admin/Desktop/traffic.mp4'
cap = cv2.VideoCapture(video_file)
if cap.isOpened():
    file_path='C:/Users/admin/Desktop/cropped_traffic2.avi'
    fps=30  #25.40 #초당 프레임 수
    fourcc = cv2.VideoWriter_fourcc(*'DIVX') #인코딩 포맷문자
    #원본과 roi는 프레임 크기가 다름
    width = roi.shape[1]     #cap.get(cv2.CAP_PROP_FRAME_WIDTH)이 아님 
    print('width:',width)
    height = roi.shape[0]    #cap.get(cv2.CAP_PROP_FRAME_HEIGHT)이 아님
    print('height:', height)
    size = (int(width), int(height))
    out = cv2.VideoWriter(file_path, fourcc, fps, size)
    while True:
        ret, frame = cap.read()        
        if ret:
            roi = frame[y:y+h, x:x+w]
            cv2.imshow('cropped', roi)   
            out.write(roi) #파일 저장
            if cv2.waitKey(int(1000/fps)) !=-1:
                break
        else:
            print('no frame')
            break   
else:
    print('cant open video')
    
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# shape (0, 0, 3) 0 0
# width: 0
# height: 0
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18412/1915595834.py in <module>
#      23         if ret:
#      24             roi = frame[y:y+h, x:x+w]
# ---> 25             cv2.imshow('cropped', roi)
#      26             out.write(roi) #파일 저장
#      27             if cv2.waitKey(int(1000/fps)) !=-1:
#
# error: OpenCV(4.5.3) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-1i5nllza\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
#화질구지 개선요함

# %%
#select ROI로 관심영역 지정
import cv2,  numpy as np

img=cv2.imread('C:/Users/admin/Desktop/traffic photo.jpg')
x,y,w,h = cv2.selectROI('img', img, False)
if w and h:
    roi = img[y:y+h, x:x+w]
    cv2.imshow('cropped', roi)
    cv2.moveWindow('cropped', 0, 0)
    cv2.imwrite('C:/Users/admin/Desktop/corss_croped.jpg', roi)
cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#횡단보도 검출하기

# %%
#BFMatcher와 SIFT로 매칭
import cv2, numpy as np
img_m6 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk0.jpg')
img_m5 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk1.jpg')
img_m4 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk2.jpg')
img_m3 = cv2.imread('C:/Users/admin/Desktop/crosswalk1.jpg')
img_m2 = cv2.imread('C:/Users/admin/Desktop/crosswalk2.jpg')
img_m1 = cv2.imread('C:/Users/admin/Desktop/crosswalk3.jpg')
img_m0 = cv2.imread('C:/Users/admin/Desktop/crosswalk4.jpg')

img2 = cv2.imread('C:/Users/admin/Desktop/day_test.jpg')
img3 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk2.jpg')

gray_m6 = cv2.cvtColor(img_m6, cv2.COLOR_BGR2GRAY)
gray_m5 = cv2.cvtColor(img_m5, cv2.COLOR_BGR2GRAY)
gray_m4 = cv2.cvtColor(img_m4, cv2.COLOR_BGR2GRAY)
gray_m3 = cv2.cvtColor(img_m3, cv2.COLOR_BGR2GRAY)
gray_m2 = cv2.cvtColor(img_m2, cv2.COLOR_BGR2GRAY)
gray_m1 = cv2.cvtColor(img_m1, cv2.COLOR_BGR2GRAY)
gray_m0 = cv2.cvtColor(img_m0, cv2.COLOR_BGR2GRAY)

gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
gray3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)

# SIFT 디스크립터 추출기 생성 ---①
detector = cv2.xfeatures2d.SIFT_create()

# 각 영상에 대해 키 포인트와 서술자 추출 ---②
kp_m6, desc_m6 = detector.detectAndCompute(gray_m6, None)
kp_m5, desc_m5 = detector.detectAndCompute(gray_m5, None)
kp_m4, desc_m4 = detector.detectAndCompute(gray_m4, None)
kp_m3, desc_m3 = detector.detectAndCompute(gray_m3, None)
kp_m2, desc_m2 = detector.detectAndCompute(gray_m2, None)
kp_m1, desc_m1 = detector.detectAndCompute(gray_m1, None)
kp_m0, desc_m0 = detector.detectAndCompute(gray_m0, None)

kp2, desc2 = detector.detectAndCompute(gray2, None)
kp3, desc3 = detector.detectAndCompute(gray3, None)

# BFMatcher 생성, L1 거리, 상호 체크 ---③
matcher = cv2.BFMatcher(cv2.NORM_L1, crossCheck=True)

# 매칭 계산 ---④
matches_m6 = matcher.match(desc_m6, desc3)
matches_m5 = matcher.match(desc_m5, desc3)
matches_m4 = matcher.match(desc_m4, desc3)
matches_m3 = matcher.match(desc_m3, desc3)
matches_m2 = matcher.match(desc_m2, desc3)
matches_m1 = matcher.match(desc_m1, desc3)
matches_m0 = matcher.match(desc_m0, desc3)

# 매칭 결과 그리기 ---⑤
res_m6 = cv2.drawMatches(img_m6, kp_m6, img3, kp3, matches_m6, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m5 = cv2.drawMatches(img_m5, kp_m5, img3, kp3, matches_m5, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m4 = cv2.drawMatches(img_m4, kp_m4, img3, kp3, matches_m4, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m3 = cv2.drawMatches(img_m3, kp_m3, img3, kp3, matches_m3, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m2 = cv2.drawMatches(img_m2, kp_m2, img3, kp3, matches_m2, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m1 = cv2.drawMatches(img_m1, kp_m1, img3, kp3, matches_m1, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m0 = cv2.drawMatches(img_m0, kp_m0, img3, kp3, matches_m0, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)

# 결과 출력 
cv2.imshow('BFMatcher + SIFT m6', res_m6)
cv2.imshow('BFMatcher + SIFT m5', res_m5)
cv2.imshow('BFMatcher + SIFT m4', res_m4)
cv2.imshow('BFMatcher + SIFT m3', res_m3)
cv2.imshow('BFMatcher + SIFT m2', res_m2)
cv2.imshow('BFMatcher + SIFT m1', res_m1)
cv2.imshow('BFMatcher + SIFT m0', res_m0)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
#아래코드 원본
import cv2
import numpy as np

img1 = cv2.imread('./img/taekwonv1.jpg')
img2 = cv2.imread('./img/figures.jpg')
gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

# SURF 서술자 추출기 생성 ---①
detector = cv2.xfeatures2d.SURF_create()
kp1, desc1 = detector.detectAndCompute(gray1, None)
kp2, desc2 = detector.detectAndCompute(gray2, None)

# BFMatcher 생성, L2 거리, 상호 체크 ---③
matcher = cv2.BFMatcher(cv2.NORM_L2, crossCheck=True)
# 매칭 계산 ---④
matches = matcher.match(desc1, desc2)
# 매칭 결과 그리기 ---⑤
res = cv2.drawMatches(img1, kp1, img2, kp2, matches, None, \
                     flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)

cv2.imshow('BF + SURF', res)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25144/2174600119.py in <module>
#       9
#      10 # SURF 서술자 추출기 생성 ---①
# ---> 11 detector = cv2.xfeatures2d.SURF_create()
#      12 kp1, desc1 = detector.detectAndCompute(gray1, None)
#      13 kp2, desc2 = detector.detectAndCompute(gray2, None)
#
# error: OpenCV(4.5.3) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-1i5nllza\opencv_contrib\modules\xfeatures2d\src\surf.cpp:1029: error: (-213:The function/feature is not implemented) This algorithm is patented and is excluded in this configuration; Set OPENCV_ENABLE_NONFREE CMake option and rebuild the library in function 'cv::xfeatures2d::SURF::create'

# %%
#BFMatcher와 SUFT로 매칭
import cv2
import numpy as np

img_m6 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk0.jpg')
img_m5 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk1.jpg')
img_m4 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk2.jpg')
img_m3 = cv2.imread('C:/Users/admin/Desktop/crosswalk1.jpg')
img_m2 = cv2.imread('C:/Users/admin/Desktop/crosswalk2.jpg')
img_m1 = cv2.imread('C:/Users/admin/Desktop/crosswalk3.jpg')
img_m0 = cv2.imread('C:/Users/admin/Desktop/crosswalk4.jpg')

img2 = cv2.imread('C:/Users/admin/Desktop/day_test.jpg')
img3 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk2.jpg')

gray_m6 = cv2.cvtColor(img_m6, cv2.COLOR_BGR2GRAY)
gray_m5 = cv2.cvtColor(img_m5, cv2.COLOR_BGR2GRAY)
gray_m4 = cv2.cvtColor(img_m4, cv2.COLOR_BGR2GRAY)
gray_m3 = cv2.cvtColor(img_m3, cv2.COLOR_BGR2GRAY)
gray_m2 = cv2.cvtColor(img_m2, cv2.COLOR_BGR2GRAY)
gray_m1 = cv2.cvtColor(img_m1, cv2.COLOR_BGR2GRAY)
gray_m0 = cv2.cvtColor(img_m0, cv2.COLOR_BGR2GRAY)

gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
gray3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)

# SURF 디스크립터 추출기 생성 ---①
detector = cv2.xfeatures2d.SURF_create()
kp_m6, desc_m6 = detector.detectAndCompute(gray_m6, None)
kp_m5, desc_m5 = detector.detectAndCompute(gray_m5, None)
kp_m4, desc_m4 = detector.detectAndCompute(gray_m4, None)
kp_m3, desc_m3 = detector.detectAndCompute(gray_m3, None)
kp_m2, desc_m2 = detector.detectAndCompute(gray_m2, None)
kp_m1, desc_m1 = detector.detectAndCompute(gray_m1, None)
kp_m0, desc_m0 = detector.detectAndCompute(gray_m0, None)

kp2, desc2 = detector.detectAndCompute(gray2, None)
kp3, desc3 = detector.detectAndCompute(gray3, None)

# BFMatcher 생성, L2 거리, 상호 체크 ---③
matcher = cv2.BFMatcher(cv2.NORM_L2, crossCheck=True)
# 매칭 계산 ---④
matches_m6 = matcher.match(desc_m6, desc3)
matches_m5 = matcher.match(desc_m5, desc3)
matches_m4 = matcher.match(desc_m4, desc3)
matches_m3 = matcher.match(desc_m3, desc3)
matches_m2 = matcher.match(desc_m2, desc3)
matches_m1 = matcher.match(desc_m1, desc3)
matches_m0 = matcher.match(desc_m0, desc3)
# 매칭 결과 그리기 ---⑤
res_m6 = cv2.drawMatches(img_m6, kp_m6, img3, kp3, matches_m6, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m5 = cv2.drawMatches(img_m5, kp_m5, img3, kp3, matches_m5, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m4 = cv2.drawMatches(img_m4, kp_m4, img3, kp3, matches_m4, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m3 = cv2.drawMatches(img_m3, kp_m3, img3, kp3, matches_m3, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m2 = cv2.drawMatches(img_m2, kp_m2, img3, kp3, matches_m2, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m1 = cv2.drawMatches(img_m1, kp_m1, img3, kp3, matches_m1, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m0 = cv2.drawMatches(img_m0, kp_m0, img3, kp3, matches_m0, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)

cv2.imshow('BF + SURF m6', res_m6)
cv2.imshow('BF + SURF m5', res_m5)
cv2.imshow('BF + SURF m4', res_m4)
cv2.imshow('BF + SURF m3', res_m3)
cv2.imshow('BF + SURF m2', res_m2)
cv2.imshow('BF + SURF m1', res_m1)
cv2.imshow('BF + SURF m0', res_m0)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25144/3017108754.py in <module>
#      26
#      27 # SURF 디스크립터 추출기 생성 ---①
# ---> 28 detector = cv2.xfeatures2d.SURF_create()
#      29 kp_m6, desc_m6 = detector.detectAndCompute(gray_m6, None)
#      30 kp_m5, desc_m5 = detector.detectAndCompute(gray_m5, None)
#
# error: OpenCV(4.5.3) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-1i5nllza\opencv_contrib\modules\xfeatures2d\src\surf.cpp:1029: error: (-213:The function/feature is not implemented) This algorithm is patented and is excluded in this configuration; Set OPENCV_ENABLE_NONFREE CMake option and rebuild the library in function 'cv::xfeatures2d::SURF::create'

# %%
#위의 에러는 패키지 버전 문제
#opencv에서 3.4.2.16이상에서 SIRF와 SURF는 더 이상 지원안한다고 함
#!pip install opencv-python==3.4.2.16
#!pip install opencv-contrib-python==3.4.2.16
#지금 받아보려 했는데 없음
# Out:
# ERROR: Could not find a version that satisfies the requirement opencv-python==3.4.2.16 (from versions: 3.4.10.37, 3.4.11.39, 3.4.11.41, 3.4.11.43, 3.4.11.45, 3.4.13.47, 3.4.14.51, 3.4.14.53, 3.4.15.55, 4.3.0.38, 4.4.0.40, 4.4.0.42, 4.4.0.44, 4.4.0.46, 4.5.1.48, 4.5.2.52, 4.5.2.54, 4.5.3.56)
# ERROR: No matching distribution found for opencv-python==3.4.2.16

# %%
#BFMatcher와 ORB로 매칭
import cv2, numpy as np

img_m6 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk0.jpg')
img_m5 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk1.jpg')
img_m4 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk2.jpg')
img_m3 = cv2.imread('C:/Users/admin/Desktop/crosswalk1.jpg')
img_m2 = cv2.imread('C:/Users/admin/Desktop/crosswalk2.jpg')
img_m1 = cv2.imread('C:/Users/admin/Desktop/crosswalk3.jpg')
img_m0 = cv2.imread('C:/Users/admin/Desktop/crosswalk4.jpg')

img2 = cv2.imread('C:/Users/admin/Desktop/day_test.jpg')
img3 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk2.jpg')

gray_m6 = cv2.cvtColor(img_m6, cv2.COLOR_BGR2GRAY)
gray_m5 = cv2.cvtColor(img_m5, cv2.COLOR_BGR2GRAY)
gray_m4 = cv2.cvtColor(img_m4, cv2.COLOR_BGR2GRAY)
gray_m3 = cv2.cvtColor(img_m3, cv2.COLOR_BGR2GRAY)
gray_m2 = cv2.cvtColor(img_m2, cv2.COLOR_BGR2GRAY)
gray_m1 = cv2.cvtColor(img_m1, cv2.COLOR_BGR2GRAY)
gray_m0 = cv2.cvtColor(img_m0, cv2.COLOR_BGR2GRAY)

gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
gray3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)

# ORB 디스크립터 추출기 생성 ---①
detector = cv2.ORB_create()
# 각 영상에 대해 키 포인트와 서술자 추출 ---②
kp_m6, desc_m6 = detector.detectAndCompute(gray_m6, None)
kp_m5, desc_m5 = detector.detectAndCompute(gray_m5, None)
kp_m4, desc_m4 = detector.detectAndCompute(gray_m4, None)
kp_m3, desc_m3 = detector.detectAndCompute(gray_m3, None)
kp_m2, desc_m2 = detector.detectAndCompute(gray_m2, None)
kp_m1, desc_m1 = detector.detectAndCompute(gray_m1, None)
kp_m0, desc_m0 = detector.detectAndCompute(gray_m0, None)

kp2, desc2 = detector.detectAndCompute(gray2, None)
kp3, desc3 = detector.detectAndCompute(gray3, None)

# BFMatcher 생성, Hamming 거리, 상호 체크 ---③
matcher = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
# 매칭 계산 ---④
matches_m6 = matcher.match(desc_m6, desc3)
matches_m5 = matcher.match(desc_m5, desc3)
matches_m4 = matcher.match(desc_m4, desc3)
matches_m3 = matcher.match(desc_m3, desc3)
matches_m2 = matcher.match(desc_m2, desc3)
matches_m1 = matcher.match(desc_m1, desc3)
matches_m0 = matcher.match(desc_m0, desc3)
# 매칭 결과 그리기 ---⑤
res_m6 = cv2.drawMatches(img_m6, kp_m6, img3, kp3, matches_m6, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m5 = cv2.drawMatches(img_m5, kp_m5, img3, kp3, matches_m5, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m4 = cv2.drawMatches(img_m4, kp_m4, img3, kp3, matches_m4, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m3 = cv2.drawMatches(img_m3, kp_m3, img3, kp3, matches_m3, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m2 = cv2.drawMatches(img_m2, kp_m2, img3, kp3, matches_m2, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m1 = cv2.drawMatches(img_m1, kp_m1, img3, kp3, matches_m1, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m0 = cv2.drawMatches(img_m0, kp_m0, img3, kp3, matches_m0, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)

cv2.imshow('BFMatcher + ORB m6', res_m6)
cv2.imshow('BFMatcher + ORB m5', res_m5)
cv2.imshow('BFMatcher + ORB m4', res_m4)
cv2.imshow('BFMatcher + ORB m3', res_m3)
cv2.imshow('BFMatcher + ORB m2', res_m2)
cv2.imshow('BFMatcher + ORB m1', res_m1)
cv2.imshow('BFMatcher + ORB m0', res_m0)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
#FLANNMatcher와 SIFT로 매칭
import cv2, numpy as np

img_m6 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk0.jpg')
img_m5 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk1.jpg')
img_m4 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk2.jpg')
img_m3 = cv2.imread('C:/Users/admin/Desktop/crosswalk1.jpg')
img_m2 = cv2.imread('C:/Users/admin/Desktop/crosswalk2.jpg')
img_m1 = cv2.imread('C:/Users/admin/Desktop/crosswalk3.jpg')
img_m0 = cv2.imread('C:/Users/admin/Desktop/crosswalk4.jpg')

img2 = cv2.imread('C:/Users/admin/Desktop/day_test.jpg')
img3 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk2.jpg')

gray_m6 = cv2.cvtColor(img_m6, cv2.COLOR_BGR2GRAY)
gray_m5 = cv2.cvtColor(img_m5, cv2.COLOR_BGR2GRAY)
gray_m4 = cv2.cvtColor(img_m4, cv2.COLOR_BGR2GRAY)
gray_m3 = cv2.cvtColor(img_m3, cv2.COLOR_BGR2GRAY)
gray_m2 = cv2.cvtColor(img_m2, cv2.COLOR_BGR2GRAY)
gray_m1 = cv2.cvtColor(img_m1, cv2.COLOR_BGR2GRAY)
gray_m0 = cv2.cvtColor(img_m0, cv2.COLOR_BGR2GRAY)

gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
gray3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)

# SIFT로 서술자 추출 ---①
detector = cv2.xfeatures2d.SIFT_create()
kp_m6, desc_m6 = detector.detectAndCompute(gray_m6, None)
kp_m5, desc_m5 = detector.detectAndCompute(gray_m5, None)
kp_m4, desc_m4 = detector.detectAndCompute(gray_m4, None)
kp_m3, desc_m3 = detector.detectAndCompute(gray_m3, None)
kp_m2, desc_m2 = detector.detectAndCompute(gray_m2, None)
kp_m1, desc_m1 = detector.detectAndCompute(gray_m1, None)
kp_m0, desc_m0 = detector.detectAndCompute(gray_m0, None)

kp2, desc2 = detector.detectAndCompute(gray2, None)
kp3, desc3 = detector.detectAndCompute(gray3, None)

#인덱스 파라미터와 검색 파라미터 설정
FLANN_INDEX_KDTREE = 1
index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=5)
search_params = dict(checks=50)

# Flann 매처 생성 ---③
matcher = cv2.FlannBasedMatcher(index_params, search_params)

# 매칭 계산 ---④
matches_m6 = matcher.match(desc_m6, desc3)
matches_m5 = matcher.match(desc_m5, desc3)
matches_m4 = matcher.match(desc_m4, desc3)
matches_m3 = matcher.match(desc_m3, desc3)
matches_m2 = matcher.match(desc_m2, desc3)
matches_m1 = matcher.match(desc_m1, desc3)
matches_m0 = matcher.match(desc_m0, desc3)

# 매칭 그리기
res_m6 = cv2.drawMatches(img_m6, kp_m6, img3, kp3, matches_m6, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m5 = cv2.drawMatches(img_m6, kp_m5, img3, kp3, matches_m5, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m4 = cv2.drawMatches(img_m6, kp_m4, img3, kp3, matches_m4, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m3 = cv2.drawMatches(img_m6, kp_m3, img3, kp3, matches_m3, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m2 = cv2.drawMatches(img_m6, kp_m2, img3, kp3, matches_m2, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m1 = cv2.drawMatches(img_m6, kp_m1, img3, kp3, matches_m1, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m0 = cv2.drawMatches(img_m6, kp_m0, img3, kp3, matches_m0, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)

cv2.imshow('Flann + SIFT m6', res_m6)
cv2.imshow('Flann + SIFT m5', res_m5)
cv2.imshow('Flann + SIFT m4', res_m4)
cv2.imshow('Flann + SIFT m3', res_m3)
cv2.imshow('Flann + SIFT m2', res_m2)
cv2.imshow('Flann + SIFT m1', res_m1)
cv2.imshow('Flann + SIFT m0', res_m0)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
#FLANNMatcher와 ORB로 매칭
import cv2, numpy as np

img_m6 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk0.jpg')
img_m5 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk1.jpg')
img_m4 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk2.jpg')
img_m3 = cv2.imread('C:/Users/admin/Desktop/crosswalk1.jpg')
img_m2 = cv2.imread('C:/Users/admin/Desktop/crosswalk2.jpg')
img_m1 = cv2.imread('C:/Users/admin/Desktop/crosswalk3.jpg')
img_m0 = cv2.imread('C:/Users/admin/Desktop/crosswalk4.jpg')

img2 = cv2.imread('C:/Users/admin/Desktop/day_test.jpg')
img3 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk2.jpg')

gray_m6 = cv2.cvtColor(img_m6, cv2.COLOR_BGR2GRAY)
gray_m5 = cv2.cvtColor(img_m5, cv2.COLOR_BGR2GRAY)
gray_m4 = cv2.cvtColor(img_m4, cv2.COLOR_BGR2GRAY)
gray_m3 = cv2.cvtColor(img_m3, cv2.COLOR_BGR2GRAY)
gray_m2 = cv2.cvtColor(img_m2, cv2.COLOR_BGR2GRAY)
gray_m1 = cv2.cvtColor(img_m1, cv2.COLOR_BGR2GRAY)
gray_m0 = cv2.cvtColor(img_m0, cv2.COLOR_BGR2GRAY)

gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
gray3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)

# SIFT로 서술자 추출 ---①
detector = cv2.ORB_create()
kp_m6, desc_m6 = detector.detectAndCompute(gray_m6, None)
kp_m5, desc_m5 = detector.detectAndCompute(gray_m5, None)
kp_m4, desc_m4 = detector.detectAndCompute(gray_m4, None)
kp_m3, desc_m3 = detector.detectAndCompute(gray_m3, None)
kp_m2, desc_m2 = detector.detectAndCompute(gray_m2, None)
kp_m1, desc_m1 = detector.detectAndCompute(gray_m1, None)
kp_m0, desc_m0 = detector.detectAndCompute(gray_m0, None)

kp2, desc2 = detector.detectAndCompute(gray2, None)
kp3, desc3 = detector.detectAndCompute(gray3, None)

# 인덱스 파라미터 설정 ---①
FLANN_INDEX_LSH = 6
index_params= dict(algorithm = FLANN_INDEX_LSH,
                   table_number = 6,
                   key_size = 12,
                   multi_probe_level = 1)

# 검색 파라미터 설정 ---②
search_params=dict(checks=32)

# Flann 매처 생성 ---③
matcher = cv2.FlannBasedMatcher(index_params, search_params)

# 매칭 계산 ---④
matches_m6 = matcher.match(desc_m6, desc3)
matches_m5 = matcher.match(desc_m5, desc3)
matches_m4 = matcher.match(desc_m4, desc3)
matches_m3 = matcher.match(desc_m3, desc3)
matches_m2 = matcher.match(desc_m2, desc3)
matches_m1 = matcher.match(desc_m1, desc3)
matches_m0 = matcher.match(desc_m0, desc3)

# 매칭 그리기
res_m6 = cv2.drawMatches(img_m6, kp_m6, img3, kp3, matches_m6, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m5 = cv2.drawMatches(img_m5, kp_m5, img3, kp3, matches_m5, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m4 = cv2.drawMatches(img_m4, kp_m4, img3, kp3, matches_m4, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m3 = cv2.drawMatches(img_m3, kp_m3, img3, kp3, matches_m3, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m2 = cv2.drawMatches(img_m2, kp_m2, img3, kp3, matches_m2, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m1 = cv2.drawMatches(img_m1, kp_m1, img3, kp3, matches_m1, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m0 = cv2.drawMatches(img_m0, kp_m0, img3, kp3, matches_m0, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)

cv2.imshow('Flann + ORB m6', res_m6)
cv2.imshow('Flann + ORB m5', res_m5)
cv2.imshow('Flann + ORB m4', res_m4)
cv2.imshow('Flann + ORB m3', res_m3)
cv2.imshow('Flann + ORB m2', res_m2)
cv2.imshow('Flann + ORB m1', res_m1)
cv2.imshow('Flann + ORB m0', res_m0)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
#match 함수로부터 좋은 매칭점 찾기
import cv2, numpy as np

img_m6 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk0.jpg')
img_m5 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk1.jpg')
img_m4 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk2.jpg')
img_m3 = cv2.imread('C:/Users/admin/Desktop/crosswalk1.jpg')
img_m2 = cv2.imread('C:/Users/admin/Desktop/crosswalk2.jpg')
img_m1 = cv2.imread('C:/Users/admin/Desktop/crosswalk3.jpg')
img_m0 = cv2.imread('C:/Users/admin/Desktop/crosswalk4.jpg')

img2 = cv2.imread('C:/Users/admin/Desktop/day_test.jpg')
img3 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk2.jpg')

gray_m6 = cv2.cvtColor(img_m6, cv2.COLOR_BGR2GRAY)
gray_m5 = cv2.cvtColor(img_m5, cv2.COLOR_BGR2GRAY)
gray_m4 = cv2.cvtColor(img_m4, cv2.COLOR_BGR2GRAY)
gray_m3 = cv2.cvtColor(img_m3, cv2.COLOR_BGR2GRAY)
gray_m2 = cv2.cvtColor(img_m2, cv2.COLOR_BGR2GRAY)
gray_m1 = cv2.cvtColor(img_m1, cv2.COLOR_BGR2GRAY)
gray_m0 = cv2.cvtColor(img_m0, cv2.COLOR_BGR2GRAY)

gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
gray3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)

# ORB로 서술자 추출 ---①
detector = cv2.ORB_create()
kp_m6, desc_m6 = detector.detectAndCompute(gray_m6, None)
kp_m5, desc_m5 = detector.detectAndCompute(gray_m5, None)
kp_m4, desc_m4 = detector.detectAndCompute(gray_m4, None)
kp_m3, desc_m3 = detector.detectAndCompute(gray_m3, None)
kp_m2, desc_m2 = detector.detectAndCompute(gray_m2, None)
kp_m1, desc_m1 = detector.detectAndCompute(gray_m1, None)
kp_m0, desc_m0 = detector.detectAndCompute(gray_m0, None)

kp2, desc2 = detector.detectAndCompute(gray2, None)
kp3, desc3 = detector.detectAndCompute(gray3, None)

# BF-Hamming으로 매칭 ---②
matcher = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
matches_m6 = matcher.match(desc_m6, desc3)
matches_m5 = matcher.match(desc_m5, desc3)
matches_m4 = matcher.match(desc_m4, desc3)
matches_m3 = matcher.match(desc_m3, desc3)
matches_m2 = matcher.match(desc_m2, desc3)
matches_m1 = matcher.match(desc_m1, desc3)
matches_m0 = matcher.match(desc_m0, desc3)

# 매칭 결과를 거리기준 오름차순으로 정렬 ---③
matches_m6 = sorted(matches_m6, key=lambda x:x.distance)
matches_m5 = sorted(matches_m5, key=lambda x:x.distance)
matches_m4 = sorted(matches_m4, key=lambda x:x.distance)
matches_m3 = sorted(matches_m3, key=lambda x:x.distance)
matches_m2 = sorted(matches_m2, key=lambda x:x.distance)
matches_m1 = sorted(matches_m1, key=lambda x:x.distance)
matches_m0 = sorted(matches_m0, key=lambda x:x.distance)

# 최소 거리 값과 최대 거리 값 확보 ---④
min_dist_m6, max_dist_m6 = matches_m6[0].distance, matches_m6[-1].distance
min_dist_m5, max_dist_m5 = matches_m5[0].distance, matches_m5[-1].distance
min_dist_m4, max_dist_m4 = matches_m4[0].distance, matches_m4[-1].distance
min_dist_m3, max_dist_m3 = matches_m3[0].distance, matches_m3[-1].distance
min_dist_m2, max_dist_m2 = matches_m2[0].distance, matches_m2[-1].distance
min_dist_m1, max_dist_m1 = matches_m1[0].distance, matches_m1[-1].distance
min_dist_m0, max_dist_m0 = matches_m0[0].distance, matches_m0[-1].distance

# 최소 거리의 15% 지점을 임계점으로 설정 ---⑤
ratio = 0.2
good_thresh_m6 = (max_dist_m6 - min_dist_m6) * ratio + min_dist_m6
good_thresh_m5 = (max_dist_m5 - min_dist_m5) * ratio + min_dist_m5
good_thresh_m4 = (max_dist_m4 - min_dist_m4) * ratio + min_dist_m4
good_thresh_m3 = (max_dist_m3 - min_dist_m3) * ratio + min_dist_m3
good_thresh_m2 = (max_dist_m2 - min_dist_m2) * ratio + min_dist_m2
good_thresh_m1 = (max_dist_m1 - min_dist_m1) * ratio + min_dist_m1
good_thresh_m0 = (max_dist_m0 - min_dist_m0) * ratio + min_dist_m0

# 임계점 보다 작은 매칭점만 좋은 매칭점으로 분류 ---⑥
good_matches_m6 = [m for m in matches_m6 if m.distance < good_thresh_m6]
good_matches_m5 = [m for m in matches_m5 if m.distance < good_thresh_m5]
good_matches_m4 = [m for m in matches_m4 if m.distance < good_thresh_m4]
good_matches_m3 = [m for m in matches_m3 if m.distance < good_thresh_m3]
good_matches_m2 = [m for m in matches_m2 if m.distance < good_thresh_m2]
good_matches_m1 = [m for m in matches_m1 if m.distance < good_thresh_m1]
good_matches_m0 = [m for m in matches_m0 if m.distance < good_thresh_m0]


print('matches_m6:%d/%d, min:%.2f, max:%.2f, thresh:%.2f' \
        %(len(good_matches_m6),len(matches_m6), min_dist_m6, max_dist_m6, good_thresh_m6))
print('matches_m5:%d/%d, min:%.2f, max:%.2f, thresh:%.2f' \
        %(len(good_matches_m5),len(matches_m5), min_dist_m5, max_dist_m5, good_thresh_m5))
print('matches_m4:%d/%d, min:%.2f, max:%.2f, thresh:%.2f' \
        %(len(good_matches_m4),len(matches_m4), min_dist_m4, max_dist_m4, good_thresh_m4))
print('matches_m3:%d/%d, min:%.2f, max:%.2f, thresh:%.2f' \
        %(len(good_matches_m3),len(matches_m3), min_dist_m3, max_dist_m3, good_thresh_m3))
print('matches_m2:%d/%d, min:%.2f, max:%.2f, thresh:%.2f' \
        %(len(good_matches_m2),len(matches_m2), min_dist_m2, max_dist_m2, good_thresh_m2))
print('matches_m1:%d/%d, min:%.2f, max:%.2f, thresh:%.2f' \
        %(len(good_matches_m1),len(matches_m1), min_dist_m1, max_dist_m1, good_thresh_m1))
print('matches_m0:%d/%d, min:%.2f, max:%.2f, thresh:%.2f' \
        %(len(good_matches_m0),len(matches_m0), min_dist_m0, max_dist_m0, good_thresh_m0))


# 좋은 매칭점만 그리기 ---⑦
res_m6 = cv2.drawMatches(img_m6, kp_m6, img3, kp3, good_matches_m6, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m5 = cv2.drawMatches(img_m5, kp_m5, img3, kp3, good_matches_m5, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m4 = cv2.drawMatches(img_m4, kp_m4, img3, kp3, good_matches_m4, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m3 = cv2.drawMatches(img_m3, kp_m3, img3, kp3, good_matches_m3, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m2 = cv2.drawMatches(img_m2, kp_m2, img3, kp3, good_matches_m2, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m1 = cv2.drawMatches(img_m1, kp_m1, img3, kp3, good_matches_m1, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m0 = cv2.drawMatches(img_m0, kp_m0, img3, kp3, good_matches_m0, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)

# 결과 출력
cv2.imshow('Good Match m6', res_m6)
cv2.imshow('Good Match m5', res_m5)
cv2.imshow('Good Match m4', res_m4)
cv2.imshow('Good Match m3', res_m3)
cv2.imshow('Good Match m2', res_m2)
cv2.imshow('Good Match m1', res_m1)
cv2.imshow('Good Match m0', res_m0)

cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# matches_m6:3/122, min:33.00, max:87.00, thresh:43.80
# matches_m5:6/92, min:35.00, max:81.00, thresh:44.20
# matches_m4:0/500, min:0.00, max:0.00, thresh:0.00
# matches_m3:5/118, min:38.00, max:87.00, thresh:47.80
# matches_m2:5/118, min:36.00, max:81.00, thresh:45.00
# matches_m1:2/113, min:36.00, max:84.00, thresh:45.60
# matches_m0:10/118, min:38.00, max:86.00, thresh:47.60

# %%
#knnmatch 함수로부터 좋은 매칭점 찾기
import cv2, numpy as np

img_m6 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk0.jpg')
img_m5 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk1.jpg')
img_m4 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk2.jpg')
img_m3 = cv2.imread('C:/Users/admin/Desktop/crosswalk1.jpg')
img_m2 = cv2.imread('C:/Users/admin/Desktop/crosswalk2.jpg')
img_m1 = cv2.imread('C:/Users/admin/Desktop/crosswalk3.jpg')
img_m0 = cv2.imread('C:/Users/admin/Desktop/crosswalk4.jpg')

img2 = cv2.imread('C:/Users/admin/Desktop/day_test.jpg')
img3 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk2.jpg')

# ORB로 서술자 추출 ---①
detector = cv2.ORB_create()
kp_m6, desc_m6 = detector.detectAndCompute(gray_m6, None)
kp_m5, desc_m5 = detector.detectAndCompute(gray_m5, None)
kp_m4, desc_m4 = detector.detectAndCompute(gray_m4, None)
kp_m3, desc_m3 = detector.detectAndCompute(gray_m3, None)
kp_m2, desc_m2 = detector.detectAndCompute(gray_m2, None)
kp_m1, desc_m1 = detector.detectAndCompute(gray_m1, None)
kp_m0, desc_m0 = detector.detectAndCompute(gray_m0, None)

kp2, desc2 = detector.detectAndCompute(gray2, None)
kp3, desc3 = detector.detectAndCompute(gray3, None)
# BF-Hamming 생성 ---②
matcher = cv2.BFMatcher(cv2.NORM_HAMMING2)
# knnMatch, k=2 ---③
matches_m6 = matcher.knnMatch(desc_m6, desc3, 2)
matches_m5 = matcher.knnMatch(desc_m5, desc3, 2)
matches_m4 = matcher.knnMatch(desc_m4, desc3, 2)
matches_m3 = matcher.knnMatch(desc_m3, desc3, 2)
matches_m2 = matcher.knnMatch(desc_m2, desc3, 2)
matches_m1 = matcher.knnMatch(desc_m1, desc3, 2)
matches_m0 = matcher.knnMatch(desc_m0, desc3, 2)
"""
matches_m6 = matcher.knnMatch(desc_m6, desc3, 3)
matches_m5 = matcher.knnMatch(desc_m5, desc3, 3)
matches_m4 = matcher.knnMatch(desc_m4, desc3, 3)
matches_m3 = matcher.knnMatch(desc_m3, desc3, 3)
matches_m2 = matcher.knnMatch(desc_m2, desc3, 3)
matches_m1 = matcher.knnMatch(desc_m1, desc3, 3)
matches_m0 = matcher.knnMatch(desc_m0, desc3, 3)

"""
# 첫번재 이웃의 거리가 두 번째 이웃 거리의 75% 이내인 것만 추출---⑤
ratio = 0.75
good_matches_m6 = [first for first,second in matches_m6 \
                    if first.distance < second.distance * ratio]
print('matches:%d/%d' %(len(good_matches_m6),len(matches_m6)))

good_matches_m5 = [first for first,second in matches_m5 \
                    if first.distance < second.distance * ratio]
print('matches:%d/%d' %(len(good_matches_m5),len(matches_m5)))

good_matches_m4 = [first for first,second in matches_m4 \
                    if first.distance < second.distance * ratio]
print('matches:%d/%d' %(len(good_matches_m4),len(matches_m4)))

good_matches_m3 = [first for first,second in matches_m3 \
                    if first.distance < second.distance * ratio]
print('matches:%d/%d' %(len(good_matches_m3),len(matches_m3)))

good_matches_m2 = [first for first,second in matches_m2 \
                    if first.distance < second.distance * ratio]
print('matches:%d/%d' %(len(good_matches_m2),len(matches_m2)))

good_matches_m1 = [first for first,second in matches_m1 \
                    if first.distance < second.distance * ratio]
print('matches:%d/%d' %(len(good_matches_m1),len(matches_m1)))

good_matches_m0 = [first for first,second in matches_m0 \
                    if first.distance < second.distance * ratio]
print('matches:%d/%d' %(len(good_matches_m0),len(matches_m0)))

# 좋은 매칭만 그리기
res_m6 = cv2.drawMatches(img_m6, kp_m6, img3, kp3, good_matches_m6, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m5 = cv2.drawMatches(img_m5, kp_m5, img3, kp3, good_matches_m5, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m4 = cv2.drawMatches(img_m4, kp_m4, img3, kp3, good_matches_m4, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m3 = cv2.drawMatches(img_m3, kp_m3, img3, kp3, good_matches_m3, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m2 = cv2.drawMatches(img_m2, kp_m2, img3, kp3, good_matches_m2, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m1 = cv2.drawMatches(img_m1, kp_m1, img3, kp3, good_matches_m1, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m0 = cv2.drawMatches(img_m0, kp_m0, img3, kp3, good_matches_m0, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)

# 결과 출력                    
cv2.imshow('Matching_m6', res_m6)
cv2.imshow('Matching_m5', res_m5)
cv2.imshow('Matching_m4', res_m4)
cv2.imshow('Matching_m3', res_m3)
cv2.imshow('Matching_m2', res_m2)
cv2.imshow('Matching_m1', res_m1)
cv2.imshow('Matching_m0', res_m0)

cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22540/1409544641.py in <module>
#      15 # ORB로 서술자 추출 ---①
#      16 detector = cv2.ORB_create()
# ---> 17 kp_m6, desc_m6 = detector.detectAndCompute(gray_m6, None)
#      18 kp_m5, desc_m5 = detector.detectAndCompute(gray_m5, None)
#      19 kp_m4, desc_m4 = detector.detectAndCompute(gray_m4, None)
#
# NameError: name 'gray_m6' is not defined

# %%
#매칭점 원근 변환으로 영역 찾기
import cv2, numpy as np

img_m6 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk0.jpg')
img_m5 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk1.jpg')
img_m4 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk2.jpg')
img_m3 = cv2.imread('C:/Users/admin/Desktop/crosswalk1.jpg')
img_m2 = cv2.imread('C:/Users/admin/Desktop/crosswalk2.jpg')
img_m1 = cv2.imread('C:/Users/admin/Desktop/crosswalk3.jpg')
img_m0 = cv2.imread('C:/Users/admin/Desktop/crosswalk4.jpg')

img2 = cv2.imread('C:/Users/admin/Desktop/day_test.jpg')
img3 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk2.jpg')


gray_m6 = cv2.cvtColor(img_m6, cv2.COLOR_BGR2GRAY)
gray_m5 = cv2.cvtColor(img_m5, cv2.COLOR_BGR2GRAY)
gray_m4 = cv2.cvtColor(img_m4, cv2.COLOR_BGR2GRAY)
gray_m3 = cv2.cvtColor(img_m3, cv2.COLOR_BGR2GRAY)
gray_m2 = cv2.cvtColor(img_m2, cv2.COLOR_BGR2GRAY)
gray_m1 = cv2.cvtColor(img_m1, cv2.COLOR_BGR2GRAY)
gray_m0 = cv2.cvtColor(img_m0, cv2.COLOR_BGR2GRAY)

gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
gray3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)

# ORB, BF-Hamming 로 knnMatch  ---①
detector = cv2.ORB_create()
kp_m6, desc_m6 = detector.detectAndCompute(gray_m6, None)
kp_m5, desc_m5 = detector.detectAndCompute(gray_m5, None)
kp_m4, desc_m4 = detector.detectAndCompute(gray_m4, None)
kp_m3, desc_m3 = detector.detectAndCompute(gray_m3, None)
kp_m2, desc_m2 = detector.detectAndCompute(gray_m2, None)
kp_m1, desc_m1 = detector.detectAndCompute(gray_m1, None)
kp_m0, desc_m0 = detector.detectAndCompute(gray_m0, None)

kp2, desc2 = detector.detectAndCompute(gray2, None)
kp3, desc3 = detector.detectAndCompute(gray3, None)

matcher = cv2.BFMatcher(cv2.NORM_HAMMING2)

matches_m6 = matcher.knnMatch(desc_m6, desc3, 2)
matches_m5 = matcher.knnMatch(desc_m5, desc3, 2)
matches_m4 = matcher.knnMatch(desc_m4, desc3, 2)
matches_m3 = matcher.knnMatch(desc_m3, desc3, 2)
matches_m2 = matcher.knnMatch(desc_m2, desc3, 2)
matches_m1 = matcher.knnMatch(desc_m1, desc3, 2)
matches_m0 = matcher.knnMatch(desc_m0, desc3, 2)

matches2 = matcher.knnMatch(desc2, desc3, 2)
matches3 = matcher.knnMatch(desc3, desc3, 2)
# 이웃 거리의 75%로 좋은 매칭점 추출---②
ratio = 0.75
good_matches_m6 = [first for first,second in matches_m6 \
                    if first.distance < second.distance * ratio]
print('good matches_m6:%d/%d' %(len(good_matches_m6),len(matches_m6)))

good_matches_m5 = [first for first,second in matches_m5 \
                    if first.distance < second.distance * ratio]
print('good matches_m5:%d/%d' %(len(good_matches_m5),len(matches_m5)))

good_matches_m4 = [first for first,second in matches_m4 \
                    if first.distance < second.distance * ratio]
print('good matches_m4:%d/%d' %(len(good_matches_m4),len(matches_m4)))

good_matches_m3 = [first for first,second in matches_m3 \
                    if first.distance < second.distance * ratio]
print('good matches_m36:%d/%d' %(len(good_matches_m3),len(matches_m3)))

good_matches_m2 = [first for first,second in matches_m2 \
                    if first.distance < second.distance * ratio]
print('good matches_m2:%d/%d' %(len(good_matches_m2),len(matches_m2)))

good_matches_m1 = [first for first,second in matches_m1 \
                    if first.distance < second.distance * ratio]
print('good matches_m1:%d/%d' %(len(good_matches_m1),len(matches_m1)))

good_matches_m0 = [first for first,second in matches_m0 \
                    if first.distance < second.distance * ratio]
print('good matches_m0:%d/%d' %(len(good_matches_m0),len(matches_m0)))

# 좋은 매칭점의 queryIdx로 원본 영상의 좌표 구하기 ---③
src_pts_m6 = np.float32([ kp_m6[m.queryIdx].pt for m in good_matches_m6 ])
print(src_pts_m6)

# 좋은 매칭점의 trainIdx로 대상 영상의 좌표 구하기 ---④
dst_pts_m6 = np.float32([ kp3[m.trainIdx].pt for m in good_matches_m6 ])
print(dst_pts_m6)
print('=============================================================')

# 좋은 매칭점의 queryIdx로 원본 영상의 좌표 구하기 ---③
src_pts_m5 = np.float32([ kp3[m.queryIdx].pt for m in good_matches_m5])
print(src_pts_m5)

# 좋은 매칭점의 trainIdx로 대상 영상의 좌표 구하기 ---④
dst_pts_m5 = np.float32([ kp3[m.trainIdx].pt for m in good_matches_m5 ])
print(dst_pts_m5)
print('=============================================================')

# 좋은 매칭점의 queryIdx로 원본 영상의 좌표 구하기 ---③
src_pts_m4 = np.float32([ kp3[m.queryIdx].pt for m in good_matches_m4 ])
print(src_pts_m4)

# 좋은 매칭점의 trainIdx로 대상 영상의 좌표 구하기 ---④
dst_pts_m4 = np.float32([ kp3[m.trainIdx].pt for m in good_matches_m4 ])
print(dst_pts_m4)
print('=============================================================')

# 좋은 매칭점의 queryIdx로 원본 영상의 좌표 구하기 ---③
src_pts_m3 = np.float32([ kp_m3[m.queryIdx].pt for m in good_matches_m3 ])
print(src_pts_m3)

# 좋은 매칭점의 trainIdx로 대상 영상의 좌표 구하기 ---④
dst_pts_m3 = np.float32([ kp3[m.trainIdx].pt for m in good_matches_m3 ])
print(dst_pts_m3)
print('=============================================================')

# 좋은 매칭점의 queryIdx로 원본 영상의 좌표 구하기 ---③
src_pts_m2 = np.float32([ kp_m3[m.queryIdx].pt for m in good_matches_m2 ])
print(src_pts_m2)

# 좋은 매칭점의 trainIdx로 대상 영상의 좌표 구하기 ---④
dst_pts_m2 = np.float32([ kp3[m.trainIdx].pt for m in good_matches_m2 ])
print(dst_pts_m2)
print('=============================================================')

# 좋은 매칭점의 queryIdx로 원본 영상의 좌표 구하기 ---③
src_pts_m1 = np.float32([ kp_m6[m.queryIdx].pt for m in good_matches_m1 ])
print(src_pts_m1)

# 좋은 매칭점의 trainIdx로 대상 영상의 좌표 구하기 ---④
dst_pts_m1 = np.float32([ kp3[m.trainIdx].pt for m in good_matches_m1 ])
print(dst_pts_m1)
print('=============================================================')


# 좋은 매칭점의 queryIdx로 원본 영상의 좌표 구하기 ---③
src_pts_m0 = np.float32([ kp_m0[m.queryIdx].pt for m in good_matches_m0 ])
print(src_pts_m0)

# 좋은 매칭점의 trainIdx로 대상 영상의 좌표 구하기 ---④
dst_pts_m0 = np.float32([ kp3[m.trainIdx].pt for m in good_matches_m0 ])
print(dst_pts_m0)
print('=============================================================')


# 원근 변환 행렬 구하기 ---⑤
mtrx_m6, mask_m6 = cv2.findHomography(src_pts_m6, dst_pts_m6)
mtrx_m5, mask_m5 = cv2.findHomography(src_pts_m5, dst_pts_m5)
mtrx_m4, mask_m4 = cv2.findHomography(src_pts_m4, dst_pts_m4)
mtrx_m3, mask_m3 = cv2.findHomography(src_pts_m3, dst_pts_m3)
mtrx_m2, mask_m2 = cv2.findHomography(src_pts_m2, dst_pts_m2)
mtrx_m1, mask_m1 = cv2.findHomography(src_pts_m1, dst_pts_m1)
mtrx_m0, mask_m0 = cv2.findHomography(src_pts_m0, dst_pts_m0)

# 원본 영상 크기로 변환 영역 좌표 생성 ---⑥
h_m6,w_m6, = img_m6.shape[:2]
h_m5,w_m5, = img_m5.shape[:2]
h_m4,w_m4, = img_m4.shape[:2]
h_m3,w_m3, = img_m3.shape[:2]
h_m2,w_m2, = img_m2.shape[:2]
h_m1,w_m1, = img_m1.shape[:2]
h_m0,w_m0, = img_m0.shape[:2]

pts_m6 = np.float32([ [[0,0]],[[0,h_m6-1]],[[w_m6-1,h_m6-1]],[[w_m6-1,0]] ])
pts_m5 = np.float32([ [[0,0]],[[0,h_m5-1]],[[w_m5-1,h_m6-1]],[[w_m5-1,0]] ])
pts_m4 = np.float32([ [[0,0]],[[0,h_m4-1]],[[w_m4-1,h_m6-1]],[[w_m4-1,0]] ])
pts_m3 = np.float32([ [[0,0]],[[0,h_m3-1]],[[w_m3-1,h_m6-1]],[[w_m3-1,0]] ])
pts_m2 = np.float32([ [[0,0]],[[0,h_m2-1]],[[w_m2-1,h_m6-1]],[[w_m2-1,0]] ])
pts_m1 = np.float32([ [[0,0]],[[0,h_m1-1]],[[w_m1-1,h_m6-1]],[[w_m1-1,0]] ])
pts_m0 = np.float32([ [[0,0]],[[0,h_m0-1]],[[w_m0-1,h_m6-1]],[[w_m0-1,0]] ])

# 원본 영상 좌표를 원근 변환  ---⑦
dst_m6 = cv2.perspectiveTransform(pts_m6,mtrx_m6)
dst_m5 = cv2.perspectiveTransform(pts_m5,mtrx_m5)
dst_m4 = cv2.perspectiveTransform(pts_m4,mtrx_m4)
dst_m3 = cv2.perspectiveTransform(pts_m3,mtrx_m3)
dst_m2 = cv2.perspectiveTransform(pts_m2,mtrx_m2)
dst_m1 = cv2.perspectiveTransform(pts_m1,mtrx_m1)
dst_m0 = cv2.perspectiveTransform(pts_m0,mtrx_m0)

# 변환 좌표 영역을 대상 영상에 그리기 ---⑧
img3 = cv2.polylines(img3,[np.int32(dst)],True,255,3, cv2.LINE_AA)

# 좋은 매칭 그려서 출력 ---⑨
res_m6 = cv2.drawMatches(img_m6, kp_m6, img3, kp3, good_matches_m6, None, \
                    flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m5 = cv2.drawMatches(img_m5, kp_m5, img3, kp3, good_matches_m5, None, \
                    flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m4 = cv2.drawMatches(img_m4, kp_m4, img3, kp3, good_matches_m4, None, \
                    flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m3 = cv2.drawMatches(img_m3, kp_m3, img3, kp3, good_matches_m3, None, \
                    flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m2 = cv2.drawMatches(img_m2, kp_m2, img3, kp3, good_matches_m2, None, \
                    flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m1 = cv2.drawMatches(img_m1, kp_m1, img3, kp3, good_matches_m1, None, \
                    flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m0 = cv2.drawMatches(img_m0, kp_m0, img3, kp3, good_matches_m0, None, \
                    flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)


cv2.imshow('Matching Homography_m6', res_m6)
cv2.imshow('Matching Homography_m5', res_m5)
cv2.imshow('Matching Homography_m4', res_m4)
cv2.imshow('Matching Homography_m3', res_m3)
cv2.imshow('Matching Homography_m2', res_m2)
cv2.imshow('Matching Homography_m1', res_m1)
cv2.imshow('Matching Homography_m0', res_m0)

cv2.waitKey()
cv2.destroyAllWindows()

#포인트 안뽑힘
# Out:
# good matches_m6:2/414
# good matches_m5:0/321
# good matches_m4:500/500
# good matches_m36:0/487
# good matches_m2:0/500
# good matches_m1:4/500
# good matches_m0:4/500
# [[234.        88.      ]
#  [ 60.480007  84.672005]]
# [[623.  53.]
#  [474.  38.]]
# =============================================================
# []
# []
# =============================================================
# [[ 95.        48.      ]
#  [117.        50.      ]
#  [113.        50.      ]
#  [496.       107.      ]
#  [464.        40.      ]
#  [119.        54.      ]
#  [298.       190.      ]
#  [623.        53.      ]
#  [494.       107.      ]
#  [ 31.        49.      ]
#  [264.       190.      ]
#  [411.        44.      ]
#  [480.        32.      ]
#  [ 78.        67.      ]
#  [517.       110.      ]
#  [615.60004  141.6     ]
#  [118.8       50.4     ]
#  [564.       312.      ]
#  [414.00003  242.40001 ]
#  [644.4      189.6     ]
#  [535.2      111.600006]
#  [184.8      104.4     ]
#  [ 42.       140.40001 ]
#  [117.600006  60.000004]
#  [118.8       81.600006]
#  [640.80005   86.4     ]
#  [181.20001  132.      ]
#  [517.2      111.600006]
#  [530.4      110.4     ]
#  [410.40002   44.4     ]
#  [360.        49.2     ]
#  [112.8       60.000004]
#  [432.00003   91.200005]
#  [139.20001  111.600006]
#  [240.00002  152.40001 ]
#  [528.       110.4     ]
#  [118.8       62.4     ]
#  [ 39.600002 139.20001 ]
#  [130.8      200.40001 ]
#  [240.00002  154.8     ]
#  [ 76.8       66.      ]
#  [384.       157.20001 ]
#  [454.80002   37.2     ]
#  [446.40002  302.40002 ]
#  [448.80002   39.600002]
#  [139.20001   84.      ]
#  [478.80002  246.00002 ]
#  [417.6       43.2     ]
#  [238.8      194.40001 ]
#  [204.00002  208.8     ]
#  [128.40001  198.00002 ]
#  [264.       189.6     ]
#  [627.60004  116.4     ]
#  [362.40002   94.8     ]
#  [379.2      202.8     ]
#  [297.6      189.6     ]
#  [409.2      300.      ]
#  [265.2      198.00002 ]
#  [370.80002  298.80002 ]
#  [204.00002  198.00002 ]
#  [499.2      112.8     ]
#  [296.40002  238.8     ]
#  [487.2      306.      ]
#  [ 76.8       88.8     ]
#  [219.6      291.6     ]
#  [ 94.8      111.600006]
#  [204.00002  202.8     ]
#  [607.2       90.      ]
#  [451.2       80.4     ]
#  [297.6      295.2     ]
#  [ 87.600006 286.80002 ]
#  [417.6       91.200005]
#  [504.00003  247.20001 ]
#  [234.00002  159.6     ]
#  [404.40002  248.40001 ]
#  [333.6      294.      ]
#  [238.8       90.      ]
#  [410.40002   91.200005]
#  [618.        92.4     ]
#  [337.2      238.8     ]
#  [118.08      50.4     ]
#  [563.04004  311.04    ]
#  [616.32     113.76    ]
#  [622.08      54.72    ]
#  [131.04001  200.16    ]
#  [607.68005   89.28001 ]
#  [640.80005   86.4     ]
#  [ 76.32      66.240005]
#  [361.44      48.960003]
#  [321.12003  168.48001 ]
#  [516.96     112.32001 ]
#  [ 72.        64.8     ]
#  [413.28003  241.92001 ]
#  [640.80005   83.520004]
#  [521.28     306.72    ]
#  [ 87.840004  89.28001 ]
#  [486.72003  305.28    ]
#  [406.08002  253.44    ]
#  [299.52002  190.08    ]
#  [383.04     158.40001 ]
#  [614.88     141.12001 ]
#  [384.48     161.28    ]
#  [237.6      152.64    ]
#  [626.4      141.12001 ]
#  [430.56003   90.72    ]
#  [185.76001  105.12    ]
#  [118.08      60.480003]
#  [407.52002  250.56001 ]
#  [417.6       50.4     ]
#  [302.40002  198.72    ]
#  [296.64     295.2     ]
#  [233.28001  126.72    ]
#  [446.40002  302.40002 ]
#  [319.68002  181.44    ]
#  [404.64     247.68001 ]
#  [ 87.840004  77.76    ]
#  [112.32001   50.4     ]
#  [332.64     293.76    ]
#  [408.96002   44.640003]
#  [420.48      50.4     ]
#  [528.       110.4     ]
#  [118.8       62.4     ]
#  [ 39.600002 139.20001 ]
#  [130.8      200.40001 ]
#  [240.00002  154.8     ]
#  [ 76.8       66.      ]
#  [384.       157.20001 ]
#  [454.80002   37.2     ]
#  [446.40002  302.40002 ]
#  [448.80002   39.600002]
#  [139.20001   84.      ]
#  [478.80002  246.00002 ]
#  [417.6       43.2     ]
#  [238.8      194.40001 ]
#  [204.00002  208.8     ]
#  [128.40001  198.00002 ]
#  [264.       189.6     ]
#  [627.60004  116.4     ]
#  [362.40002   94.8     ]
#  [379.2      202.8     ]
#  [297.6      189.6     ]
#  [409.2      300.      ]
#  [265.2      198.00002 ]
#  [370.80002  298.80002 ]
#  [204.00002  198.00002 ]
#  [499.2      112.8     ]
#  [296.40002  238.8     ]
#  [487.2      306.      ]
#  [ 76.8       88.8     ]
#  [219.6      291.6     ]
#  [ 94.8      111.600006]
#  [204.00002  202.8     ]
#  [607.2       90.      ]
#  [451.2       80.4     ]
#  [297.6      295.2     ]
#  [ 87.600006 286.80002 ]
#  [417.6       91.200005]
#  [504.00003  247.20001 ]
#  [234.00002  159.6     ]
#  [404.40002  248.40001 ]
#  [333.6      294.      ]
#  [238.8       90.      ]
#  [410.40002   91.200005]
#  [618.        92.4     ]
#  [337.2      238.8     ]
#  [118.08      50.4     ]
#  [563.04004  311.04    ]
#  [616.32     113.76    ]
#  [622.08      54.72    ]
#  [131.04001  200.16    ]
#  [607.68005   89.28001 ]
#  [640.80005   86.4     ]
#  [ 76.32      66.240005]
#  [361.44      48.960003]
#  [321.12003  168.48001 ]
#  [516.96     112.32001 ]
#  [ 72.        64.8     ]
#  [413.28003  241.92001 ]
#  [640.80005   83.520004]
#  [521.28     306.72    ]
#  [ 87.840004  89.28001 ]
#  [486.72003  305.28    ]
#  [406.08002  253.44    ]
#  [299.52002  190.08    ]
#  [383.04     158.40001 ]
#  [614.88     141.12001 ]
#  [384.48     161.28    ]
#  [237.6      152.64    ]
#  [626.4      141.12001 ]
#  [430.56003   90.72    ]
#  [185.76001  105.12    ]
#  [118.08      60.480003]
#  [407.52002  250.56001 ]
#  [417.6       50.4     ]
#  [302.40002  198.72    ]
#  [296.64     295.2     ]
#  [233.28001  126.72    ]
#  [446.40002  302.40002 ]
#  [319.68002  181.44    ]
#  [404.64     247.68001 ]
#  [ 87.840004  77.76    ]
#  [112.32001   50.4     ]
#  [332.64     293.76    ]
#  [408.96002   44.640003]
#  [420.48      50.4     ]
#  [407.52002  299.52002 ]
#  [417.6       92.16    ]
#  [380.16     207.36002 ]
#  [112.32001   60.480003]
#  [410.40002   92.16    ]
#  [181.44     132.48001 ]
#  [108.00001  135.36    ]
#  [478.08002  246.24    ]
#  [250.56001  237.6     ]
#  [528.48004  110.880005]
#  [456.48     244.8     ]
#  [318.24002  178.56001 ]
#  [128.16     197.28001 ]
#  [138.24     112.32001 ]
#  [220.32     290.88    ]
#  [378.72     203.04001 ]
#  [383.04     241.92001 ]
#  [295.2      239.04001 ]
#  [421.02386  250.82272 ]
#  [391.164    250.82272 ]
#  [140.34128  113.46742 ]
#  [301.58447  194.08902 ]
#  [385.19205  158.2572  ]
#  [131.38333  197.075   ]
#  [471.78558  244.85075 ]
#  [346.37424  179.15909 ]
#  [238.87878  152.28522 ]
#  [373.2481   179.15909 ]
#  [615.11285  116.45341 ]
#  [627.0568   119.43939 ]
#  [337.4163   188.11703 ]
#  [149.29924  125.41136 ]
#  [316.5144   179.15909 ]
#  [409.07993   92.56553 ]
#  [244.85075  238.87878 ]
#  [301.58447  238.87878 ]
#  [280.68256  194.08902 ]
#  [616.30725  136.1609  ]
#  [139.7441   114.66182 ]
#  [426.39865  243.65637 ]
#  [243.65637  236.49    ]
#  [376.2341   179.15909 ]
#  [379.8173   240.07318 ]
#  [616.30725  114.66182 ]
#  [627.0568   118.245   ]
#  [340.40228  189.90865 ]
#  [157.66     125.41136 ]
#  [404.89954  236.49    ]
#  [329.65274  236.49    ]
#  [300.98727  193.49182 ]
#  [322.48636  236.49    ]
#  [290.23773  236.49    ]
#  [318.9032   189.90865 ]
#  [161.24318  114.66182 ]
#  [627.0568   136.1609  ]
#  [229.32364  157.66    ]
#  [132.57773  193.49182 ]
#  [136.1609   200.65819 ]
#  [347.56863  179.15909 ]
#  [462.23047  243.65637 ]
#  [247.23955  146.91046 ]
#  [419.23227  240.07318 ]
#  [236.49     150.49364 ]
#  [308.15363  236.49    ]
#  [329.65274  186.32545 ]
#  [261.57227  236.49    ]
#  [404.89954  179.15909 ]
#  [401.31638  218.5741  ]]
# =============================================================
# []
# []
# =============================================================
# []
# []
# =============================================================
# [[115.  67.]
#  [151.  87.]
#  [115.  78.]
#  [150.  89.]]
# [[535.      111.     ]
#  [335.23203 238.46402]
#  [250.56001 237.6    ]
#  [373.2481  179.15909]]
# =============================================================
# [[653.        47.      ]
#  [487.       100.      ]
#  [630.        51.      ]
#  [106.99779  116.951065]]
# [[139.  111. ]
#  [478.   38. ]
#  [511.  112. ]
#  [297.6 189.6]]
# =============================================================
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25144/3961398458.py in <module>
#     145
#     146 # 원근 변환 행렬 구하기 ---⑤
# --> 147 mtrx_m6, mask_m6 = cv2.findHomography(src_pts_m6, dst_pts_m6)
#     148 mtrx_m5, mask_m5 = cv2.findHomography(src_pts_m5, dst_pts_m5)
#     149 mtrx_m4, mask_m4 = cv2.findHomography(src_pts_m4, dst_pts_m4)
#
# error: OpenCV(4.5.3) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-1i5nllza\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'

# %%
#RANSAC 원근 변환 근사 계산으로 나쁜 매칭 제거
import cv2, numpy as np

img_m6 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk0.jpg')
img_m5 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk1.jpg')
img_m4 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk2.jpg')
img_m3 = cv2.imread('C:/Users/admin/Desktop/crosswalk1.jpg')
img_m2 = cv2.imread('C:/Users/admin/Desktop/crosswalk2.jpg')
img_m1 = cv2.imread('C:/Users/admin/Desktop/crosswalk3.jpg')
img_m0 = cv2.imread('C:/Users/admin/Desktop/crosswalk4.jpg')

img2 = cv2.imread('C:/Users/admin/Desktop/day_test.jpg')
img3 = cv2.imread('C:/Users/admin/Desktop/dark_crosswalk2.jpg')


gray_m6 = cv2.cvtColor(img_m6, cv2.COLOR_BGR2GRAY)
gray_m5 = cv2.cvtColor(img_m5, cv2.COLOR_BGR2GRAY)
gray_m4 = cv2.cvtColor(img_m4, cv2.COLOR_BGR2GRAY)
gray_m3 = cv2.cvtColor(img_m3, cv2.COLOR_BGR2GRAY)
gray_m2 = cv2.cvtColor(img_m2, cv2.COLOR_BGR2GRAY)
gray_m1 = cv2.cvtColor(img_m1, cv2.COLOR_BGR2GRAY)
gray_m0 = cv2.cvtColor(img_m0, cv2.COLOR_BGR2GRAY)

gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
gray3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)

# ORB, BF-Hamming 로 knnMatch  ---①
detector = cv2.ORB_create()
kp_m6, desc_m6 = detector.detectAndCompute(gray_m6, None)
kp_m5, desc_m5 = detector.detectAndCompute(gray_m5, None)
kp_m4, desc_m4 = detector.detectAndCompute(gray_m4, None)
kp_m3, desc_m3 = detector.detectAndCompute(gray_m3, None)
kp_m2, desc_m2 = detector.detectAndCompute(gray_m2, None)
kp_m1, desc_m1 = detector.detectAndCompute(gray_m1, None)
kp_m0, desc_m0 = detector.detectAndCompute(gray_m0, None)

kp2, desc2 = detector.detectAndCompute(gray2, None)
kp3, desc3 = detector.detectAndCompute(gray3, None)

matcher = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

matches_m6 = matcher.knnMatch(desc_m6, desc3, 2)
matches_m5 = matcher.knnMatch(desc_m5, desc3, 2)
matches_m4 = matcher.knnMatch(desc_m4, desc3, 2)
matches_m3 = matcher.knnMatch(desc_m3, desc3, 2)
matches_m2 = matcher.knnMatch(desc_m2, desc3, 2)
matches_m1 = matcher.knnMatch(desc_m1, desc3, 2)
matches_m0 = matcher.knnMatch(desc_m0, desc3, 2)

matches2 = matcher.knnMatch(desc2, desc3, 2)
matches3 = matcher.knnMatch(desc3, desc3, 2)

# 매칭 결과를 거리기준 오름차순으로 정렬 ---③
matches_m6 = sorted(matches_m6, key=lambda x:x.distance)
matches_m5 = sorted(matches_m5, key=lambda x:x.distance)
matches_m4 = sorted(matches_m4, key=lambda x:x.distance)
matches_m3 = sorted(matches_m3, key=lambda x:x.distance)
matches_m2 = sorted(matches_m2, key=lambda x:x.distance)
matches_m1 = sorted(matches_m1, key=lambda x:x.distance)
matches_m0 = sorted(matches_m0, key=lambda x:x.distance)

# 모든 매칭점 그리기 ---⑦
res_m6_all = cv2.drawMatches(img_m6, kp_m6, img3, kp3, good_matches_m6, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m5_all = cv2.drawMatches(img_m5, kp_m5, img3, kp3, good_matches_m5, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m4_all = cv2.drawMatches(img_m4, kp_m4, img3, kp3, good_matches_m4, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m3_all = cv2.drawMatches(img_m3, kp_m3, img3, kp3, good_matches_m3, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m2_all = cv2.drawMatches(img_m2, kp_m2, img3, kp3, good_matches_m2, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m1_all = cv2.drawMatches(img_m1, kp_m1, img3, kp3, good_matches_m1, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m0_all = cv2.drawMatches(img_m0, kp_m0, img3, kp3, good_matches_m0, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)

# 매칭점으로 원근 변환 및 영역 표시 ---⑤
src_pts_m6 = np.float32([ kp_m6[m.queryIdx].pt for m in matches_m6 ])
dst_pts_m6 = np.float32([ kp3[m.trainIdx].pt for m in matches_m6 ])

src_pts_m5 = np.float32([ kp3[m.queryIdx].pt for m in matches_m5])
dst_pts_m5 = np.float32([ kp3[m.trainIdx].pt for m in  matches_m5 ])

src_pts_m4 = np.float32([ kp3[m.queryIdx].pt for m in matches_m4 ])
dst_pts_m4 = np.float32([ kp3[m.trainIdx].pt for m in matches_m4 ])

src_pts_m3 = np.float32([ kp_m3[m.queryIdx].pt for m in matches_m3 ])
dst_pts_m3 = np.float32([ kp3[m.trainIdx].pt for m in matches_m3 ])

src_pts_m2 = np.float32([ kp_m3[m.queryIdx].pt for m in matches_m2 ])
dst_pts_m2 = np.float32([ kp3[m.trainIdx].pt for m in matches_m2 ])

src_pts_m1 = np.float32([ kp_m6[m.queryIdx].pt for m in matches_m1 ])
dst_pts_m1 = np.float32([ kp3[m.trainIdx].pt for m in matches_m1 ])

src_pts_m0 = np.float32([ kp_m0[m.queryIdx].pt for m in matches_m0 ])
dst_pts_m0 = np.float32([ kp3[m.trainIdx].pt for m in matches_m0 ])


# RANSAC으로 변환 행렬 근사 계산 ---⑥
mtrx_m6, mask_m6 = cv2.findHomography(src_pts_m6, dst_pts_m6, cv2.RANSAC, 5.0)
mtrx_m5, mask_m5 = cv2.findHomography(src_pts_m5, dst_pts_m5, cv2.RANSAC, 5.0)
mtrx_m4, mask_m4 = cv2.findHomography(src_pts_m4, dst_pts_m4, cv2.RANSAC, 5.0)
mtrx_m3, mask_m3 = cv2.findHomography(src_pts_m3, dst_pts_m3, cv2.RANSAC, 5.0)
mtrx_m2, mask_m2 = cv2.findHomography(src_pts_m2, dst_pts_m2, cv2.RANSAC, 5.0)
mtrx_m1, mask_m1 = cv2.findHomography(src_pts_m1, dst_pts_m1, cv2.RANSAC, 5.0)
mtrx_m0, mask_m0 = cv2.findHomography(src_pts_m0, dst_pts_m0, cv2.RANSAC, 5.0)

h_m6,w_m6, = img_m6.shape[:2]
h_m5,w_m5, = img_m5.shape[:2]
h_m4,w_m4, = img_m4.shape[:2]
h_m3,w_m3, = img_m3.shape[:2]
h_m2,w_m2, = img_m2.shape[:2]
h_m1,w_m1, = img_m1.shape[:2]
h_m0,w_m0, = img_m0.shape[:2]

pts_m6 = np.float32([ [[0,0]],[[0,h_m6-1]],[[w_m6-1,h_m6-1]],[[w_m6-1,0]] ])
pts_m5 = np.float32([ [[0,0]],[[0,h_m5-1]],[[w_m5-1,h_m6-1]],[[w_m5-1,0]] ])
pts_m4 = np.float32([ [[0,0]],[[0,h_m4-1]],[[w_m4-1,h_m6-1]],[[w_m4-1,0]] ])
pts_m3 = np.float32([ [[0,0]],[[0,h_m3-1]],[[w_m3-1,h_m6-1]],[[w_m3-1,0]] ])
pts_m2 = np.float32([ [[0,0]],[[0,h_m2-1]],[[w_m2-1,h_m6-1]],[[w_m2-1,0]] ])
pts_m1 = np.float32([ [[0,0]],[[0,h_m1-1]],[[w_m1-1,h_m6-1]],[[w_m1-1,0]] ])
pts_m0 = np.float32([ [[0,0]],[[0,h_m0-1]],[[w_m0-1,h_m6-1]],[[w_m0-1,0]] ])

dst_m6 = cv2.perspectiveTransform(pts_m6,mtrx_m6)
dst_m5 = cv2.perspectiveTransform(pts_m5,mtrx_m5)
dst_m4 = cv2.perspectiveTransform(pts_m4,mtrx_m4)
dst_m3 = cv2.perspectiveTransform(pts_m3,mtrx_m3)
dst_m2 = cv2.perspectiveTransform(pts_m2,mtrx_m2)
dst_m1 = cv2.perspectiveTransform(pts_m1,mtrx_m1)
dst_m0 = cv2.perspectiveTransform(pts_m0,mtrx_m0)

img3 = cv2.polylines(img3,[np.int32(dst)],True,255,3, cv2.LINE_AA)

# 정상치 매칭만 그리기 ---⑦
matchesMask = mask.ravel().tolist()

res_m6 = cv2.drawMatches(img_m6, kp_m6, img3, kp3, matches_m6, None, \
                    matchesMask = matchesMask,
                    flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m5 = cv2.drawMatches(img_m5, kp_m5, img3, kp3, matches_m5, None, \
                    matchesMask = matchesMask,
                    flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m4 = cv2.drawMatches(img_m4, kp_m4, img3, kp3, matches_m4, None, \
                    matchesMask = matchesMask,
                    flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m3 = cv2.drawMatches(img_m3, kp_m3, img3, kp3, matches_m3, None, \
                    matchesMask = matchesMask,
                    flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m2 = cv2.drawMatches(img_m2, kp_m2, img3, kp3, matches_m2, None, \
                    matchesMask = matchesMask,
                    flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m1 = cv2.drawMatches(img_m1, kp_m1, img3, kp3, matches_m1, None, \
                    matchesMask = matchesMask,
                    flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
res_m0 = cv2.drawMatches(img_m0, kp_m0, img3, kp3, matches_m0, None, \
                    matchesMask = matchesMask,
                    flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)

# 모든 매칭점과 정상치 비율 ---⑧
accuracy=float(mask.sum()) / mask.size
print("accuracy: %d/%d(%.2f%%)"% (mask.sum(), mask.size, accuracy))

# 결과 출력                    
cv2.imshow('Matching-All', res_m6_all)
cv2.imshow('Matching-All', res_m5_all)
cv2.imshow('Matching-All', res_m4_all)
cv2.imshow('Matching-All', res_m3_all)
cv2.imshow('Matching-All', res_m2_all)
cv2.imshow('Matching-All', res_m1_all)
cv2.imshow('Matching-All', res_m0_all)

cv2.imshow('Matching-Inlier ', res_m6)
cv2.imshow('Matching-Inlier ', res_m5)
cv2.imshow('Matching-Inlier ', res_m4)
cv2.imshow('Matching-Inlier ', res_m3)
cv2.imshow('Matching-Inlier ', res_m2)
cv2.imshow('Matching-Inlier ', res_m1)
cv2.imshow('Matching-Inlier ', res_m0)

cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1428/190389504.py in <module>
#      40 matcher = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
#      41
# ---> 42 matches_m6 = matcher.knnMatch(desc_m6, desc3, 2)
#      43 matches_m5 = matcher.knnMatch(desc_m5, desc3, 2)
#      44 matches_m4 = matcher.knnMatch(desc_m4, desc3, 2)
#
# error: OpenCV(4.5.3) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-1i5nllza\opencv\modules\core\src\batch_distance.cpp:303: error: (-215:Assertion failed) K == 1 && update == 0 && mask.empty() in function 'cv::batchDistance'

# %%
#매치 알고리즘을 전부 돌려본 결과 검출되는것이 없음

# %%
#객체 이동 방향 확인

# %%
import cv2, numpy as np

video_file='./img/walking.avi'
cap = cv2.VideoCapture(video_file)
if cap.isOpened():
    while True:
        ret, img = cap.read()
        if ret:
            cv2.imshow(video_file, img)
            cv2.waitKey(2)
            if cv2.waitKey(1) != -1: #아무키나 누르면
                cv2.imwrite('C:/Users/admin/Desktop/person1.jpg', img)
                break
        else:
            break
    
else:
    print('cant open video')
cap.release()
cv2.destroyAllWindows()

# %%
#select ROI로 관심영역 지정
import cv2,  numpy as np

img = cv2.imread('C:/Users/admin/Desktop/person1.jpg')
x,y,w,h = cv2.selectROI('img', img, False)
if w and h:
    roi = img[y:y+h, x:x+w]
    cv2.imshow('cropped', roi)
    cv2.moveWindow('cropped', 0, 0)
    cv2.imwrite('C:/Users/admin/Desktop/cropped_person.jpg', roi)
cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2, numpy as np

video_file='C:/Users/admin/Desktop/traffic.mp4'
cap = cv2.VideoCapture(video_file)
if cap.isOpened():
    while True:
        ret, img = cap.read()
        if ret:
            cv2.imshow(video_file, img)
            cv2.waitKey(2)
            if cv2.waitKey(1) != -1: #아무키나 누르면
                cv2.imwrite('C:/Users/admin/Desktop/traffic photo.jpg', img)
                break
        else:
            break
    
else:
    print('cant open video')
cap.release()
cv2.destroyAllWindows()

# %%
import cv2, numpy as np

img1 = cv2.imread('./img/taekwonv1.jpg')
img2 = cv2.imread('./img/figures2.jpg')
gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

# ORB, BF-Hamming 로 knnMatch  ---①
detector = cv2.ORB_create()
kp1, desc1 = detector.detectAndCompute(gray1, None)
kp2, desc2 = detector.detectAndCompute(gray2, None)
matcher = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
matches = matcher.match(desc1, desc2)

# 매칭 결과를 거리기준 오름차순으로 정렬 ---③
matches = sorted(matches, key=lambda x:x.distance)
# 모든 매칭점 그리기 ---④
res1 = cv2.drawMatches(img1, kp1, img2, kp2, matches, None, \
                    flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)

# 매칭점으로 원근 변환 및 영역 표시 ---⑤
src_pts = np.float32([ kp1[m.queryIdx].pt for m in matches ])
dst_pts = np.float32([ kp2[m.trainIdx].pt for m in matches ])
# RANSAC으로 변환 행렬 근사 계산 ---⑥
mtrx, mask = cv2.findHomography(src_pts, dst_pts, cv2.RANSAC, 5.0)
h,w = img1.shape[:2]
pts = np.float32([ [[0,0]],[[0,h-1]],[[w-1,h-1]],[[w-1,0]] ])
dst = cv2.perspectiveTransform(pts,mtrx)
img2 = cv2.polylines(img2,[np.int32(dst)],True,255,3, cv2.LINE_AA)

# 정상치 매칭만 그리기 ---⑦
matchesMask = mask.ravel().tolist()
res2 = cv2.drawMatches(img1, kp1, img2, kp2, matches, None, \
                    matchesMask = matchesMask,
                    flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
# 모든 매칭점과 정상치 비율 ---⑧
accuracy=float(mask.sum()) / mask.size
print("accuracy: %d/%d(%.2f%%)"% (mask.sum(), mask.size, accuracy))

# 결과 출력                    
cv2.imshow('Matching-All', res1)
cv2.imshow('Matching-Inlier ', res2)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# accuracy: 25/135(0.19%)

# %%
#

# %%
#원근변환 근사 계산으로 나쁜 매칭 제거
import cv2, numpy as np

video_file = './img/walking.avi'
img1 = cv2.imread('C:/Users/admin/Desktop/cropped_person.jpg')
gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
# ORB, BF-Hamming 로 knnMatch  ---①
detector = cv2.ORB_create()
kp1, desc1 = detector.detectAndCompute(gray1, None)
matcher = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

h,w = img1.shape[:2]
pts = np.float32([ [[0,0]],[[0,h-1]],[[w-1,h-1]],[[w-1,0]] ])

cap = cv2.VideoCapture(video_file)
if cap.isOpened():
    while True:
        ret, img = cap.read()
        if ret:
            cv2.imshow(video_file, img)

            #여기서 img2가 프레임이 될 것임
            #img2 = cv2.imread(img)
            img2=img
            gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

            kp2, desc2 = detector.detectAndCompute(gray2, None)
            matches = matcher.match(desc1, desc2)

            # 매칭 결과를 거리기준 오름차순으로 정렬 ---③
            matches = sorted(matches, key=lambda x:x.distance)
            
            # 모든 매칭점 그리기 ---④
            res1 = cv2.drawMatches(img1, kp1, img2, kp2, matches, None, \
                                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)

            dst_pts = np.float32([ kp2[m.trainIdx].pt for m in matches ])
            # 매칭점으로 원근 변환 및 영역 표시 ---⑤
            src_pts = np.float32([ kp1[m.queryIdx].pt for m in matches ])
            # RANSAC으로 변환 행렬 근사 계산 ---⑥
            mtrx, mask = cv2.findHomography(src_pts, dst_pts, cv2.RANSAC, 8.0)
            dst = cv2.perspectiveTransform(pts,mtrx)
            img2 = cv2.polylines(img2,[np.int32(dst)],True,255,3, cv2.LINE_AA)
            
            # 정상치 매칭만 그리기 ---⑦
            matchesMask = mask.ravel().tolist()
            
            res2 = cv2.drawMatches(img1, kp1, img2, kp2, matches, None, \
                                matchesMask = matchesMask,
                                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
            # 모든 매칭점과 정상치 비율 ---⑧
            accuracy=float(mask.sum()) / mask.size
            print("accuracy: %d/%d(%.2f%%)"% (mask.sum(), mask.size, accuracy))

            # 결과 출력                    
            cv2.imshow('Matching-All', res1)
            cv2.imshow('Matching-Inlier ', res2)

            cv2.waitKey(2)
            if cv2.waitKey(1) != -1: #아무키나 누르면
                cv2.imwrite('C:/Users/admin/Desktop/traffic photo.jpg', img)
                break
        else:
            break
            
else:
    print('cant open video')
    
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
0.36%)
# accuracy: 5/11(0.45%)
# accuracy: 5/12(0.42%)
# accuracy: 5/13(0.38%)
# accuracy: 4/14(0.29%)
# accuracy: 5/12(0.42%)
# accuracy: 6/9(0.67%)
# accuracy: 5/15(0.33%)
# accuracy: 6/17(0.35%)
# accuracy: 4/11(0.36%)
# accuracy: 5/10(0.50%)
# accuracy: 4/13(0.31%)
# accuracy: 5/11(0.45%)
# accuracy: 4/11(0.36%)
# accuracy: 4/8(0.50%)
# accuracy: 5/10(0.50%)
# accuracy: 5/12(0.42%)
# accuracy: 4/10(0.40%)
# accuracy: 5/8(0.62%)
# accuracy: 5/13(0.38%)
# accuracy: 5/10(0.50%)
# accuracy: 5/12(0.42%)
# accuracy: 4/10(0.40%)
# accuracy: 5/13(0.38%)
# accuracy: 5/9(0.56%)
# accuracy: 6/10(0.60%)
# accuracy: 6/11(0.55%)
# accuracy: 6/11(0.55%)
# accuracy: 5/10(0.50%)
# accuracy: 4/10(0.40%)
# accuracy: 5/10(0.50%)
# accuracy: 5/14(0.36%)
# accuracy: 5/10(0.50%)
# accuracy: 5/14(0.36%)
# accuracy: 4/7(0.57%)
# accuracy: 6/13(0.46%)
# accuracy: 4/7(0.57%)
# accuracy: 5/13(0.38%)
# accuracy: 5/12(0.42%)
# accuracy: 5/12(0.42%)
# accuracy: 5/10(0.50%)
# accuracy: 5/11(0.45%)
# accuracy: 6/12(0.50%)
# accuracy: 6/14(0.43%)
# accuracy: 6/12(0.50%)
# accuracy: 5/13(0.38%)
# accuracy: 6/14(0.43%)
# accuracy: 5/12(0.42%)
# accuracy: 5/8(0.62%)
# accuracy: 6/11(0.55%)
# accuracy: 6/14(0.43%)
# accuracy: 6/12(0.50%)
# accuracy: 4/11(0.36%)
# accuracy: 5/14(0.36%)
# accuracy: 4/9(0.44%)
# accuracy: 6/13(0.46%)
# accuracy: 7/12(0.58%)
# accuracy: 5/13(0.38%)
# accuracy: 6/15(0.40%)
# accuracy: 6/15(0.40%)
# accuracy: 5/12(0.42%)
# accuracy: 4/11(0.36%)
# accuracy: 5/12(0.42%)
# accuracy: 5/14(0.36%)
# accuracy: 4/11(0.36%)
# accuracy: 5/11(0.45%)
# accuracy: 5/12(0.42%)

# %%
#hog!!!
import cv2

# default 디덱터를 위한 HOG 객체 생성 및 설정--- ①
hogdef = cv2.HOGDescriptor()
hogdef.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())

# dailer 디덱터를 위한 HOG 객체 생성 및 설정--- ②
hogdaim  = cv2.HOGDescriptor((48,96), (16,16), (8,8), (8,8), 9)
hogdaim.setSVMDetector(cv2.HOGDescriptor_getDaimlerPeopleDetector())

cap = cv2.VideoCapture('./img/walking.avi')
mode = True  # 모드 변환을 위한 플래그 변수 
print('Toggle Space-bar to change mode.')
now_x=-1
now_y=-1
now_w=-1
now_y=-1
now_x_w, now_y_h=-1,-1
while cap.isOpened():
    ret, img = cap.read()
    if ret :
        #
        if mode:
            # default 디텍터로 보행자 검출 --- ③
            found, _ = hogdef.detectMultiScale(img)
            for (x,y,w,h) in found:
                cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,255))
        else:
            # daimler 디텍터로 보행자 검출 --- ④
            found, _ = hogdaim.detectMultiScale(img)
            print(found)
            for (x,y,w,h) in found:
                cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0))
                """
                사람 특정하는 법을 모르겠음
                
                if x < now_x:
                    print('왼쪽으로 이동중')
                    now_x=x
                elif x > now_x:
                    print('오른쪽으로 이동중')
                    now_x=x
                elif w < now_w:
                    print('멀리 떨어지는 중')
                    now_w = w 
                elif w > now_w:
                    print('가까이 오는중')
                    now_w = w
                elif now_x = x and now_y=y:
                    print('멈춰있음')
                """
        cv2.putText(img, 'Detector:%s'%('Default' if mode else 'Daimler'), \
                        (10,50 ), cv2.FONT_HERSHEY_DUPLEX,1, (0,255,0),1)
        cv2.imshow('frame', img)
        key = cv2.waitKey(1) 
        if key == 27:
            break
        elif key == ord(' '):
            mode = not mode
    else:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# Toggle Space-bar to change mode.

# %%
#횡단보도 객체확인
"""
횡단보도 검출
351p 카메라로 객체매칭하는 것만 검출
"""

#match함수로부터 좋은 매칭점 찾기 

import cv2, numpy as np

img1 = cv2.imread('C:/Users/admin/Desktop/crosswalk4.jpg')
#배율 지정으로 확대 2배 상관없음
#img1 = cv2.resize(img1, None, None, 4, 4, cv2.INTER_CUBIC)

img2 = cv2.imread('C:/Users/admin/Desktop/day_test.jpg')

#비교대상
gray1 =  cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
gray2 =  cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

#SHIFT 디스크립터 추출기 생성
detector = cv2.ORB_create()

#각 영상에 대해 키 포인트와 디스크립터 추출

kp1, desc1 = detector.detectAndCompute(gray1,None)
print('kp1', kp1)
kp2, desc2 = detector.detectAndCompute(gray2, None)
print('kp2', kp2)
#DF_HAMMING으로 매칭
matcher = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
matches = matcher.match(desc1, desc2)

#매칭 결과를 거리 기준 오름차순으로 정렬
matches = sorted(matches, key=lambda x:x.distance)

#print('desc1:',desc1, 'desc2:',desc2)
#print(matcher)
#print()

#최소거리값과 최대 거리값 확보
min_dist, max_dist = matches[0].distance, matches[-1].distance

#최소 거리의 20%지점을 임계점으로 설정
ratio=0.2
good_thresh = (max_dist - min_dist) * ratio + min_dist
#임계점보다 작은 매칭점만 좋은 매칭점으로 분류
good_matches = [m for m in matches if m.distance < good_thresh]
print('matches:%d/%d, min:%.2f, max:%.2f, thresh:%.2f'%(len(good_matches),len(matches), min_dist, max_dist, good_thresh))
#좋은 매칭점만 그리기
res = cv2.drawMatches(img1, kp1, img2, kp2, good_matches, None, flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
#결과 출력
cv2.imshow('good Match', res)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# kp1 [<KeyPoint 0000024438453270>, <KeyPoint 0000024438453EA0>, <KeyPoint 0000024438453180>, <KeyPoint 0000024438453FC0>, <KeyPoint 0000024438453150>, <KeyPoint 0000024438453ED0>, <KeyPoint 0000024438453DE0>, <KeyPoint 0000024438453F90>, <KeyPoint 0000024438453E70>, <KeyPoint 00000244384531E0>, <KeyPoint 0000024438453210>, <KeyPoint 0000024438453240>, <KeyPoint 00000244384531B0>, <KeyPoint 0000024438453120>, <KeyPoint 00000244384530F0>, <KeyPoint 00000244384530C0>, <KeyPoint 0000024438453090>, <KeyPoint 0000024438453060>, <KeyPoint 0000024438453030>, <KeyPoint 0000024438453A20>, <KeyPoint 0000024438453C90>, <KeyPoint 0000024438453DB0>, <KeyPoint 000002443844D1E0>, <KeyPoint 000002443844DEA0>, <KeyPoint 000002443844DE70>, <KeyPoint 000002443844DE40>, <KeyPoint 000002443844DE10>, <KeyPoint 000002443844DDE0>, <KeyPoint 000002443844DDB0>, <KeyPoint 000002443844DD80>, <KeyPoint 000002443844DD50>, <KeyPoint 000002443844DD20>, <KeyPoint 000002443844DCF0>, <KeyPoint 000002443844DCC0>, <KeyPoint 000002443844DC90>, <KeyPoint 000002443844DC60>, <KeyPoint 000002443844DC30>, <Key
000244312DE060>, <KeyPoint 00000244312DE090>, <KeyPoint 00000244312DE0C0>, <KeyPoint 00000244312DEA50>, <KeyPoint 00000244312DEA80>, <KeyPoint 00000244312DEA20>, <KeyPoint 00000244312DE990>, <KeyPoint 00000244312DE930>, <KeyPoint 00000244312DE7E0>, <KeyPoint 00000244312DEBA0>, <KeyPoint 00000244312DEB10>, <KeyPoint 000002442F32A780>, <KeyPoint 000002442F32A540>, <KeyPoint 000002442F32A030>, <KeyPoint 000002442F32A930>, <KeyPoint 000002442F32AC90>, <KeyPoint 000002442F32AC60>, <KeyPoint 000002442F32AC30>, <KeyPoint 000002442F32AC00>, <KeyPoint 000002442F32ABD0>, <KeyPoint 000002442F32ABA0>, <KeyPoint 000002442F32AB70>, <KeyPoint 000002442F32AB40>, <KeyPoint 000002442F32A5A0>, <KeyPoint 000002442F32A570>, <KeyPoint 000002442F32A5D0>, <KeyPoint 000002442F32A2A0>, <KeyPoint 000002442F32A360>, <KeyPoint 000002442F32A6F0>, <KeyPoint 000002442F32A7B0>, <KeyPoint 000002442F32A7E0>, <KeyPoint 000002442F32A810>, <KeyPoint 000002442F32A840>, <KeyPoint 000002442F32A870>, <KeyPoint 000002442F32A8A0>, <KeyPoint 000002442F32A8D0>, <KeyPoint 000002442F32A900>, <KeyPoint 000002442F32A960>, <KeyPoint 000002442F32A3F0>, <KeyPoint 000002442F32A450>, <KeyPoint 000002442F32A750>, <KeyPoint 000002442F32A330>, <KeyPoint 000002442F32A180>, <KeyPoint 000002442F32A690>, <KeyPoint 000002442F32A600>, <KeyPoint 000002442F32A4E0>, <KeyPoint 000002442F32A390>, <KeyPoint 000002442F32A480>, <KeyPoint 000002442F32A1B0>, <KeyPoint 000002442F32A720>, <KeyPoint 000002442F32AD80>, <KeyPoint 000002442F32A0C0>, <KeyPoint 000002442F32A6C0>, <KeyPoint 000002442F32AA50>, <KeyPoint 000002442F32AA80>, <KeyPoint 000002442F32AAB0>, <KeyPoint 000002442F32AAE0>, <KeyPoint 000002442F32AB10>, <KeyPoint 000002442F32A990>, <KeyPoint 000002442F32A9C0>, <KeyPoint 000002442F32A9F0>, <KeyPoint 000002442F32 ...
# matches:5/142, min:41.00, max:86.00, thresh:50.00

# %%
#횡단보도 객체확인
"""
횡단보도 검출
351p 카메라로 객체매칭하는 것만 검출
"""

#match함수로부터 좋은 매칭점 찾기 

import cv2, numpy as np

img1 = cv2.imread('C:/Users/admin/Desktop/cropped2.jpg')
#img1 = cv2.imread('./img/taekwonv1.jpg')
#print(img1.shape)
cv2.imshow('img1',img1)
img2 = cv2.imread('C:/Users/admin/Desktop/close_cross.jpg')
#img2 = cv2.imread('./img/figures.jpg')
#print(img2.shape)
cv2.imshow('img2',img2)

#배율 지정으로 확대 2배 상관없음
img1 = cv2.resize(img1, None, None, 4, 4, cv2.INTER_CUBIC)

#비교대상
gray1 =  cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
#print('gray1', gray1)
gray2 =  cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

#SHIFT 디스크립터 추출기 생성
detector = cv2.ORB_create()
#print('detector',detector)
"""
keypoints, descriptors = detector.detectAndCompute(image, mask, decriptors, useProvidedKeypoints): 특징점 검출과 특징 디스크립터 계산을 한 번에 수행
image: 입력 이미지
keypoints: 디스크립터 계산을 위해 사용할 특징점
descriptors(optional): 계산된 디스크립터
mask(optional): 특징점 검출에 사용할 마스크
useProvidedKeypoints(optional): True인 경우 특징점 검출을 수행하지 않음
"""    
#각 영상에 대해 키 포인트와 디스크립터 추출

kp1, desc1 = detector.detectAndCompute(gray1,None)
print('kp1', kp1)
kp2, desc2 = detector.detectAndCompute(gray2, None)
print('kp2', kp2)
#DF_HAMMING으로 매칭
matcher = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
matches = matcher.match(desc1, desc2)

#매칭 결과를 거리 기준 오름차순으로 정렬
matches = sorted(matches, key=lambda x:x.distance)

#print('desc1:',desc1, 'desc2:',desc2)
#print(matcher)
#print()

#최소거리값과 최대 거리값 확보
min_dist, max_dist = matches[0].distance, matches[-1].distance

#최소 거리의 20%지점을 임계점으로 설정
ratio=0.2
good_thresh = (max_dist - min_dist) * ratio + min_dist
#임계점보다 작은 매칭점만 좋은 매칭점으로 분류
good_matches = [m for m in matches if m.distance < good_thresh]
print('matches:%d/%d, min:%.2f, max:%.2f, thresh:%.2f'%(len(good_matches),len(matches), min_dist, max_dist, good_thresh))
#좋은 매칭점만 그리기
res = cv2.drawMatches(img1, kp1, img2, kp2, good_matches, None, flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
#결과 출력
cv2.imshow('good Match', res)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# kp1 []
# kp2 [<KeyPoint 000001FD2CCCF120>, <KeyPoint 000001FD4D576FC0>, <KeyPoint 000001FD4D576F90>, <KeyPoint 000001FD2CC3B360>, <KeyPoint 000001FD2CC3B4E0>, <KeyPoint 000001FD4D269330>, <KeyPoint 000001FD4D2697E0>, <KeyPoint 000001FD4D269480>, <KeyPoint 000001FD4D269570>, <KeyPoint 000001FD4D2694E0>, <KeyPoint 000001FD4D2695A0>, <KeyPoint 000001FD4D2695D0>, <KeyPoint 000001FD4D269240>, <KeyPoint 000001FD4D269210>, <KeyPoint 000001FD4D2691E0>, <KeyPoint 000001FD4D2691B0>, <KeyPoint 000001FD4D269A20>, <KeyPoint 000001FD4D269AE0>, <KeyPoint 000001FD4D269C60>, <KeyPoint 000001FD4D269C30>, <KeyPoint 000001FD4D269C00>, <KeyPoint 000001FD4D269B40>, <KeyPoint 000001FD4D269B10>, <KeyPoint 000001FD4D269810>, <KeyPoint 000001FD4D269840>, <KeyPoint 000001FD4D269BD0>, <KeyPoint 000001FD4D269D80>, <KeyPoint 000001FD4D269F00>, <KeyPoint 000001FD4D269E70>, <KeyPoint 000001FD4D2696F0>, <KeyPoint 000001FD4D2696C0>, <KeyPoint 000001FD4D269690>, <KeyPoint 000001FD4D2690C0>, <KeyPoint 000001FD4D269120>, <KeyPoint 000001FD4D269150>, <KeyPoint 000001FD4D269780>, <KeyPoint 000001FD4D2697B0>, <KeyPoint 000001FD4D2692D0>, <KeyPoint 000001FD4D2692A0>, <KeyPoint 000001FD4D269360>, <KeyPoint 000001FD4D269450>, <KeyPoint 000001FD4D269600>, <KeyPoint 000001FD4D269540>, <KeyPoint 000001FD4D2694B0>, <KeyPoint 000001FD4D269510>, <KeyPoint 000001FD4D269DB0>, <KeyPoint 000001FD4D269B70>, <KeyPoint 000001FD4D269BA0>, <KeyPoint 000001FD4D269DE0>, <KeyPoint 000001FD4D269E40>, <KeyPoint 000001FD4D269C90>, <KeyPoint 000001FD4D269FC0>, <KeyPoint 000001FD4D269F90>, <KeyPoint 000001FD4D269F60>, <KeyPoint 000001FD4D269CF0>, <KeyPoint 000001FD4D269D20>, <KeyPoint 000001FD4D269CC0>, <KeyPoint 000001FD4D269D50>, <KeyPoint 000001FD4D269F30>, <KeyPoint 000001FD4D269ED0>, <KeyPoint 000001FD4D269EA0>, <KeyPoint 000001FD4D269390>, <KeyPoint 000001FD4D2693C0>, <KeyPoint 000001FD4D2693F0>, <KeyPoint 000001FD4D269420>, <KeyPoint 000001FD4D269A50>, <KeyPoint 000001FD4D269660>, <KeyPoint 000001FD2CD26990>, <KeyPoint 000001FD2CD260C0>, <KeyPoint 000001FD2CD26690>, <KeyPoint 000001FD2CD265A0>, <KeyPoint 000001FD2CD26A20>, <KeyPoint 000001FD2CD26BA0>, <KeyPoint 000001FD2CD26D50>, <KeyPoint 000001FD2CD26B70>, <KeyPoint 000001FD2CD26810>, <KeyPoint 000001FD2CD26630>, <KeyPoint 000001FD2CD26240>, <KeyPoint 000001FD2CD262A0>, <KeyPoint 000001FD2CD26C00>, <KeyPoint 000001FD2CD26330>, <KeyPoint 000001FD2CD26960>, <KeyPoint 000001FD2CD26750>, <KeyPoint 000001FD2CD26E40>, <KeyPoint 000001FD2CD26840>, <KeyPoint 000001FD2CD26180>, <KeyPoint 000001FD2CD26480>, <KeyPoint 000001FD2CD264B0>, <KeyPoint 000001FD2CD263F0>, <KeyPoint 000001FD2CD26060>, <KeyPoint 000001FD2CD261B0>, <KeyPoint 000001FD2CD260F0>, <KeyPoint 000001FD2CD268D0>, <KeyPoint 000001FD2CD26900>, <KeyPoint 000001FD2CD26CF0>, <KeyPoint 000001FD2CD26DE0>, <KeyPoint 000001FD2CD26090>, <KeyPoint 000001FD2CD26120>, <KeyPoint 000001FD2CD26CC0>, <KeyPoint 000001FD2CD26D20>, <KeyPoint 000001FD2CD0AA50>, <KeyPoint 000001FD2CD0ABA0>, <KeyPoint 000001FD2CD0AB70>, <KeyPoint 000001FD2CD0A510>, <KeyPoint 000001FD2CD0A090>, <KeyPoint 000001FD2CD0A0C0>, <KeyPoint 000001FD2CD0A2D0>, <KeyPoint 000001FD2CD0A900>, <KeyPoint 000001FD2CD0A7B0>, <KeyPoint 000001FD2CD0A7E0>, <KeyPoint 000001FD2CD0A3C0>, <KeyPoint 000001FD2CD0A450>, <KeyPoint 000001FD2CD0ABD0>, <KeyPoint 000001FD2CD0A150>, <KeyPoint 000001FD2CD0A4E0>, <KeyPoint 000001FD2CD0A870>, <KeyPoint 000001FD2CD0A2A0>, <KeyPoint 000001FD2CD0AA20>, <KeyPoint 000001FD2CD0A660>, <KeyPoint 000001FD2CD0A030>, <KeyPoint 000001FD2CD0AF60>, <KeyPoint 000001FD2CD0A780>, <KeyPoint 000001FD2CD0A600>, <KeyPoint 000001FD2CD0A570>, <KeyPoint 000001FD2CD0A5D0>, <KeyPoint 000001FD2CD0A300>, <KeyPoint 000001FD2CD0A180>, <KeyPoint 000001FD2CD0A990>, <KeyPoint 000001FD2CD0A9F0>, <KeyPoint 000001FD2CD0A750>, <KeyPoint 000001FD2CD0AC30>, <KeyPoint 000001FD2CD0AD20>, <KeyPoint 000001FD2CD0AF90>, <KeyPoint 000001FD2CD0A420>, <KeyPoint 000001FD2CD0A8D0>, <KeyPoint 000001FD2CD0A540>, <KeyPoint 000001FD2CD0ACC0>, <KeyPoint 000001FD2CD0 ...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13728/3309935442.py in <module>
#      55
#      56 #최소거리값과 최대 거리값 확보
# ---> 57 min_dist, max_dist = matches[0].distance, matches[-1].distance
#      58
#      59 #최소 거리의 20%지점을 임계점으로 설정
#
# IndexError: list index out of range

# %%
while cap.isOpened():
    ret, img = cap.read()
    fps = cap.get(cv2.CAP_PROP_FPS)#프레임 수 구하기
    delay = int(100/fps)

# %%
#hog svm
import imutils
import cv2

# default 디덱터를 위한 HOG 객체 생성 및 설정--- ①
hogdef = cv2.HOGDescriptor()
hogdef.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())

# dailer 디덱터를 위한 HOG 객체 생성 및 설정--- ②
hogdaim  = cv2.HOGDescriptor((48,96), (16,16), (8,8), (8,8), 9)
hogdaim.setSVMDetector(cv2.HOGDescriptor_getDaimlerPeopleDetector())

cap = cv2.VideoCapture('C:/Users/admin/Downloads/accident.mp4')
mode = True  # 모드 변환을 위한 플래그 변수 
print('Toggle Space-bar to change mode.')
while cap.isOpened():
    ret, img = cap.read()
    fps = cap.get(cv2.CAP_PROP_FPS)#프레임 수 구하기
    delay = int(100000/fps)
    if ret :
        if mode:
            # default 디텍터로 보행자 검출 --- ③
            img = imutils.resize(img, width=500)
            found, _ = hogdef.detectMultiScale(img)
            for (x,y,w,h) in found:
                cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,255))
        else:
            # daimler 디텍터로 보행자 검출 --- ④
            found, _ = hogdaim.detectMultiScale(img)
            for (x,y,w,h) in found:
                cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0))
        cv2.putText(img, 'Detector:%s'%('Default' if mode else 'Daimler'), \
                        (10,50 ), cv2.FONT_HERSHEY_DUPLEX,1, (0,255,0),1)
        cv2.imshow('frame', img)
        key = cv2.waitKey(1) 
        if key == 27:
            break
        elif key == ord(' '):
            mode = not mode
    else:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# Toggle Space-bar to change mode.

# %%
import cv2, numpy as np

# 플로우 결과 그리기 ---①
def drawFlow(img,flow,step=16):
  h,w = img.shape[:2]
  # 16픽셀 간격의 그리드 인덱스 구하기 ---②
  idx_y,idx_x = np.mgrid[step/2:h:step,step/2:w:step].astype(np.int)
  indices =  np.stack( (idx_x,idx_y), axis =-1).reshape(-1,2)
  
  for x,y in indices:   # 인덱스 순회
    # 각 그리드 인덱스 위치에 점 그리기 ---③
    cv2.circle(img, (x,y), 1, (0,255,0), -1)
    # 각 그리드 인덱스에 해당하는 플로우 결과 값 (이동 거리)  ---④
    dx,dy = flow[y, x].astype(np.int)
    # 각 그리드 인덱스 위치에서 이동한 거리 만큼 선 그리기 ---⑤
    cv2.line(img, (x,y), (x+dx, y+dy), (0,255, 0),2, cv2.LINE_AA )


prev = None # 이전 프레임 저장 변수

cap = cv2.VideoCapture('C:/Users/admin/Downloads/무단횡단_밤_검출 아예못함.mp4')
fps = cap.get(cv2.CAP_PROP_FPS) # 프레임 수 구하기
delay = int(1000/fps)

while cap.isOpened():
  ret,frame = cap.read()
  if not ret: break
  gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
  # 최초 프레임 경우 
  if prev is None: 
    prev = gray # 첫 이전 프레임 --- ⑥
  else:
    # 이전, 이후 프레임으로 옵티컬 플로우 계산 ---⑦
    flow = cv2.calcOpticalFlowFarneback(prev,gray,None,\
                0.5,3,15,3,5,1.1,cv2.OPTFLOW_FARNEBACK_GAUSSIAN) 
    # 계산 결과 그리기, 선언한 함수 호출 ---⑧
    drawFlow(frame,flow)
    # 다음 프레임을 위해 이월 ---⑨
    prev = gray
  
  cv2.imshow('OpticalFlow-Farneback', frame)
  if cv2.waitKey(delay) == 27:
      break
cap.release()
cv2.destroyAllWindows()

# %%
# 8-26 calcOpticalFlowPyrLK추적(track_opticalLK.py)
#움직이는 모든것들에 대해 검출
import numpy as np, cv2
cap = cv2.VideoCapture('C:/Users/admin/Downloads/cropped_traffic2.mp4')
fps = cap.get(cv2.CAP_PROP_FPS) # 프레임 수 구하기
delay = int(1000/fps)
# 추적 경로를 그리기 위한 랜덤 색상
color = np.random.randint(0,255,(200,3))
lines = None  #추적 선을 그릴 이미지 저장 변수
prevImg = None  # 이전 프레임 저장 변수
# calcOpticalFlowPyrLK 중지 요건 설정
termcriteria =  (cv2.TERM_CRITERIA_EPS | cv2.TERM_CRITERIA_COUNT, 10, 0.03)
while cap.isOpened():
    ret,frame = cap.read()
    if not ret:
        break
    img_draw = frame.copy()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # 최초 프레임 경우
    if prevImg is None:
        prevImg = gray
        # 추적선 그릴 이미지를 프레임 크기에 맞게 생성
        lines = np.zeros_like(frame)
        # 추적 시작을 위한 코너 검출  ---①
        prevPt = cv2.goodFeaturesToTrack(prevImg, 200, 0.01, 10)
    else:
        nextImg = gray
        # 옵티컬 플로우로 다음 프레임의 코너점  찾기 ---②
        nextPt, status, err = cv2.calcOpticalFlowPyrLK(prevImg, nextImg, \
                                        prevPt, None, criteria=termcriteria)
        # 대응점이 있는 코너, 움직인 코너 선별 ---③
        prevMv = prevPt[status==1]
        nextMv = nextPt[status==1]
        for i,(p, n) in enumerate(zip(prevMv, nextMv)):
            px,py = p.ravel()
            nx,ny = n.ravel()
            # 이전 코너와 새로운 코너에 선그리기 ---④
            cv2.line(lines, (int(px), int(py)), (int(nx),int(ny)), color[i].tolist(), 2)
            # 새로운 코너에 점 그리기
            cv2.circle(img_draw, (int(nx),int(ny)), 2, color[i].tolist(), -1)
        # 누적된 추적 선을 출력 이미지에 합성 ---⑤
        img_draw = cv2.add(img_draw, lines)
        # 다음 프레임을 위한 프레임과 코너점 이월
        prevImg = nextImg
        prevPt = nextMv.reshape(-1,1,2)
    cv2.imshow('OpticalFlow-LK', img_draw)
    key = cv2.waitKey(delay)
    if key == 27 : # Esc:종료
        break
    elif key == 8: # Backspace:추적 이력 지우기
        prevImg = None
cv2.destroyAllWindows()
cap.release()

# %%
#hog svm
import imutils
import cv2

# default 디덱터를 위한 HOG 객체 생성 및 설정--- ①
hogdef = cv2.HOGDescriptor()
hogdef.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())

# dailer 디덱터를 위한 HOG 객체 생성 및 설정--- ②
hogdaim  = cv2.HOGDescriptor((48,96), (16,16), (8,8), (8,8), 9)
hogdaim.setSVMDetector(cv2.HOGDescriptor_getDaimlerPeopleDetector())

cap = cv2.VideoCapture('C:/Users/admin/Downloads/accident .mp4')
mode = True  # 모드 변환을 위한 플래그 변수 
print('Toggle Space-bar to change mode.')
while cap.isOpened():
    ret, img = cap.read()
    if ret :
        if mode:
            # default 디텍터로 보행자 검출 --- ③
            img = imutils.resize(img, width=500)
            found, _ = hogdef.detectMultiScale(img)
            for (x,y,w,h) in found:
                cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,255))
        else:
            # daimler 디텍터로 보행자 검출 --- ④
            found, _ = hogdaim.detectMultiScale(img)
            for (x,y,w,h) in found:
                cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0))
        cv2.putText(img, 'Detector:%s'%('Default' if mode else 'Daimler'), \
                        (10,50 ), cv2.FONT_HERSHEY_DUPLEX,1, (0,255,0),1)
        cv2.imshow('frame', img)
        key = cv2.waitKey(1) 
        if key == 27:
            break
        elif key == ord(' '):
            mode = not mode
    else:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# Toggle Space-bar to change mode.

# %%
import cv2, numpy as np

img1 = cv2.imread('C:/Users/admin/Desktop/crosswalk3.jpg')
img2 = cv2.imread('C:/Users/admin/Desktop/close_cross.jpg')
gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

# ORB, BF-Hamming 로 knnMatch  ---①
detector = cv2.ORB_create()
kp1, desc1 = detector.detectAndCompute(gray1, None)
kp2, desc2 = detector.detectAndCompute(gray2, None)
matcher = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
matches = matcher.match(desc1, desc2)

# 매칭 결과를 거리기준 오름차순으로 정렬 ---③
matches = sorted(matches, key=lambda x:x.distance)
# 모든 매칭점 그리기 ---④
res1 = cv2.drawMatches(img1, kp1, img2, kp2, matches, None, \
                    flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)

# 매칭점으로 원근 변환 및 영역 표시 ---⑤
src_pts = np.float32([ kp1[m.queryIdx].pt for m in matches ])
dst_pts = np.float32([ kp2[m.trainIdx].pt for m in matches ])
# RANSAC으로 변환 행렬 근사 계산 ---⑥
mtrx, mask = cv2.findHomography(src_pts, dst_pts, cv2.RANSAC, 5.0)
h,w = img1.shape[:2]
pts = np.float32([ [[0,0]],[[0,h-1]],[[w-1,h-1]],[[w-1,0]] ])
dst = cv2.perspectiveTransform(pts,mtrx)
img2 = cv2.polylines(img2,[np.int32(dst)],True,255,3, cv2.LINE_AA)

# 정상치 매칭만 그리기 ---⑦
matchesMask = mask.ravel().tolist()
res2 = cv2.drawMatches(img1, kp1, img2, kp2, matches, None, \
                    matchesMask = matchesMask,
                    flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
# 모든 매칭점과 정상치 비율 ---⑧
accuracy=float(mask.sum()) / mask.size
print("accuracy: %d/%d(%.2f%%)"% (mask.sum(), mask.size, accuracy))

# 결과 출력                    
cv2.imshow('Matching-All', res1)
cv2.imshow('Matching-Inlier ', res2)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# accuracy: 9/90(0.10%)

# %%
#링크https://deep-learning-study.tistory.com/274?category=946336

# %%
#Mog 사용하기엔 무리가 있어보임
# 비디오 파일 열기
cap = cv2.VideoCapture('C:/Users/admin/Downloads/movies/jaywalk2.mp4')

if not cap.isOpened():
    print('Video open failed!')
    sys.exit()

# 배경 차분 알고리즘 객체 생성
bs = cv2.createBackgroundSubtractorMOG2()
#bs = cv2.createBackgroundSubtractorKNN() # 배경영상이 업데이트 되는 형태가 다름
#bs.setDetectShadows(False) # 그림자 검출 안하면 0과 255로 구성된 마스크 출력

# 비디오 매 프레임 처리
while True:
    ret, frame = cap.read()

    if not ret:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # 0또는 128또는 255로 구성된 fgmask 생성
    fgmask = bs.apply(gray)
    # 배경 영상 받아오기
    back = bs.getBackgroundImage()

    # 레이블링을 이용하여 바운딩 박스 표시
    cnt, _, stats, _ = cv2.connectedComponentsWithStats(fgmask)

    for i in range(1, cnt):
        x, y, w, h, s = stats[i]

        if s < 80:
            continue

        cv2.rectangle(frame, (x, y), (w, h), (0, 0, 255), 2)

    cv2.imshow('frame', frame)
    cv2.imshow('back', back)
    cv2.imshow('fgmask', fgmask)

    if cv2.waitKey(20) == 27:
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2

# 트랙커 객체 생성자 함수 리스트 ---①
trackers = [cv2.TrackerBoosting_create,
            cv2.TrackerMIL_create,
            cv2.TrackerKCF_create,
            cv2.TrackerTLD_create,
            cv2.TrackerMedianFlow_create,
            cv2.TrackerGOTURN_create, #버그로 오류 발생
            cv2.TrackerCSRT_create,
            cv2.TrackerMOSSE_create]
trackerIdx = 0  # 트랙커 생성자 함수 선택 인덱스
tracker = None
isFirst = True

#video_src = 0 # 비디오 파일과 카메라 선택 ---②
video_src = "C:/Users/admin/Downloads/movies/jaywalk2.mp4"
cap = cv2.VideoCapture(video_src)
fps = cap.get(cv2.CAP_PROP_FPS) # 프레임 수 구하기
delay = int(1000/fps)
win_name = 'Tracking APIs'
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print('Cannot read video file')
        break
    img_draw = frame.copy()
    if tracker is None: # 트랙커 생성 안된 경우
        cv2.putText(img_draw, "Press the Space to set ROI!!", \
            (100,80), cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2,cv2.LINE_AA)
    else:
        ok, bbox = tracker.update(frame)   # 새로운 프레임에서 추적 위치 찾기 ---③
        (x,y,w,h) = bbox
        if ok: # 추적 성공
            cv2.rectangle(img_draw, (int(x), int(y)), (int(x + w), int(y + h)), \
                          (0,255,0), 2, 1)
        else : # 추적 실패
            cv2.putText(img_draw, "Tracking fail.", (100,80), \
                        cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2,cv2.LINE_AA)
    trackerName = tracker.__class__.__name__
    cv2.putText(img_draw, str(trackerIdx) + ":"+trackerName , (100,20), \
                 cv2.FONT_HERSHEY_SIMPLEX, 0.75, (0,255,0),2,cv2.LINE_AA)

    cv2.imshow(win_name, img_draw)
    key = cv2.waitKey(delay) & 0xff
    # 스페이스 바 또는 비디오 파일 최초 실행 ---④
    if key == ord(' ') or (video_src != 0 and isFirst): 
        isFirst = False
        roi = cv2.selectROI(win_name, frame, False)  # 초기 객체 위치 설정
        if roi[2] and roi[3]:         # 위치 설정 값 있는 경우
            tracker = trackers[trackerIdx]()    #트랙커 객체 생성 ---⑤
            isInit = tracker.init(frame, roi)
    elif key in range(48, 56): # 0~7 숫자 입력   ---⑥
        trackerIdx = key-48     # 선택한 숫자로 트랙커 인덱스 수정
        if bbox is not None:
            tracker = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성 ---⑦
            isInit = tracker.init(frame, bbox) # 이전 추적 위치로 추적 위치 초기화
    elif key == 27 : 
        break
else:
    print( "Could not open video")
cap.release()
cv2.destroyAllWindows()

# %%
import cv2

# 트랙커 객체 생성자 함수 리스트 ---①
trackers = [cv2.TrackerBoosting_create,
            cv2.TrackerMIL_create,
            cv2.TrackerKCF_create,
            cv2.TrackerTLD_create,
            cv2.TrackerMedianFlow_create,
            cv2.TrackerGOTURN_create, #버그로 오류 발생
            cv2.TrackerCSRT_create,
            cv2.TrackerMOSSE_create]
trackerIdx = 0  # 트랙커 생성자 함수 선택 인덱스
tracker = None
isFirst = True

video_src = 0 # 비디오 파일과 카메라 선택 ---②
video_src = "C:/Users/admin/Downloads/movies/jaywalk2.mp4"
cap = cv2.VideoCapture(video_src)
fps = cap.get(cv2.CAP_PROP_FPS) # 프레임 수 구하기
delay = int(1000/fps)
win_name = 'Tracking APIs'
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print('Cannot read video file')
        break
    img_draw = frame.copy()
    if tracker is None: # 트랙커 생성 안된 경우
        cv2.putText(img_draw, "Press the Space to set ROI!!", \
            (100,80), cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2,cv2.LINE_AA)
    else:
        ok, bbox = tracker.update(frame)   # 새로운 프레임에서 추적 위치 찾기 ---③
        (x,y,w,h) = bbox
        if ok: # 추적 성공
            cv2.rectangle(img_draw, (int(x), int(y)), (int(x + w), int(y + h)), \
                          (0,255,0), 2, 1)
        else : # 추적 실패
            cv2.putText(img_draw, "Tracking fail.", (100,80), \
                        cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2,cv2.LINE_AA)
    trackerName = tracker.__class__.__name__
    cv2.putText(img_draw, str(trackerIdx) + ":"+trackerName , (100,20), \
                 cv2.FONT_HERSHEY_SIMPLEX, 0.75, (0,255,0),2,cv2.LINE_AA)

    cv2.imshow(win_name, img_draw)
    key = cv2.waitKey(delay) & 0xff
    # 스페이스 바 또는 비디오 파일 최초 실행 ---④
    if key == ord(' ') or (video_src != 0 and isFirst): 
        isFirst = False
        roi = cv2.selectROI(win_name, frame, False)  # 초기 객체 위치 설정
        print('roi', type(roi), roi)
        if roi[2] and roi[3]:         # 위치 설정 값 있는 경우
            tracker = trackers[trackerIdx]()    #트랙커 객체 생성 ---⑤
            print('tracker', type(tracker), tracker)
            isInit = tracker.init(frame, roi)
            print('islnit',type(isInit),isInit)
    elif key in range(48, 56): # 0~7 숫자 입력   ---⑥
        trackerIdx = key-48     # 선택한 숫자로 트랙커 인덱스 수정
        if bbox is not None:
            tracker = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성 ---⑦
            isInit = tracker.init(frame, bbox) # 이전 추적 위치로 추적 위치 초기화
    elif key == 27 : 
        break
else:
    print( "Could not open video")
cap.release()
cv2.destroyAllWindows()
# Out:
# roi <class 'tuple'> (0, 0, 0, 0)
# roi <class 'tuple'> (1159, 288, 122, 196)
# tracker <class 'cv2.TrackerBoosting'> <TrackerBoosting 000001BAB5DC1970>
# islnit <class 'bool'> True
# roi <class 'tuple'> (353, 258, 92, 102)
# tracker <class 'cv2.TrackerBoosting'> <TrackerBoosting 000001BA95898970>
# islnit <class 'bool'> True
# roi <class 'tuple'> (455, 288, 117, 51)
# tracker <class 'cv2.TrackerBoosting'> <TrackerBoosting 000001BAB5DC1B70>
# islnit <class 'bool'> True

# %%
#!pip install opencv-contrib-python==3.4.11.45
import cv2 
print(cv2.__version__)
# Out:
# 3.4.11

# %%
"""
Tracking API
OpenCV에서는 객체 추적을 위한 Tracking API를 제공합니다. Tracking API를 이용하면 쉽게 객체 추적을 할 수 있습니다. 알고리즘 이론을 몰라도 됩니다. 추적하고자 하는 객체만 지정해주면 API가 알아서 객체를 추적해줍니다. 편리하죠? OpenCV에서 제공하는 Tracking API생성자는 아래와 같습니다. 생성자는 알고리즘에 따라 다양합니다.

tracker = cv2.TrackerBoosting_create(): AdaBoost 알고리즘 기반
tracker = cv2.TrackerMIL_create(): MIL(Multiple Instance Learning) 알고리즘 기반
tracker = cv2.TrackerKCF_create(): KCF(Kernelized Correlation Filters) 알고리즘 기반
tracker = cv2.TrackerTLD_create(): TLD(Tracking, Learning and Detection) 알고리즘 기반
tracker = cv2.TrackerMedianFlow_create(): 객체의 전방향/역방향을 추적해서 불일치성을 측정
tracker = cv2.TrackerGOTURN_cretae(): CNN(Convolutional Neural Networks) 기반 - OpenCV 3.4 버전에서는 버그로 동작이 안 됨
tracker = cv2.TrackerCSRT_create(): CSRT(Channel and Spatial Reliability)
tracker = cv2.TrackerMOSSE_create(): 내부적으로 그레이 스케일 사용

생성한 Tracker는 init() 함수로 초기화할 수 있습니다. 
init() 함수의 파라미터로 두 가지를 전달해야 합니다.
입력 영상과 추적 대상 객체가 있는 좌표입니다. 

retval = cv2.Tracker.init(img, boundingBox): Tracker 초기화
img: 입력 영상
boundingBox: 추적 대상 객체가 있는 좌표 (x, y)
초기화 후 새로운 영상 프레임에서 추적 대상 객체의 위치를 찾기 위해 update() 함수를 호출해야 합니다.

retval, boundingBox = cv2.Tracker.update(img): 새로운 프레임에서 추적 대상 객체 위치 찾기
img: 새로운 프레임 영상
retval: 추적 성공 여부
boundingBox: 새로운 프레임에서의 추적 대상 객체의 새로운 위치 (x, y, w, h)
아래 코드는 Tracking API를 이용해서 객체를 추적하는 예제
"""

# %%
import cv2

# 트랙커 객체 생성자 함수 리스트 
trackers = [cv2.TrackerBoosting_create,
            cv2.TrackerMIL_create,
            cv2.TrackerKCF_create,
            cv2.TrackerTLD_create,
            cv2.TrackerMedianFlow_create,
            cv2.TrackerGOTURN_create, #버그로 오류 발생
            cv2.TrackerCSRT_create,
            cv2.TrackerMOSSE_create]
trackerIdx = 0  # 트랙커 생성자 함수 선택 인덱스
tracker = None
isFirst = True

video_src = 0 # 비디오 파일과 카메라 선택 
video_src = "C:/Users/admin/Downloads/movies/jagwalk2.mp4"
cap = cv2.VideoCapture(video_src)
fps = cap.get(cv2.CAP_PROP_FPS) # 프레임 수 구하기
delay = int(1000/fps)
win_name = 'Tracking APIs'
while cap.isOpened():
    ret, frame = cap.read()
    frame1=frame
    if not ret:
        print('Cannot read video file')
        break
    img_draw = frame.copy()
    if tracker is None: # 트랙커 생성 안된 경우
        cv2.putText(img_draw, "Press the Space to set ROI!!", \
            (100,80), cv2.FONT_HERSHEY_SIMPLEX, 0.5,(0,0,255),2,cv2.LINE_AA)
    else:
        ok1, bbox1 = tracker.update(frame)   # 새로운 프레임에서 추적 위치 찾기 
        ok2, bbox2 = tracker.update(frame)   # 새로운 프레임에서 추적 위치 찾기 
        (x1,y1,w1,h1) = bbox1
        (x2,y2,w2,h2) = bbox2
        if ok1 and ok2: # 추적 성공
            cv2.rectangle(img_draw, (int(x1), int(y1)), (int(x1 + w1), int(y1 + h1)), \
                          (0,255,0), 2, 1)
            cv2.rectangle(img_draw, (int(x2), int(y2)), (int(x2 + w2), int(y2 + h2)), \
                          (0,0,255), 2, 1)
        else : # 추적 실패
            cv2.putText(img_draw, "Tracking fail.", (100,80), \
                        cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2,cv2.LINE_AA)
    trackerName = tracker.__class__.__name__
    cv2.putText(img_draw, str(trackerIdx) + ":"+trackerName , (100,20), \
                 cv2.FONT_HERSHEY_SIMPLEX, 0.75, (0,0,255),2,cv2.LINE_AA)
    cv2.imshow(win_name, img_draw)
    key = cv2.waitKey(delay) & 0xff
    # 스페이스 바 또는 비디오 파일 최초 실행 
    if key == ord(' ') or (video_src != 0 and isFirst): 
        isFirst = False
        roi1 = cv2.selectROI(win_name, frame, False)  # 초기 객체 위치 설정
        roi2 = cv2.selectROI(win_name+'1', frame1, False)  # 초기 객체 위치 설정
        if roi1[2] and roi1[3]:         # 위치 설정 값 있는 경우
            tracker1 = trackers[trackerIdx]()    #트랙커 객체 생성 
            isInit1 = tracker.init(frame, roi1)
            tracker2 = trackers[trackerIdx]()    #트랙커 객체 생성 
            isInit2 = tracker.init(frame1, roi2)
    elif key in range(48, 56): # 0~7 숫자 입력  
        trackerIdx = key-48     # 선택한 숫자로 트랙커 인덱스 수정
        if bbox is not None:
            tracker1 = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성 
            isInit1 = tracker.init(frame, bbox1) # 이전 추적 위치로 추적 위치 초기화
            tracker2 = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성 
            isInit2 = tracker.init(frame, bbox2) # 이전 추적 위치로 추적 위치 초기화

    elif key == 27 : 
        break
else:
    print( "Could not open video")
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16920/2722454611.py in <module>
#      18 cap = cv2.VideoCapture(video_src)
#      19 fps = cap.get(cv2.CAP_PROP_FPS) # 프레임 수 구하기
# ---> 20 delay = int(1000/fps)
#      21 win_name = 'Tracking APIs'
#      22 while cap.isOpened():
#
# ZeroDivisionError: float division by zero

# %%
import cv2
import numpy as np

 #image_path
img_path="C:/Users/admin/Desktop/person1.jpg"

#read image
img_raw = cv2.imread(img_path)

#select ROI function
roi = cv2.selectROI(img_raw)

#print rectangle points of selected roi
print(roi)

#Crop selected roi from raw image
roi_cropped = img_raw[int(roi[1]):int(roi[1]+roi[3]), int(roi[0]):int(roi[0]+roi[2])]

#show cropped image
cv2.imshow("ROI", roi_cropped)
cv2.imwrite("crop.jpeg",roi_cropped)

cv2.waitKey()
cv2.destroyAllWindows()
#hold window
# Out:
# (349, 132, 167, 179)

# %%
import cv2
import numpy as np

 #image_path
img_path="C:/Users/admin/Desktop/person1.jpg"

#read image
img_raw = cv2.imread(img_path)

#select ROIs function
ROIs = cv2.selectROIs("Select Rois",img_raw)

#print rectangle points of selected roi
print(ROIs)

#Crop selected roi ffrom raw image

#counter to save image with different name
crop_number=0 

#loop over every bounding box save in array "ROIs"
for rect in ROIs:
    x1=rect[0]
    y1=rect[1]
    x2=rect[2]
    y2=rect[3]

    #crop roi from original image
    img_crop=img_raw[y1:y1+y2,x1:x1+x2]

    #show cropped image
    cv2.imshow("crop"+str(crop_number),img_crop)

    #save cropped image
    cv2.imwrite("crop"+str(crop_number)+".jpeg",img_crop)
        
    crop_number+=1

#hold window
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [[359 145  79 104]
#  [547 293 132 116]
#  [348 156  98 110]
#  [572 282 123 147]
#  [572 282 123 147]
#  [572 282 123 147]]
# 27

# %%
"""
src( Rect( x, y, width, height)) )
  ○ src : 관심영역을 설정할 원본 이미지
  ○ Rect( x, y, width, height) ) : 관심영역을 설정할 사각형 정보, 좌표( x, y)를 시작으로 width 와 height 를 설정함
src( Rect( Point( x1, y1 ), Point( x2, y2) ) )
  ○ src : 관심영역을 설정할 원본 이미지
  ○ Rect( Point( x1, y1 ), Point( x2, y2) ) : 관심영역을 설정할 사각형 정보, 두 좌표를 지정하여 사각형 범위를 설정함
"""

	x1=rect[0]
	y1=rect[1]
	x2=rect[2]
	y2=rect[3]
img_draw[y1:y1+y2,x1:x1+x2]

# %%
#시행착오 
import cv2
# 트랙커 객체 생성자 함수 리스트 
trackers = [cv2.TrackerBoosting_create,
            cv2.TrackerMIL_create,
            cv2.TrackerKCF_create,
            cv2.TrackerTLD_create,
            cv2.TrackerMedianFlow_create,
            cv2.TrackerGOTURN_create, #버그로 오류 발생
            cv2.TrackerCSRT_create,
            cv2.TrackerMOSSE_create]
trackerIdx = 0  # 트랙커 생성자 함수 선택 인덱스
tracker = None
isFirst = True

video_src = 0 # 비디오 파일과 카메라 선택 
video_src = "C:/Users/admin/Downloads/movies/jaywalk2.mp4"
cap = cv2.VideoCapture(video_src)
fps = cap.get(cv2.CAP_PROP_FPS) # 프레임 수 구하기
delay = int(1000/fps)
win_name = 'Tracking APIs'
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print('Cannot read video file')
        break
    img_draw = frame.copy()
    if tracker1 is None and tracker2 is None: # 트랙커 생성 안된 경우
        cv2.putText(img_draw, "Press the Space to set ROI", \
            (100,80), cv2.FONT_HERSHEY_SIMPLEX, 0.5,(0,0,255),2,cv2.LINE_AA)
    else:
        ok1, bbox1 = tracker1.update(frame)   # 새로운 프레임에서 추적 위치 찾기 
        ok2, bbox2 = tracker2.update(frame)   # 새로운 프레임에서 추적 위치 찾기 
        (x1,y1,w1,h1) = bbox1
        print('bbox1',bbox1)
        (x2,y2,w2,h2) = bbox2
        print('bbox2',bbox2)
        if ok1 and ok2: # 추적 성공
            cv2.rectangle(img_draw, (int(x1), int(y1)), (int(x1 + w1), int(y1 + h1)), \
                          (0,255,0), 2, 1) #img_draw
            cv2.rectangle(img_draw, (int(x2), int(y2)), (int(x2 + w2), int(y2 + h2)), \
                          (0,0,255), 2, 1) #img_draw

        else : # 추적 실패
            cv2.putText(img_draw, "Tracking fail.", (100,80), \
                        cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2,cv2.LINE_AA)
    trackerName = tracker.__class__.__name__
    cv2.putText(img_draw, str(trackerIdx) + ":"+trackerName , (100,20), \
                 cv2.FONT_HERSHEY_SIMPLEX, 0.75, (0,0,255),2,cv2.LINE_AA)
    cv2.imshow(win_name, img_draw)
    key = cv2.waitKey(delay) & 0xff
    # 스페이스 바 또는 비디오 파일 최초 실행 
    if key == ord(' ') or (video_src != 0 and isFirst): 
        isFirst = False
        ROIs = cv2.selectROIs("Tracking APIs",img_draw)
        #이름을 다르게 지정하기 위함
        crop_imgs= [] 
        crop_number=0
        for rect in ROIs:
            x1=rect[0]
            y1=rect[1]
            x2=rect[2]
            y2=rect[3]
            #crop_imgs.append([y1,y1+y2,x1:x1+x2])
#            crop_imgs.append((y1,y1+y2,x1,x1+x2))
            crop_imgs.append((x1,y1,x2,y2))
            #crop_imgs.append((y1,y2,x1,x2))
            #print(x1, y1, x2, y2)
            #show cropped image
            #cv2.imshow("crop"+str(crop_number),img_draw[y1:y1+y2,x1:x1+x2])
            #crop_number+=1
        #cv2.waitKey()
        #cv2.destroyAllWindows()
        cv2.destroyWindow('Select Rois')
        #roi1 = cv2.selectROI(win_name, frame, False)  # 초기 객체 위치 설정
        #roi2 = cv2.selectROI(win_name+'1', frame1, False)  # 초기 객체 위치 설정
        if len(crop_imgs) != 0:         # 위치 설정 값 있는 경우
            tracker1 = trackers[trackerIdx]()    #트랙커 객체 생성 
            isInit1 = tracker1.init(frame, crop_imgs[0]) #roi1
            tracker2 = trackers[trackerIdx]()    #트랙커 객체 생성 
            isInit2 = tracker2.init(frame, crop_imgs[1]) #roi2
    elif key in range(48, 56): # 0~7 숫자 입력  
        trackerIdx = key-48     # 선택한 숫자로 트랙커 인덱스 수정
        if bbox1 is not None:
            tracker1 = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성 
            isInit1 = tracker1.init(frame, bbox1) # 이전 추적 위치로 추적 위치 초기화
            tracker2 = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성 
            isInit2 = tracker2.init(frame, bbox2) # 이전 추적 위치로 추적 위치 초기화
    elif key == 27 : 
        break
else:
    print( "Could not open video")
cap.release()
cv2.destroyAllWindows()
# Out:
# bbox1 (684.0, 292.0, 186.0, 184.0)
# bbox2 (1030.0, 288.0, 80.0, 155.0)
# bbox1 (683.0, 290.0, 186.0, 184.0)
# bbox2 (1034.0, 288.0, 80.0, 155.0)
# bbox1 (684.0, 290.0, 186.0, 184.0)
# bbox2 (1034.0, 288.0, 80.0, 155.0)
# bbox1 (683.0, 290.0, 186.0, 184.0)
# bbox2 (1043.0, 290.0, 80.0, 155.0)
# bbox1 (682.0, 288.0, 186.0, 184.0)
# bbox2 (1048.0, 288.0, 80.0, 155.0)
# bbox1 (681.0, 288.0, 186.0, 184.0)
# bbox2 (1048.0, 288.0, 80.0, 155.0)
# bbox1 (680.0, 286.0, 186.0, 184.0)
# bbox2 (1053.0, 288.0, 80.0, 155.0)
# bbox1 (679.0, 280.0, 186.0, 184.0)
# bbox2 (1063.0, 286.0, 80.0, 155.0)
# bbox1 (680.0, 280.0, 186.0, 184.0)
# bbox2 (1063.0, 286.0, 80.0, 155.0)
# bbox1 (679.0, 280.0, 186.0, 184.0)
# bbox2 (1068.0, 286.0, 80.0, 155.0)
# bbox1 (676.0, 276.0, 186.0, 184.0)
# bbox2 (1078.0, 286.0, 80.0, 155.0)
# bbox1 (675.0, 276.0, 186.0, 184.0)
# bbox2 (1084.0, 286.0, 80.0, 155.0)
# bbox1 (674.0, 274.0, 186.0, 184.0)
# bbox1 (650.0, 278.0, 186.0, 184.0)
# bbox2 (1699.0, 434.0, 80.0, 155.0)
# bbox1 (651.0, 276.0, 186.0, 184.0)
# bbox2 (1724.0, 436.0, 80.0, 155.0)
# bbox1 (652.0, 272.0, 186.0, 184.0)
# bbox2 (1749.0, 440.0, 80.0, 155.0)
# bbox1 (655.0, 270.0, 186.0, 184.0)
# bbox2 (1775.0, 444.0, 80.0, 155.0)
# bbox1 (654.0, 268.0, 186.0, 184.0)
# bbox2 (1801.0, 448.0, 80.0, 155.0)
# bbox1 (657.0, 262.0, 186.0, 184.0)
# bbox2 (1825.0, 452.0, 80.0, 155.0)
# bbox1 (660.0, 260.0, 186.0, 184.0)
# bbox2 (1793.0, 390.0, 80.0, 155.0)
# bbox1 (659.0, 258.0, 186.0, 184.0)
# bbox2 (1823.0, 394.0, 80.0, 155.0)
# bbox1 (662.0, 258.0, 186.0, 184.0)
# bbox2 (1801.0, 390.0, 80.0, 155.0)
# bbox1 (663.0, 260.0, 186.0, 184.0)
# bbox2 (1791.0, 378.0, 80.0, 155.0)
# bbox1 (666.0, 260.0, 186.0, 184.0)
# bbox2 (1821.0, 384.0, 80.0, 155.0)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26456/88335323.py in <module>
#      82     elif key in range(48, 56): # 0~7 숫자 입력
#      83         trackerIdx = key-48     # 선택한 숫자로 트랙커 인덱스 수정
# ---> 84         if bbox is not None:
#      85             tracker1 = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성
#      86             isInit1 = tracker1.init(frame, bbox1) # 이전 추적 위치로 추적 위치 초기화
#
# NameError: name 'bbox' is not defined

# %%
#시행착오
import cv2

# 트랙커 객체 생성자 함수 리스트 
trackers = [cv2.TrackerBoosting_create,
            cv2.TrackerMIL_create,
            cv2.TrackerKCF_create,
            cv2.TrackerTLD_create,
            cv2.TrackerMedianFlow_create,
            cv2.TrackerGOTURN_create, #버그로 오류 발생
            cv2.TrackerCSRT_create,
            cv2.TrackerMOSSE_create]
trackerIdx = 0  # 트랙커 생성자 함수 선택 인덱스
tracker = None
isFirst = True

video_src = 0 # 비디오 파일과 카메라 선택 
video_src = "C:/Users/admin/Downloads/movies/cropped_traffic2.mp4"
cap = cv2.VideoCapture(video_src)
fps = cap.get(cv2.CAP_PROP_FPS) # 프레임 수 구하기
delay = int(1000/fps)
win_name = 'Tracking APIs'
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print('Cannot read video file')
        break
    img_draw = frame.copy()
    if tracker is None: # 트랙커 생성 안된 경우
        cv2.putText(img_draw, "Press the Space to set ROI", \
            (100,80), cv2.FONT_HERSHEY_SIMPLEX, 0.5,(0,0,255),2,cv2.LINE_AA)
    else:
        ok1, bbox1 = tracker.update(frame)   # 새로운 프레임에서 추적 위치 찾기 
        ok2, bbox2 = tracker.update(frame)   # 새로운 프레임에서 추적 위치 찾기 
        (x1,y1,w1,h1) = bbox1
        print('bbox1',bbox1)
        (x2,y2,w2,h2) = bbox2
        print('bbox2',bbox2)
        if ok1 and ok2: # 추적 성공
            cv2.rectangle(img_draw, (int(x1), int(y1)), (int(x1 + w1), int(y1 + h1)), \
                          (0,255,0), 2, 1) #img_draw
            cv2.rectangle(img_draw, (int(x2), int(y2)), (int(x2 + w2), int(y2 + h2)), \
                          (0,0,255), 2, 1) #img_draw

        else : # 추적 실패
            cv2.putText(img_draw, "Tracking fail.", (100,80), \
                        cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2,cv2.LINE_AA)
    trackerName = tracker.__class__.__name__
    cv2.putText(img_draw, str(trackerIdx) + ":"+trackerName , (100,20), \
                 cv2.FONT_HERSHEY_SIMPLEX, 0.75, (0,0,255),2,cv2.LINE_AA)
    cv2.imshow(win_name, img_draw)
    key = cv2.waitKey(delay) & 0xff
    # 스페이스 바 또는 비디오 파일 최초 실행 
    if key == ord(' ') or (video_src != 0 and isFirst): 
        isFirst = False
        ROIs = cv2.selectROIs("Tracking APIs",img_draw)
        #이름을 다르게 지정하기 위함
        crop_imgs= [] 
        crop_number=0
        for rect in ROIs:
            x1=rect[0]
            y1=rect[1]
            x2=rect[2]
            y2=rect[3]
            #crop_imgs.append([y1,y1+y2,x1:x1+x2])
#            crop_imgs.append((y1,y1+y2,x1,x1+x2))
            crop_imgs.append((x1,y1,x2,y2))
            #crop_imgs.append((y1,y2,x1,x2))
            #show cropped image
            #cv2.imshow("crop"+str(crop_number),img_draw[y1:y1+y2,x1:x1+x2])
            #crop_number+=1
        #cv2.waitKey()
        #cv2.destroyAllWindows()
        cv2.destroyWindow('Select Rois')
        #roi1 = cv2.selectROI(win_name, frame, False)  # 초기 객체 위치 설정
        #roi2 = cv2.selectROI(win_name+'1', frame1, False)  # 초기 객체 위치 설정
        if len(crop_imgs) != 0:         # 위치 설정 값 있는 경우
            tracker = trackers[trackerIdx]()    #트랙커 객체 생성 
            isInit1 = tracker.init(frame, crop_imgs[0]) #roi1
            isInit2 = tracker.init(frame, crop_imgs[1]) #roi2
    elif key in range(48, 56): # 0~7 숫자 입력  
        trackerIdx = key-48     # 선택한 숫자로 트랙커 인덱스 수정
        if bbox1 is not None:
            tracker = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성 
            isInit1 = tracker.init(frame, bbox1) # 이전 추적 위치로 추적 위치 초기화
            isInit2 = tracker.init(frame, bbox2) # 이전 추적 위치로 추적 위치 초기화
    elif key == 27 : 
        break
else:
    print( "Could not open video")
cap.release()
cv2.destroyAllWindows()

# %%
"""
roi <class 'tuple'> (686, 271, 159, 236)
tracker <class 'cv2.TrackerBoosting'> <TrackerBoosting 000001CAD001E890>
islnit <class 'bool'> True
"""

# %%
crop_imgs[0]
# Out:
# (385, 734, 328, 60)

# %%
for i in range(50):
    if i%5==0:
        a=[]
        for j in range(3):
            a.append([j])
a
# Out:
# [[0], [1], [2]]

# %%
range(200:200+45
# Out:
#   File "C:\Users\admin\AppData\Local\Temp/ipykernel_25588/4108724208.py", line 1
#     [200:200+45]
#         ^
# SyntaxError: invalid syntax

# %%
[i for i in range(1,5)]
# Out:
# [1, 2, 3, 4]

# %%
#객체 두개가 겹치는 때 검출하기
#(x,y,w,h)
#bbox1 =(472.0, 765.0, 202.0, 19.0)
#bbox2 =(763.0, 635.0, 37.0, 22.0)

rect1 =(150, 123, 450, 38)
rect2 =(212, 178, 45, 50)

#예시
#첫번째 사각형
x1=150 #시작점의 x
y1=123 #시작점의 y
w1=450 #시작점으로부터 가로길이로 나아가는 길이
h1=38  #시작점으로부터 세로길이로 내려가는 길이

#두번째 사각형
x2=212
y2=150
w2=45
h2=50 


"""
좌측상단(0,0)에 가까울 수록 x좌표나 y좌표의 값은 작아짐 

좀더 좌측 상단에 있는 시작점을 검출해 이것을 기준으로 함
x좌표를 기준으로 검출
if rect1[0] < rect2[0] ]:
    standard_rect = rect1
    other_rect= rect2
else:
    standard_rect = rect2
    other_rect= rect1
    

겹친다는 것의 요건은 
기준이 되는 사각형의 면적 안에 다른 사각형의 꼭지점이 하나라도 들어간다는 것

rect2 =(212, 178, 45, 50)
         x,   y,  w,  h
         
다른 사각형의 꼭지점은 
           x좌표,  y좌표
좌측상단 (rect2[0],rect2[1])
            x좌표 + 가로길이, y좌표
우측상단 (rect2[0]+rect[2], rect2[1])
            x좌표,   y좌표 + 세로길이  
좌측하단 (rect2[0],rect2[1]+rect2[3])
             x좌표+가로길이,    y좌표+세로길이     
우측하단 (rect2[0]+rect2[2], rect2[1]+rect2[3])
                       
#모든 꼭지점이 x는 range(rect2[0],rect2[0]+rect2[2]+1)내에서 존재하고
               y는 range(rect2[1],rect2[1]+rect2[3]+1)내에서 존재
  
#예시
212,200 x,y    xrange= range(212,212+480+1)
480,363 w,h    yrange= range(200,200+363+1)

비교대상 겹침
527,145 x,y    x의 최대값
60,90 w,h      y의 최소값


#사각형이 겹친다는 것은 꼭지점 좌표가 어느 구간에 들어간다는 것으로
 그것은 사각형에 겹치는 구간이 있다는 것으로 인식
 따라서 비교대상이 되는 rect2의 x값과 y값의 최댓값과 최소값으로 범위내에 있는지 검출
"""

img_test = cv2.imread('./img/blank_500.jpg') 
#배율 지정으로 도화지 늘리기
img_test = cv2.resize(img_test, None, None, 3.5, 2, cv2.INTER_CUBIC)
img_test2 = img_test

cv2.rectangle(img_test, (int(x1), int(y1)), (int(x1 + w1), int(y1 + h1)),(0,255,0), 2, 1) 
cv2.rectangle(img_test, (int(x2), int(y2)), (int(x2 + w2), int(y2 + h2)),(0,255,0), 2, 1) 

ract1=cv2.rectangle(img_test, (int(x1), int(y1)), (int(x1 + w1), int(y1 + h1)),(0,255,0), 2, 1) 
ract2=cv2.rectangle(img_test, (int(x2), int(y2)), (int(x2 + w2), int(y2 + h2)),(0,255,0), 2, 1) 

print('==========================')


#??overlap(rect1, rect2)
cv2.imshow('img_test', img_test)

cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# ==========================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13192/1403018970.py in <module>
#      88
#      89
# ---> 90 overlap(rect1, rect2)
#      91 cv2.imshow('img_test', img_test)
#      92
#
# NameError: name 'overlap' is not defined

# %%
# Out:
# (212, 200, 480, 363) (527, 145, 60, 90)
# 2

# %%
"""                       
#모든 꼭지점이 x는 range(rect2[0],rect2[0]+rect2[2]+1)내에서 존재하고
               y는 range(rect2[1],rect2[1]+rect2[3]+1)내에서 존재
  
#예시
212,200 x,y    xrange= range(212,212+480+1)
480,363 w,h    yrange= range(200,200+363+1)

비교대상 겹침
527,145 x,y    x의 최대값
60,90 w,h      y의 최소값


#사각형이 겹친다는 것은 꼭지점 좌표가 어느 구간에 들어간다는 것으로
 그것은 사각형에 겹치는 구간이 있다는 것으로 인식
 따라서 비교대상이 되는 rect2의 x값과 y값의 최댓값과 최소값으로 범위내에 있는지 검출


최소값 in range(x_n:x1+w1) or 최대값 in range(x1:x1+w1)
혹은 
2(최소값) in range(y1:y1+h1) or (최대값) in range(y1:y1+h1)
"""

xrange= range(212,212+480+1) 
yrange= range(200,200+363+1) 
xrange#range(212, 693)
yrange#range(200, 564)

#비교대상(하단의 작은 검은 직사각형) 겹침
check_x,check_y = 527,145     #x의 최소값: check_x , x의 최대값:check_x+check_w
check_w,check_h = 60,90       #y의 최소값: check_y , y의 최대값:check_y+checj_h 

total=0
#좌측상단 꼭지점 확인
if check_x in xrange and check_y in yrange:
    total+=1

#우측상단 꼭지점 확인
if check_x+check_w in xrange and check_y in yrange:
    total+=1
    
#좌측하단 꼭지점 확인
if check_y+check_h in yrange and check_x in xrange:
    total+=1

#우측하단 꼭지점 확인
if check_x+check_w in xrange and check_y+check_h in yrange:
    total+=1
    
print(total)    #꼭지점이 두개 겹친다는 의미



"""
이후에 꼭지점이 한개이상 검출되면 겹치는 영역이 있다고 판단
"""

if spot_check() > 0:
    print('차량 stop을 이미지에 띄우시오')
# Out:
# 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#겹치는 사각형에 대한 꼭지점 수 검출하기

def spot_check(rect1, rect2):
    #겹치는 사각형 영역의 꼭지점 수 검출
    
    #좀더 좌측 상단에 있는 시작점을 검출해 이것을 기준으로 함
    #x좌표를 기준으로 검출
    if rect1[0] < rect2[0]:
        standard_rect = rect1
        other_rect= rect2
    else:
        standard_rect = rect2
        other_rect= rect1
    #standard 사각형 기준    
                                                           #list(range(1,3)) >>> [1,2]
    #range(          x좌표,           x좌표+가로길이(너비)+range는 미만으로 수를 잡으므로 +1 
    xrange= range(standard_rect[0],standard_rect[0]+standard_rect[2]+1) 
    #range(          y좌표,           y좌표+세로길이(높이)+range는 미만으로 수를 잡으므로 +1 
    yrange= range(standard_rect[1],standard_rect[1]+standard_rect[3]+1)   
    
    #겹치는지 확인하기 위한 비교대상이 되는 사각형(other_rect) 기준
    min_check_x=other_rect[0]                #x의 최소값: check_x
    max_check_x=other_rect[0]+other_rect[2]  #x의 최대값:check_x+check_w
    min_check_y=other_rect[1]                #y의 최소값: check_y   
    max_check_y=other_rect[1]+other_rect[3]  #y의 최대값:check_y+check_h 
    
    #검출된 겹치는 꼭지점 개수 초기화
    total_points=0

    #좌측상단 꼭지점 확인
    if min_check_x in xrange and min_check_y in yrange:
        total_points+=1

    #우측상단 꼭지점 확인
    if max_check_x in xrange and min_check_y in yrange:
        total_points+=1

    #좌측하단 꼭지점 확인
    if max_check_y in yrange and min_check_x in xrange:
        total_points+=1

    #우측하단 꼭지점 확인
    if max_check_x in xrange and max_check_y in yrange:
        total_points+=1
    
    return total_points

########################################################################################################################
#사각형 겹침 상태 확인
img_test = cv2.imread('./img/blank_500.jpg') 
#배율 지정으로 도화지 늘리기
img_test = cv2.resize(img_test, None, None, 3, 2, cv2.INTER_CUBIC)

rect1 =(212, 200, 480, 363)
rect2 =(527, 145, 60, 90)

#연두색 큰 사각형
cv2.rectangle(img_test, (rect1[0], rect1[1]), (rect1[0]+rect1[2], rect1[1]+rect1[3]),(0,255,0), 2, 1) 
#빨간 작은 사각형 
cv2.rectangle(img_test, (rect2[0], rect2[1]), (rect2[0]+rect2[2], rect2[1]+rect2[3]),(0,0,255), 2, 1) 

cv2.imshow('img_blank', img_test)
cv2.waitKey()
cv2.destroyAllWindows()

########################################################################################################################
#꼭지점 수 구하기 (spot_check 함수사용)
rect1 =(212, 200, 480, 363)
rect2 =(527, 145, 60, 90)

print(rect1, rect2)
spot_check(rect1, rect2)
# Out:
# (212, 200, 480, 363) (527, 145, 60, 90)
# 2

# %%
#성공! 368p확인
#cv2.ROIs 는 https://blog.electroica.com/select-roi-or-multiple-rois-bounding-box-in-opencv-python/ 참조

"""
멈춘 영상을 재생하기 위해선 esc
이후 roi를 드래그로 지정하고 enter 혹은 spacebar로 set
이후에 다시 esc

현재는 횡단보도와 사람을 검출하기 위해 
roi를 두개만 지정할 수 있게 함

영상 재생중 exit하고 싶다면 esc를 두번이상 누름
"""
import cv2

#디폴트 에이다 부스트를 이용한 검출 
#영상의 길이가 멀어질 수록 잘 검출이 안됨 
#사각은 정면보다 특히나 검출이 더 안됨

# 트랙커 객체 생성자 함수 리스트 
trackers = [cv2.TrackerBoosting_create,
            cv2.TrackerMIL_create,
            cv2.TrackerKCF_create,
            cv2.TrackerTLD_create,
            cv2.TrackerMedianFlow_create,
            cv2.TrackerGOTURN_create, #버그로 오류 발생 안하는게 좋음
            cv2.TrackerCSRT_create,
            cv2.TrackerMOSSE_create]
trackerIdx = 0  # 트랙커 생성자 함수 선택 인덱스
tracker1 = None
tracker2 = None
isFirst = True

video_src = 0 # 비디오 파일과 카메라 선택 
video_src = "C:/Users/admin/Downloads/movies/cropped_traffic2.mp4"
cap = cv2.VideoCapture(video_src)
fps = cap.get(cv2.CAP_PROP_FPS) # 프레임 수 구하기
delay = int(1000/fps)
win_name = 'Tracking APIs'
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print('Cannot read video file')
        break
    img_draw = frame.copy()
    if tracker1 is None and tracker2 is None: # 트랙커 생성 안된 경우
        cv2.putText(img_draw, "Press the Space to set ROI", \
            (100,80), cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2,cv2.LINE_AA)
    else:
        ok1, bbox1 = tracker1.update(frame)   # 새로운 프레임에서 추적 위치 찾기 
        ok2, bbox2 = tracker2.update(frame)   # 새로운 프레임에서 추적 위치 찾기 
        (x1,y1,w1,h1) = bbox1
        print('bbox1',bbox1)
        (x2,y2,w2,h2) = bbox2
        print('bbox2',bbox2)
        if ok1 and ok2: # 추적 성공
            cv2.rectangle(img_draw, (int(x1), int(y1)), (int(x1 + w1), int(y1 + h1)), \
                          (0,255,0), 2, 1) #img_draw
            cv2.rectangle(img_draw, (int(x2), int(y2)), (int(x2 + w2), int(y2 + h2)), \
                          (0,0,255), 2, 1) #img_draw
            #if :#사람 객체 roi가 횡단보도 객체roi와 겹친다면 횡단보도 보행자로 인식
            #    cv2.putText(img_draw, "STOP!", \
            #        (1000,800), cv2.FONT_HERSHEY_SIMPLEX, 0.5,(0,0,255),2,cv2.LINE_AA)  
        
        else : # 추적 실패
            cv2.putText(img_draw, "Tracking fail.", (100,80), \
                        cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2,cv2.LINE_AA)
    trackerName = tracker1.__class__.__name__
    cv2.putText(img_draw, str(trackerIdx) + ":"+trackerName , (100,20), \
                 cv2.FONT_HERSHEY_SIMPLEX, 0.75, (0,0,255),2,cv2.LINE_AA)
    cv2.imshow(win_name, img_draw)
    key = cv2.waitKey(delay) & 0xff
    # 스페이스 바 또는 비디오 파일 최초 실행 
    if key == ord(' ') or (video_src != 0 and isFirst): 
        isFirst = False
        ROIs = cv2.selectROIs("Tracking APIs",img_draw)
        #이름을 다르게 지정하기 위함
        crop_imgs= [] 
        crop_number=0
        for rect in ROIs:
            x1=rect[0]
            y1=rect[1]
            x2=rect[2]
            y2=rect[3]
            crop_imgs.append((x1,y1,x2,y2))
        cv2.destroyWindow('Select Rois')
        if len(crop_imgs) != 0:         # 위치 설정 값 있는 경우
            tracker1 = trackers[trackerIdx]()    #트랙커 객체 생성 
            isInit1 = tracker1.init(frame, crop_imgs[0]) #roi1
            tracker2 = trackers[trackerIdx]()    #트랙커 객체 생성 
            isInit2 = tracker2.init(frame, crop_imgs[1]) #roi2
    elif key in range(48, 56): # 0~7 숫자 입력  #근데 안될 수 있는게 있을 수도 있음
        trackerIdx = key-48     # 선택한 숫자로 트랙커 인덱스 수정
        if bbox1 is not None and bbox2 is not None:
            tracker1 = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성 
            isInit1 = tracker1.init(frame, bbox1) # 이전 추적 위치로 추적 위치 초기화
            tracker2 = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성 
            isInit2 = tracker2.init(frame, bbox2) # 이전 추적 위치로 추적 위치 초기화
    elif key == 27 : 
        break
else:
    print( "Could not open video")
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27872/3015331740.py in <module>
#      89             isInit1 = tracker1.init(frame, crop_imgs[0]) #roi1
#      90             tracker2 = trackers[trackerIdx]()    #트랙커 객체 생성
# ---> 91             isInit2 = tracker2.init(frame, crop_imgs[1]) #roi2
#      92     elif key in range(48, 56): # 0~7 숫자 입력  #근데 안될 수 있는게 있을 수도 있음
#      93         trackerIdx = key-48     # 선택한 숫자로 트랙커 인덱스 수정
#
# IndexError: list index out of range

# %%
#객체검출 횡단보도 걷는사람 성공
import cv2
import numpy as np

##겹치는 사각형 영역의 꼭지점 수 검출 함수
def spot_check(rect1, rect2):
    #좀더 좌측 상단에 있는 시작점을 검출해 이것을 기준으로 함
    #x좌표를 기준으로 검출
    if rect1[0] < rect2[0]:
        standard_rect = rect1
        other_rect= rect2
    else:
        standard_rect = rect2
        other_rect= rect1
    #standard 사각형 기준    
                                                           #list(range(1,3)) >>> [1,2]
    #range(          x좌표,           x좌표+가로길이(너비)+range는 미만으로 수를 잡으므로 +1 
    xrange= range(int(standard_rect[0]),int(standard_rect[0])+int(standard_rect[2])+1) 
    #range(          y좌표,           y좌표+세로길이(높이)+range는 미만으로 수를 잡으므로 +1 
    yrange= range(int(standard_rect[1]),int(standard_rect[1])+int(standard_rect[3])+1)   
    
    #겹치는지 확인하기 위한 비교대상이 되는 사각형(other_rect) 기준
    min_check_x=int(other_rect[0])                #x의 최소값: check_x
    max_check_x=int(other_rect[0]+other_rect[2])  #x의 최대값:check_x+check_w
    min_check_y=int(other_rect[1])                #y의 최소값: check_y   
    max_check_y=int(other_rect[1]+other_rect[3])  #y의 최대값:check_y+check_h 
    
    #검출된 겹치는 꼭지점 개수 초기화
    total_points=0

    #좌측상단 꼭지점 확인
    if min_check_x in xrange and min_check_y in yrange:
        total_points+=1

    #우측상단 꼭지점 확인
    if max_check_x in xrange and min_check_y in yrange:
        total_points+=1

    #좌측하단 꼭지점 확인
    if max_check_y in yrange and min_check_x in xrange:
        total_points+=1

    #우측하단 꼭지점 확인
    if max_check_x in xrange and max_check_y in yrange:
        total_points+=1
    
    return total_points

###############################################################################################################################
##횡단보도와 사람객체 roi 추적 API
#디폴트 에이다 부스트를 이용한 검출 
#영상의 길이가 멀어질 수록 잘 검출이 안됨 
#사각은 정면보다 특히나 검출이 더 안됨
#트랙커 객체 생성자 함수 리스트 
trackers = [cv2.TrackerBoosting_create,
            cv2.TrackerMIL_create,
            cv2.TrackerKCF_create,
            cv2.TrackerTLD_create,
            cv2.TrackerMedianFlow_create,
            cv2.TrackerGOTURN_create, #버그로 오류 발생 안하는게 좋음
            cv2.TrackerCSRT_create,
            cv2.TrackerMOSSE_create]
trackerIdx = 0  # 트랙커 생성자 함수 선택 인덱스
tracker1 = None
tracker2 = None
isFirst = True

video_src = 0 # 비디오 파일과 카메라 선택 
video_src = "C:/Users/admin/Downloads/movies/cropped_traffic2.mp4"
cap = cv2.VideoCapture(video_src)
fps = cap.get(cv2.CAP_PROP_FPS) # 프레임 수 구하기
delay = int(1000/fps)
win_name = 'Tracking APIs'
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print('Cannot read video file')
        break
    img_draw = frame.copy()
    if tracker1 is None and tracker2 is None: # 트랙커 생성 안된 경우
        cv2.putText(img_draw, "Press the Space to set ROI", \
            (100,80), cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2,cv2.LINE_AA)
    else:
        ok1, bbox1 = tracker1.update(frame)   # 새로운 프레임에서 추적 위치 찾기 
        ok2, bbox2 = tracker2.update(frame)   # 새로운 프레임에서 추적 위치 찾기 
        (x1,y1,w1,h1) = bbox1
        print('bbox1',bbox1)
        (x2,y2,w2,h2) = bbox2
        print('bbox2',bbox2)
        if ok1 and ok2: # 추적 성공
            cv2.rectangle(img_draw, (int(x1), int(y1)), (int(x1 + w1), int(y1 + h1)), \
                          (0,255,0), 2, 1) #img_draw
            cv2.rectangle(img_draw, (int(x2), int(y2)), (int(x2 + w2), int(y2 + h2)), \
                          (0,0,255), 2, 1) #img_draw
            
            #if사람 객체 roi가 횡단보도 객체roi와 겹친다면 횡단보도 보행자로 인식
            if spot_check(bbox1, bbox2)>0: #최소한 꼭지점 하나영역이 겹친다면
                cv2.putText(img_draw, "STOP!", (1000,800), cv2.FONT_HERSHEY_SIMPLEX, 10,(0,0,255),2,cv2.LINE_AA)  
            else:
                cv2.putText(img_draw, '', (1000,800), cv2.FONT_HERSHEY_SIMPLEX, 10,(0,0,255),2,cv2.LINE_AA) 
        else : # 추적 실패
            cv2.putText(img_draw, "Tracking fail.", (100,80), \
                        cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2,cv2.LINE_AA)
    trackerName = tracker1.__class__.__name__
    cv2.putText(img_draw, str(trackerIdx) + ":"+trackerName , (100,20), \
                 cv2.FONT_HERSHEY_SIMPLEX, 0.75, (0,0,255),2,cv2.LINE_AA)
    cv2.imshow(win_name, img_draw)
    key = cv2.waitKey(delay) & 0xff
    # 스페이스 바 또는 비디오 파일 최초 실행 
    if key == ord(' ') or (video_src != 0 and isFirst): 
        isFirst = False
        ROIs = cv2.selectROIs("Tracking APIs",img_draw)
        #이름을 다르게 지정하기 위함
        crop_imgs= [] 
        crop_number=0
        for rect in ROIs:
            x1=int(rect[0])
            y1=int(rect[1])
            x2=int(rect[2])
            y2=int(rect[3])
            crop_imgs.append((x1,y1,x2,y2))
        cv2.destroyWindow('Select Rois')
        if len(crop_imgs) != 0:         # 위치 설정 값 있는 경우
            tracker1 = trackers[trackerIdx]()    #트랙커 객체 생성 
            isInit1 = tracker1.init(frame, crop_imgs[0]) #roi1
            tracker2 = trackers[trackerIdx]()    #트랙커 객체 생성 
            isInit2 = tracker2.init(frame, crop_imgs[1]) #roi2
    elif key in range(48, 56): # 0~7 숫자 입력  #근데 안될 수 있는게 있을 수도 있음
        trackerIdx = key-48     # 선택한 숫자로 트랙커 인덱스 수정
        if bbox1 is not None and bbox2 is not None:
            tracker1 = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성 
            isInit1 = tracker1.init(frame, bbox1) # 이전 추적 위치로 추적 위치 초기화
            tracker2 = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성 
            isInit2 = tracker2.init(frame, bbox2) # 이전 추적 위치로 추적 위치 초기화
    elif key == 27 : 
        break
else:
    print( "Could not open video")
cap.release()
cv2.destroyAllWindows()

# %%
#방향이동 확인
"""
#방향을 이동한 다는 것은 
이전의rect 좌표가 왼쪽으로 이동할 경우
이전 [x,y,w,h]에서 x값이 -로 이동한다는 의미

오른쪽으로 이동할 경우
이전 [x,y,w,h]에서 x값이 -로 이동한다는 의미

따라서 x좌표만 알면 좌우 이동을 알 수 있음

#가까워지는지 멀어지는지에 대해서는 데이터가 블랙박스로 본인의 차량이 움직이는 시점이기에 검출하지 않음
"""

#횡단보도가 아닌 곳에서 걷는 사람을 검출하기 
"""
hog 알고리즘으로 우선 사람들을 검출하고 
기존에 잡힌 횡단보도 영역이 아닌 부분에서 움직이는 사람객체를 찾고자 했으나  

횡단보도가 아닌 도로에서 걷는 사람만을 검출하기에는 
다른 인도같은 영역이나 풀밭 같은 영역을 구분하기에 opencv로 아직 한계가 있음
"""

# %%
#방향이동 확인
#겹치는 사각형에 대한 꼭지점 수 검출하기
bbox1
bbox2

def move_dir(bbox1, bbox2):
    #움직이는 방향 검출하기
    #x좌표 기준 
    try:
        none_x 
    except:
        
    none_x=-1
    if bbox1[0]>none_x : #맨 처음 들어온 좌표
        before
        

##keep ing

# %%
import cv2
import imutils  # resize1
# default 디텍터를 위한 HOG 객체 생성 및 설정
# HOGDescriptor_getDefaultPeopleDetector() 함수에 의해서 제공되는 64 x 128 크기의 윈도로 훈련된 모델 이용
# HOGDescriptor() 생성자의 기본 값도 이와 같으므로 디폴트 생성자 사용
hogdef = cv2.HOGDescriptor()
hogdef.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())
# daimler 디텍터를 위한 HOG 객체 생성 및 설정
# HOGDescriptor_getDaimlerPeopleDetector() 함수가 제공하는 48 x 96 크기의 윈도로 훈련된 모델을 이용하므로 생성자도 이에 맞게 설정
hogdaim = cv2.HOGDescriptor((48,96), (16,16), (8,8), (8,8), 9)
hogdaim.setSVMDetector(cv2.HOGDescriptor_getDaimlerPeopleDetector())
cap = cv2.VideoCapture('./img/walking.avi')
while cap.isOpened():
    ret, img = cap.read()
    if img is None:
        break
    img2 = img.copy()
    if ret :
        # resize
        img = imutils.resize(img, width = 800)  # resize1
        img2 = imutils.resize(img, width = 800)  # resize1
#         img = cv2.resize(img, dsize=None, fx=0.5, fy=0.5)  # resize2
#         img2 = cv2.resize(img, dsize=None, fx=0.5, fy=0.5)  # resize2
        # default 디텍터로 보행자 검출
        found, _ = hogdef.detectMultiScale(img)
        for (x, y, w, h) in found:
            cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 255), 2)
        cv2.putText(img, 'Detector:%s'%('Default'), (10, 50), cv2.FONT_HERSHEY_DUPLEX,1, (0, 255, 0),1)
        cv2.imshow('img', img)
        # daimler 디텍터로 보행자 검출
        found2, _ = hogdaim.detectMultiScale(img2)
        for (x, y, w, h) in found2:
            cv2.rectangle(img2, (x,y), (x+w, y+h), (0, 255, 0), 2)
        cv2.putText(img2, 'Detector:%s'%('Daimler'), (10, 50), cv2.FONT_HERSHEY_DUPLEX,1, (0, 255, 0),1)
        cv2.imshow('img2', img2)
        key = cv2.waitKey(1)
        if key == 27:
            break
        if key == 32: # 스페이스
            cv2.waitKey(-1) # wait until any key is pressed
    else:
        break
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import imutils  # resize1
import cv2
import numpy as np

##겹치는 사각형 영역의 꼭지점 수 검출 함수
def spot_check(rect1, rect2):
    #좀더 좌측 상단에 있는 시작점을 검출해 이것을 기준으로 함
    #x좌표를 기준으로 검출
    if rect1[0] < rect2[0]:
        standard_rect = rect1
        other_rect= rect2
    else:
        standard_rect = rect2
        other_rect= rect1
    #standard 사각형 기준    
                                                           #list(range(1,3)) >>> [1,2]
    #range(          x좌표,           x좌표+가로길이(너비)+range는 미만으로 수를 잡으므로 +1 
    xrange= range(int(standard_rect[0]),int(standard_rect[0])+int(standard_rect[2])+1) 
    #range(          y좌표,           y좌표+세로길이(높이)+range는 미만으로 수를 잡으므로 +1 
    yrange= range(int(standard_rect[1]),int(standard_rect[1])+int(standard_rect[3])+1)   
    
    #겹치는지 확인하기 위한 비교대상이 되는 사각형(other_rect) 기준
    min_check_x=int(other_rect[0])                #x의 최소값: check_x
    max_check_x=int(other_rect[0]+other_rect[2])  #x의 최대값:check_x+check_w
    min_check_y=int(other_rect[1])                #y의 최소값: check_y   
    max_check_y=int(other_rect[1]+other_rect[3])  #y의 최대값:check_y+check_h 
    
    #검출된 겹치는 꼭지점 개수 초기화
    total_points=0

    #좌측상단 꼭지점 확인
    if min_check_x in xrange and min_check_y in yrange:
        total_points+=1

    #우측상단 꼭지점 확인
    if max_check_x in xrange and min_check_y in yrange:
        total_points+=1

    #좌측하단 꼭지점 확인
    if max_check_y in yrange and min_check_x in xrange:
        total_points+=1

    #우측하단 꼭지점 확인
    if max_check_x in xrange and max_check_y in yrange:
        total_points+=1
    
    return total_points


###############################################################################################################################
##횡단보도와 사람객체 roi 추적 API
"""hogdef = cv2.HOGDescriptor()
hogdef.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())
hogdaim = cv2.HOGDescriptor((48,96), (16,16), (8,8), (8,8), 9)
hogdaim.setSVMDetector(cv2.HOGDescriptor_getDaimlerPeopleDetector())
cap = cv2.VideoCapture('C:/Users/admin/Downloads/movies/cropped_traffic2.mp4')
ROIs=0          
crop_imgs= [] 
while cap.isOpened():
    global ROIs, crop_imgs
    ret, img = cap.read()
    if img is None:
        break
    img2 = img.copy()
    if ret :
        # resize
        img = imutils.resize(img, width = 800)  # resize1#counter to save image with different name
        # default 디텍터로 보행자 검출
        found, _ = hogdef.detectMultiScale(img)
        for (x, y, w, h) in found:
            cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 255), 2)
        cv2.putText(img, 'Detector:%s'%('Default'), (10, 50), cv2.FONT_HERSHEY_DUPLEX,1, (0, 255, 0),1)
        cv2.imshow('img', img)
        # daimler 디텍터로 보행자 검출
        key = cv2.waitKey(1)
        if key == 27:
            break
        if key == 32: # 스페이스
            ROIs = cv2.selectROIs("img",img)
            crop_imgs= [] 
            for rect in ROIs:
                x1=rect[0]
                y1=rect[1]
                x2=rect[2]
                y2=rect[3]
                crop_imgs.append((x1,y1,x2,y2))
            cv2.waitKey()
            cv2.destroyWindow('Select Rois')
    else:
        break
cap.release()
cv2.destroyAllWindows()"""

##겹치는 사각형 영역의 꼭지점 수 검출 함수
def spot_check(rect1, rect2):
    #좀더 좌측 상단에 있는 시작점을 검출해 이것을 기준으로 함
    #x좌표를 기준으로 검출
    if rect1[0] < rect2[0]:
        standard_rect = rect1
        other_rect= rect2
    else:
        standard_rect = rect2
        other_rect= rect1
    #standard 사각형 기준    
                                                           #list(range(1,3)) >>> [1,2]
    #range(          x좌표,           x좌표+가로길이(너비)+range는 미만으로 수를 잡으므로 +1 
    xrange= range(int(standard_rect[0]),int(standard_rect[0])+int(standard_rect[2])+1) 
    #range(          y좌표,           y좌표+세로길이(높이)+range는 미만으로 수를 잡으므로 +1 
    yrange= range(int(standard_rect[1]),int(standard_rect[1])+int(standard_rect[3])+1)   
    
    #겹치는지 확인하기 위한 비교대상이 되는 사각형(other_rect) 기준
    min_check_x=other_rect[0]                #x의 최소값: check_x
    max_check_x=other_rect[0]+other_rect[2]  #x의 최대값:check_x+check_w
    min_check_y=other_rect[1]                #y의 최소값: check_y   
    max_check_y=other_rect[1]+other_rect[3]  #y의 최대값:check_y+check_h 
    
    #검출된 겹치는 꼭지점 개수 초기화
    total_points=0

    #좌측상단 꼭지점 확인
    if min_check_x in xrange and min_check_y in yrange:
        total_points+=1

    #우측상단 꼭지점 확인
    if max_check_x in xrange and min_check_y in yrange:
        total_points+=1

    #좌측하단 꼭지점 확인
    if max_check_y in yrange and min_check_x in xrange:
        total_points+=1

    #우측하단 꼭지점 확인
    if max_check_x in xrange and max_check_y in yrange:
        total_points+=1
    
    return total_points

###############################################################################################################################
##횡단보도와 사람객체 roi 추적 API
#디폴트 에이다 부스트를 이용한 검출 
#영상의 길이가 멀어질 수록 잘 검출이 안됨 
#사각은 정면보다 특히나 검출이 더 안됨
#트랙커 객체 생성자 함수 리스트 
trackers = [cv2.TrackerBoosting_create,
            cv2.TrackerMIL_create,
            cv2.TrackerKCF_create,
            cv2.TrackerTLD_create,
            cv2.TrackerMedianFlow_create,
            cv2.TrackerGOTURN_create, #버그로 오류 발생 안하는게 좋음
            cv2.TrackerCSRT_create,
            cv2.TrackerMOSSE_create]
trackerIdx = 0  # 트랙커 생성자 함수 선택 인덱스
tracker1 = None
tracker2 = None
isFirst = True

video_src = 0 # 비디오 파일과 카메라 선택 
video_src = "C:/Users/admin/Downloads/movies/cropped_traffic2.mp4"
cap = cv2.VideoCapture(video_src)
fps = cap.get(cv2.CAP_PROP_FPS) # 프레임 수 구하기
delay = int(1000/fps)
win_name = 'Tracking APIs'
ROIs=0
crop_imgs= [] 
while cap.isOpened():
    #global ROIs, crop_imgs
    ret, frame = cap.read()
    if not ret:
        print('Cannot read video file')
        break
    img_draw = frame.copy()
    if tracker1 is None and tracker2 is None: # 트랙커 생성 안된 경우
        cv2.putText(img_draw, "Press the Space to set ROI", \
            (100,80), cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2,cv2.LINE_AA)
    else:
        ok1, bbox1 = tracker1.update(frame)   # 새로운 프레임에서 추적 위치 찾기 
        ok2, bbox2 = tracker2.update(frame)   # 새로운 프레임에서 추적 위치 찾기 
        (x1,y1,w1,h1) = bbox1
        print('bbox1',bbox1)
        (x2,y2,w2,h2) = bbox2
        print('bbox2',bbox2)
        if ok1 and ok2: # 추적 성공
            cv2.rectangle(img_draw, (int(x1), int(y1)), (int(x1 + w1), int(y1 + h1)), \
                          (0,255,0), 2, 1) #img_draw
            cv2.rectangle(img_draw, (int(x2), int(y2)), (int(x2 + w2), int(y2 + h2)), \
                          (0,0,255), 2, 1) #img_draw
            
            #if사람 객체 roi가 횡단보도 객체roi와 겹친다면 횡단보도 보행자로 인식
            if spot_check(bbox1, bbox2)>0: #최소한 꼭지점 하나영역이 겹친다면
                cv2.putText(img_draw, "STOP!", (1000,800), cv2.FONT_HERSHEY_SIMPLEX, 10,(0,0,255),2,cv2.LINE_AA)  
            else:
                cv2.imshow(win_name, img)
        else : # 추적 실패
            cv2.putText(img_draw, "Tracking fail.", (100,80), \
                        cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2,cv2.LINE_AA)
    trackerName = tracker1.__class__.__name__
    cv2.putText(img_draw, str(trackerIdx) + ":"+trackerName , (100,20), \
                 cv2.FONT_HERSHEY_SIMPLEX, 0.75, (0,0,255),2,cv2.LINE_AA)
    cv2.imshow(win_name, img_draw)
    key = cv2.waitKey(delay) & 0xff
    # 스페이스 바 또는 비디오 파일 최초 실행 
    if (video_src != 0 and isFirst):#key == ord(' ') or (video_src != 0 and isFirst): 
        isFirst = False
        ##
        hogdef = cv2.HOGDescriptor()
        hogdef.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())
        hogdaim = cv2.HOGDescriptor((48,96), (16,16), (8,8), (8,8), 9)
        hogdaim.setSVMDetector(cv2.HOGDescriptor_getDaimlerPeopleDetector())
        cap = cv2.VideoCapture(video_src)
        #ROIs=0          
        #crop_imgs= [] 
        while cap.isOpened():
            global ROIs, crop_imgs
            ret, img = cap.read()
            if img is None:
                break
            img2 = img.copy()
            if ret :
                # resize
                img = imutils.resize(img, width = 800)  # resize1#counter to save image with different name
                # default 디텍터로 보행자 검출
                found, _ = hogdef.detectMultiScale(img)
                for (x, y, w, h) in found:
                    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 255), 2)
                cv2.putText(img, 'Detector:%s'%('Default'), (10, 50), cv2.FONT_HERSHEY_DUPLEX,1, (0, 255, 0),1)
                cv2.imshow('img', img)
                # daimler 디텍터로 보행자 검출
                key = cv2.waitKey(1)
                if key == 27:
                    break
                if key == 32: # 스페이스
                    ROIs = cv2.selectROIs("img",img)
                    crop_imgs= [] 
                    for rect in ROIs:
                        x1=rect[0]
                        y1=rect[1]
                        x2=rect[2]
                        y2=rect[3]
                        crop_imgs.append((x1,y1,x2,y2))
                    cv2.waitKey()
                    cv2.destroyWindow('Select Rois')
            else:
                break
        cap.release()
        cv2.destroyAllWindows()
        ##
        ROIs = cv2.selectROIs("Tracking APIs",img_draw)
        #이름을 다르게 지정하기 위함
#        crop_imgs= [] 
#        crop_number=0
#        for rect in ROIs:
#            x1=rect[0]
#            y1=rect[1]
#            x2=rect[2]
#            y2=rect[3]
#            crop_imgs.append((x1,y1,x2,y2))
#        cv2.destroyWindow('Select Rois')
        if len(crop_imgs) != 0:         # 위치 설정 값 있는 경우
            tracker1 = trackers[trackerIdx]()    #트랙커 객체 생성 
            isInit1 = tracker1.init(frame, crop_imgs[0]) #roi1
            tracker2 = trackers[trackerIdx]()    #트랙커 객체 생성
            print('crop_imgs[1]', crop_imgs[1])
            isInit2 = tracker2.init(frame, crop_imgs[1]) #roi2
    elif key in range(48, 56): # 0~7 숫자 입력  #근데 안될 수 있는게 있을 수도 있음
        trackerIdx = key-48     # 선택한 숫자로 트랙커 인덱스 수정
        if bbox1 is not None and bbox2 is not None:
            tracker1 = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성 
            isInit1 = tracker1.init(frame, bbox1) # 이전 추적 위치로 추적 위치 초기화
            tracker2 = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성 
            isInit2 = tracker2.init(frame, bbox2) # 이전 추적 위치로 추적 위치 초기화
    elif key == 27 : 
        break
else:
    print( "Could not open video")
cap.release()
cv2.destroyAllWindows()
# Out:
# Could not open video

# %%
#두개 합침(성공)
import cv2
import numpy as np
import imutils  # resize1
import cv2
import numpy as np

##겹치는 사각형 영역의 꼭지점 수 검출 함수
def spot_check(rect1, rect2):
    #좀더 좌측 상단에 있는 시작점을 검출해 이것을 기준으로 함
    #x좌표를 기준으로 검출
    if rect1[0] < rect2[0]:
        standard_rect = rect1
        other_rect= rect2
    else:
        standard_rect = rect2
        other_rect= rect1
    #standard 사각형 기준    
                                                           #list(range(1,3)) >>> [1,2]
    #range(          x좌표,           x좌표+가로길이(너비)+range는 미만으로 수를 잡으므로 +1 
    xrange= range(int(standard_rect[0]),int(standard_rect[0])+int(standard_rect[2])+1) 
    #range(          y좌표,           y좌표+세로길이(높이)+range는 미만으로 수를 잡으므로 +1 
    yrange= range(int(standard_rect[1]),int(standard_rect[1])+int(standard_rect[3])+1)   
    
    #겹치는지 확인하기 위한 비교대상이 되는 사각형(other_rect) 기준
    min_check_x=int(other_rect[0])                #x의 최소값: check_x
    max_check_x=int(other_rect[0]+other_rect[2])  #x의 최대값:check_x+check_w
    min_check_y=int(other_rect[1])                #y의 최소값: check_y   
    max_check_y=int(other_rect[1]+other_rect[3])  #y의 최대값:check_y+check_h 
    
    #검출된 겹치는 꼭지점 개수 초기화
    total_points=0

    #좌측상단 꼭지점 확인
    if min_check_x in xrange and min_check_y in yrange:
        total_points+=1

    #우측상단 꼭지점 확인
    if max_check_x in xrange and min_check_y in yrange:
        total_points+=1

    #좌측하단 꼭지점 확인
    if max_check_y in yrange and min_check_x in xrange:
        total_points+=1

    #우측하단 꼭지점 확인
    if max_check_x in xrange and max_check_y in yrange:
        total_points+=1
    
    return total_points


###############################################################################################################################
##횡단보도와 사람객체 roi 추적 API
"""hogdef = cv2.HOGDescriptor()
hogdef.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())
hogdaim = cv2.HOGDescriptor((48,96), (16,16), (8,8), (8,8), 9)
hogdaim.setSVMDetector(cv2.HOGDescriptor_getDaimlerPeopleDetector())
cap = cv2.VideoCapture('C:/Users/admin/Downloads/movies/cropped_traffic2.mp4')
ROIs=0          
crop_imgs= [] 
while cap.isOpened():
    global ROIs, crop_imgs
    ret, img = cap.read()
    if img is None:
        break
    img2 = img.copy()
    if ret :
        # resize
        img = imutils.resize(img, width = 800)  # resize1#counter to save image with different name
        # default 디텍터로 보행자 검출
        found, _ = hogdef.detectMultiScale(img)
        for (x, y, w, h) in found:
            cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 255), 2)
        cv2.putText(img, 'Detector:%s'%('Default'), (10, 50), cv2.FONT_HERSHEY_DUPLEX,1, (0, 255, 0),1)
        cv2.imshow('img', img)
        # daimler 디텍터로 보행자 검출
        key = cv2.waitKey(1)
        if key == 27:
            break
        if key == 32: # 스페이스
            ROIs = cv2.selectROIs("img",img)
            crop_imgs= [] 
            for rect in ROIs:
                x1=rect[0]
                y1=rect[1]
                x2=rect[2]
                y2=rect[3]
                crop_imgs.append((x1,y1,x2,y2))
            cv2.waitKey()
            cv2.destroyWindow('Select Rois')
    else:
        break
cap.release()
cv2.destroyAllWindows()"""

##겹치는 사각형 영역의 꼭지점 수 검출 함수
def spot_check(rect1, rect2):
    #좀더 좌측 상단에 있는 시작점을 검출해 이것을 기준으로 함
    #x좌표를 기준으로 검출
    if int(rect1[0]) < int(rect2[0]):
        standard_rect = rect1
        other_rect= rect2
    else:
        standard_rect = rect2
        other_rect= rect1
    #standard 사각형 기준    
                                                           #list(range(1,3)) >>> [1,2]
    #range(          x좌표,           x좌표+가로길이(너비)+range는 미만으로 수를 잡으므로 +1 
    xrange= range(int(standard_rect[0]),int(standard_rect[0])+int(standard_rect[2])+1) 
    #range(          y좌표,           y좌표+세로길이(높이)+range는 미만으로 수를 잡으므로 +1 
    yrange= range(int(standard_rect[1]),int(standard_rect[1])+int(standard_rect[3])+1)   
    
    #겹치는지 확인하기 위한 비교대상이 되는 사각형(other_rect) 기준
    min_check_x=int(other_rect[0])                #x의 최소값: check_x
    max_check_x=int(other_rect[0])+int(other_rect[2])  #x의 최대값:check_x+check_w
    min_check_y=int(other_rect[1])                #y의 최소값: check_y   
    max_check_y=int(other_rect[1])+int(other_rect[3])  #y의 최대값:check_y+check_h 
    
    #검출된 겹치는 꼭지점 개수 초기화
    total_points=0

    #좌측상단 꼭지점 확인
    if min_check_x in xrange and min_check_y in yrange:
        total_points+=1

    #우측상단 꼭지점 확인
    if max_check_x in xrange and min_check_y in yrange:
        total_points+=1

    #좌측하단 꼭지점 확인
    if max_check_y in yrange and min_check_x in xrange:
        total_points+=1

    #우측하단 꼭지점 확인
    if max_check_x in xrange and max_check_y in yrange:
        total_points+=1
    
    return total_points

###############################################################################################################################
##횡단보도와 사람객체 roi 추적 API
#디폴트 에이다 부스트를 이용한 검출 
#영상의 길이가 멀어질 수록 잘 검출이 안됨 
#사각은 정면보다 특히나 검출이 더 안됨
#트랙커 객체 생성자 함수 리스트 
trackers = [cv2.TrackerBoosting_create,
            cv2.TrackerMIL_create,
            cv2.TrackerKCF_create,
            cv2.TrackerTLD_create,
            cv2.TrackerMedianFlow_create,
            cv2.TrackerGOTURN_create, #버그로 오류 발생 안하는게 좋음
            cv2.TrackerCSRT_create,
            cv2.TrackerMOSSE_create]
trackerIdx = 0  # 트랙커 생성자 함수 선택 인덱스
tracker1 = None
tracker2 = None
isFirst = True

video_src = 0 # 비디오 파일과 카메라 선택 
video_src = "C:/Users/admin/Downloads/movies/cropped_traffic2.mp4"
cap = cv2.VideoCapture(video_src)
fps = cap.get(cv2.CAP_PROP_FPS) # 프레임 수 구하기
delay = int(1000/fps)
win_name = 'Tracking APIs'
ROIs=0
crop_imgs= [] 
while cap.isOpened():
    ret, frame = cap.read()
    frame = imutils.resize(frame, width = 800)  # resize1#counter to save image with different name
    if not ret:
        print('Cannot read video file')
        break
    img_draw = frame.copy()
    if tracker1 is None and tracker2 is None: # 트랙커 생성 안된 경우
        cv2.putText(img_draw, "Press the Space to set ROI", \
            (100,80), cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2,cv2.LINE_AA)
    else:
        ok1, bbox1 = tracker1.update(frame)   # 새로운 프레임에서 추적 위치 찾기 
        ok2, bbox2 = tracker2.update(frame)   # 새로운 프레임에서 추적 위치 찾기 
        (x1,y1,w1,h1) = bbox1
        #print('bbox1',bbox1)
        (x2,y2,w2,h2) = bbox2
        #print('bbox2',bbox2)
        if ok1 and ok2: # 추적 성공
            cv2.rectangle(img_draw, (int(x1), int(y1)), (int(x1 + w1), int(y1 + h1)), \
                          (0,255,0), 2, 1) #img_draw
            cv2.rectangle(img_draw, (int(x2), int(y2)), (int(x2 + w2), int(y2 + h2)), \
                          (0,0,255), 2, 1) #img_draw
            #if사람 객체 roi가 횡단보도 객체roi와 겹친다면 횡단보도 보행자로 인식
            if spot_check(bbox1, bbox2)>0: #최소한 꼭지점 하나영역이 겹친다면 
                cv2.putText(img_draw, "STOP!", (100,80), cv2.FONT_HERSHEY_SIMPLEX, 2,(0,0,255),2,cv2.LINE_AA)  
            else:
                 cv2.putText(img_draw, "", (100,80), cv2.FONT_HERSHEY_SIMPLEX, 2,(0,0,255),2,cv2.LINE_AA)
        else : # 추적 실패
            cv2.putText(img_draw, "Tracking fail.", (100,80), \
                        cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2,cv2.LINE_AA)
    trackerName = tracker1.__class__.__name__
    cv2.putText(img_draw, str(trackerIdx) + ":"+trackerName , (100,20), \
                 cv2.FONT_HERSHEY_SIMPLEX, 0.75, (0,0,255),2,cv2.LINE_AA)
    cv2.imshow(win_name, img_draw)
    key = cv2.waitKey(delay) & 0xff
    # 스페이스 바 또는 비디오 파일 최초 실행 
    if (video_src != 0 and isFirst):#key == ord(' ') or (video_src != 0 and isFirst): 
        isFirst = False
        ##
        hogdef = cv2.HOGDescriptor()
        hogdef.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())
        hogdaim = cv2.HOGDescriptor((48,96), (16,16), (8,8), (8,8), 9)
        hogdaim.setSVMDetector(cv2.HOGDescriptor_getDaimlerPeopleDetector())
        cap = cv2.VideoCapture(video_src)
        while cap.isOpened():
            global ROIs, crop_imgs 
            ret, img = cap.read()
            if img is None:
                break
            img2 = img.copy()
            if ret :
                # resize
                img = imutils.resize(img, width = 800)  # resize1#counter to save image with different name
                # default 디텍터로 보행자 검출
                found, _ = hogdef.detectMultiScale(img)
                for (x, y, w, h) in found:
                    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 255), 2)
                cv2.putText(img, 'Detector:%s'%('Default'), (10, 50), cv2.FONT_HERSHEY_DUPLEX,1, (0, 255, 0),1)
                cv2.imshow(win_name, img)
                # daimler 디텍터로 보행자 검출
                key = cv2.waitKey(1)
                if key == 27:
                    break
                if key == 32: # 스페이스
                    ROIs = cv2.selectROIs(win_name,img)
                    crop_imgs= [] 
                    for rect in ROIs:
                        x1=rect[0]
                        y1=rect[1]
                        x2=rect[2]
                        y2=rect[3]
                        crop_imgs.append((x1,y1,x2,y2))
                    cv2.waitKey()
            else:
                break
        if len(crop_imgs) != 0:         # 위치 설정 값 있는 경우
            tracker1 = trackers[trackerIdx]()    #트랙커 객체 생성 
            isInit1 = tracker1.init(frame, crop_imgs[0]) #roi1
            tracker2 = trackers[trackerIdx]()    #트랙커 객체 생성
            isInit2 = tracker2.init(frame, crop_imgs[1]) #roi2
    elif key in range(48, 56): # 0~7 숫자 입력  #근데 안될 수 있는게 있을 수도 있음
        trackerIdx = key-48     # 선택한 숫자로 트랙커 인덱스 수정
        if bbox1 is not None and bbox2 is not None:
            tracker1 = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성 
            isInit1 = tracker1.init(frame, bbox1) # 이전 추적 위치로 추적 위치 초기화
            tracker2 = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성 
            isInit2 = tracker2.init(frame, bbox2) # 이전 추적 위치로 추적 위치 초기화
    elif key == 27 : 
        break
else:
    print( "Could not open video")
cap.release()
cv2.destroyAllWindows()

# %%
# Out:
# 210
# 1770

# %%
#신호등까지 합치기

import cv2
import numpy as np
import imutils  # resize1
import cv2
import numpy as np


#
#신호등
def set_blob_param(r_type: str):
    # BLOB 필터 생성하기 
    params = cv2.SimpleBlobDetector_Params()
    
    params.minThreshold = 10
    params.maxThreshold = 240
    params.thresholdStep = 3
    params.filterByArea = False
    params.filterByColor = False
    params.filterByCircularity = True
    params.filterByConvexity = False 
    params.filterByInertia = False 
    
    if r_type == 'color':
        # 경계 값 조정
        params.minCircularity = 0.8
        params.maxCircularity = 1     
    elif r_type == 'shape':
        params.filterByArea = True 
        params.minArea = 100
        params.maxArea = 250
        
        params.filterByColor = False
#         params.blobColor = 0
        
        params.minCircularity = 0.4
        params.maxCircularity = 0.8
    
    return params 
############################################################################

# 신호등으로 추정되는 영역 검출 
def subtract_shape(img):
    global k, h, w   # 모폴로지 연산 필터 
    
    #res_s = cv2.resize(img, (800, 800)) 이미 있으므로 삭제
    #res_s=frame
    #img = cv2.resize(img, (800, 800)) 
    
    #img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) #stop 글자가 보여서 안보이는 프레임으로 함
    img_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    #기존 영상이미지에 차이가 있으므로 비율 수정
    roi_s = img_gray[int((0.2)*w):int((3) * w), int((0.2)*h): int((3)*h)]

    ret, th = cv2.threshold(roi_s, 55, 255, cv2.THRESH_BINARY)
    #cv2.imshow('th', th) 
    dst_s = cv2.morphologyEx(th, cv2.MORPH_OPEN, k)   # 모폴로지 열기 연산 
    #필터 확인
    edge_s = cv2.Laplacian(dst_s, -2)
    #edge_s = cv2.Canny(frame, 100, 200)
    #cv2.imshow('edge_s', edge_s)
    #cv2.imshow('dst', dst_s)
    detector = cv2.SimpleBlobDetector_create(param_s)
    
    s_keypoints = detector.detect(edge_s)
    img_draw_s = cv2.drawKeypoints(roi_s, s_keypoints, None, None, cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS) 
            
    global shape_list 
    
    for s_keypoint in s_keypoints:
        roi_cx, roi_cy = map(int, s_keypoint.pt)
        #바로 밑의줄 ?? 모르겠음
        cx, cy = int(roi_cx + h * (1/5)), int(roi_cy + w * (1/5))
        cv2.putText(img_gray, '!', (cx, cy), cv2.FONT_HERSHEY_TRIPLEX, 1,(255, 255, 255))
        size = int(s_keypoint.size)
        cx2, cy2 = cx + size // 2, cy + size // 2    
        shape_list.append([cx, cx2, cy, cy2])
    
#     cv2.imshow('img_gray', img_gray)     
#     print(len(s_keypoints))
    return shape_list  

###########
# 신호등 색상에 해당되는 영역 검출 
def subtract_color(img, color):
    global k, w, h   # 모폴로지 연산 필터 
    
    lower_green = np.array([50, 50, 80]); upper_green = np.array([90, 255, 255])
    lower_red = np.array([-10, 50, 50]);  upper_red = np.array([10, 255, 255])
    lower_yellow = np.array([11, 50, 50]); upper_yellow = np.array([30, 255, 255])
    
    #res_c = cv2.resize(img, (700, 500)) 안씀
    img_hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
                          #res_c    
    roi_c = img_hsv[int((0.2)*w):int((3) * w), int((0.2)*h): int((3)*h)]

    if color == 'red_yellow':
        mask1 = cv2.inRange(roi_c, lower_red, upper_red)
        mask2 = cv2.inRange(roi_c, lower_yellow, upper_yellow)
        
        mask = cv2.bitwise_or(mask1, mask2)   # 색상 부분 추출 
    elif color == 'green':
        mask = cv2.inRange(roi_c, lower_green, upper_green)   
        
    #cv2.imshow('mask', mask)
    img_mask = cv2.bitwise_and(roi_c, roi_c, mask=mask)
    edge_c = cv2.Laplacian(img_mask, -1)
    dst_c = cv2.morphologyEx(edge_c, cv2.MORPH_OPEN, k)   # 모폴로지 닫기 연산 
    #cv2.imshow('dst_c', dst_c) #이렇게 검출이 생각보다 잘 안된다는 거 확인
    #cv2.imshow('res', redds) redds가 없음  

    detector = cv2.SimpleBlobDetector_create(param_c)
    c_keypoints = detector.detect(edge_c)
    img_draw_c = cv2.drawKeypoints(roi_c, c_keypoints, None, None, cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
    #cv2.imshow('roi_c', roi_c) 맨 마지막이 멈춤
    
    global color_list 
    
    for c_keypoint in c_keypoints:
        roi_cx, roi_cy = map(int, c_keypoint.pt)
        cx, cy = int(roi_cx + h * (1/5)), int(roi_cy + w * (1/5))
        cv2.putText(img_hsv, '!', (cx, cy), cv2.FONT_HERSHEY_TRIPLEX, 1,(255, 255, 255))
        size = int(c_keypoint.size)
        cx2, cy2 = cx + size // 2, cy + size // 2 
        color_list.append([cx, cx2, cy, cy2])
    
        cv2.imshow('img_hsv', img_hsv)    
#     print(color_list)
    return color_list

# 겹치는 구간 판단 
#def check_location(shape_list, color_list):   # 직사각형 겹치는 좌표 개수 구하기 
#    global tl_flag, img_draw 
#    for a1, a2, b1, b2 in color_list:
#        for x1, x2, y1, y2 in shape_list:
#            if ((a1 >= x1 and a1 <= x2) and (b1 >= y1 and b1 <= y2)) and tl_flag == False:
#                input_str= (img_draw, 'Traffic Light Detected !', (10, 50), cv2.FONT_HERSHEY_TRIPLEX, 1,(255, 255, 255))
#                tl_flag_input = True
                #cv2.imshow('img_draw', img_draw) 
                #tl_flag = True                                   #a1, b1       
                
##########################################################################
##겹치는 사각형 영역의 꼭지점 수 검출 함수
def spot_check(rect1, rect2):
    #좀더 좌측 상단에 있는 시작점을 검출해 이것을 기준으로 함
    #x좌표를 기준으로 검출
    if rect1[0] < rect2[0]:
        standard_rect = rect1
        other_rect= rect2
    else:
        standard_rect = rect2
        other_rect= rect1
    #standard 사각형 기준    
                                                           #list(range(1,3)) >>> [1,2]
    #range(          x좌표,           x좌표+가로길이(너비)+range는 미만으로 수를 잡으므로 +1 
    xrange= range(int(standard_rect[0]),int(standard_rect[0])+int(standard_rect[2])+1) 
    #range(          y좌표,           y좌표+세로길이(높이)+range는 미만으로 수를 잡으므로 +1 
    yrange= range(int(standard_rect[1]),int(standard_rect[1])+int(standard_rect[3])+1)   
    
    #겹치는지 확인하기 위한 비교대상이 되는 사각형(other_rect) 기준
    min_check_x=int(other_rect[0])                #x의 최소값: check_x
    max_check_x=int(other_rect[0]+other_rect[2])  #x의 최대값:check_x+check_w
    min_check_y=int(other_rect[1])                #y의 최소값: check_y   
    max_check_y=int(other_rect[1]+other_rect[3])  #y의 최대값:check_y+check_h 
    
    #검출된 겹치는 꼭지점 개수 초기화
    total_points=0

    #좌측상단 꼭지점 확인
    if min_check_x in xrange and min_check_y in yrange:
        total_points+=1

    #우측상단 꼭지점 확인
    if max_check_x in xrange and min_check_y in yrange:
        total_points+=1

    #좌측하단 꼭지점 확인
    if max_check_y in yrange and min_check_x in xrange:
        total_points+=1

    #우측하단 꼭지점 확인
    if max_check_x in xrange and max_check_y in yrange:
        total_points+=1
    
    return total_points


###############################################################################################################################

##겹치는 사각형 영역의 꼭지점 수 검출 함수
def spot_check(rect1, rect2):
    #좀더 좌측 상단에 있는 시작점을 검출해 이것을 기준으로 함
    #x좌표를 기준으로 검출
    if int(rect1[0]) < int(rect2[0]):
        standard_rect = rect1
        other_rect= rect2
    else:
        standard_rect = rect2
        other_rect= rect1
    #standard 사각형 기준    
                                                           #list(range(1,3)) >>> [1,2]
    #range(          x좌표,           x좌표+가로길이(너비)+range는 미만으로 수를 잡으므로 +1 
    xrange= range(int(standard_rect[0]),int(standard_rect[0])+int(standard_rect[2])+1) 
    #range(          y좌표,           y좌표+세로길이(높이)+range는 미만으로 수를 잡으므로 +1 
    yrange= range(int(standard_rect[1]),int(standard_rect[1])+int(standard_rect[3])+1)   
    
    #겹치는지 확인하기 위한 비교대상이 되는 사각형(other_rect) 기준
    min_check_x=int(other_rect[0])                #x의 최소값: check_x
    max_check_x=int(other_rect[0])+int(other_rect[2])  #x의 최대값:check_x+check_w
    min_check_y=int(other_rect[1])                #y의 최소값: check_y   
    max_check_y=int(other_rect[1])+int(other_rect[3])  #y의 최대값:check_y+check_h 
    
    #검출된 겹치는 꼭지점 개수 초기화
    total_points=0

    #좌측상단 꼭지점 확인
    if min_check_x in xrange and min_check_y in yrange:
        total_points+=1

    #우측상단 꼭지점 확인
    if max_check_x in xrange and min_check_y in yrange:
        total_points+=1

    #좌측하단 꼭지점 확인
    if max_check_y in yrange and min_check_x in xrange:
        total_points+=1

    #우측하단 꼭지점 확인
    if max_check_x in xrange and max_check_y in yrange:
        total_points+=1
    
    return total_points

###############################################################################################################################
##횡단보도와 사람객체 roi 추적 API
#디폴트 에이다 부스트를 이용한 검출 
#영상의 길이가 멀어질 수록 잘 검출이 안됨 
#사각은 정면보다 특히나 검출이 더 안됨
#트랙커 객체 생성자 함수 리스트 
trackers = [cv2.TrackerBoosting_create,
            cv2.TrackerMIL_create,
            cv2.TrackerKCF_create,
            cv2.TrackerTLD_create,
            cv2.TrackerMedianFlow_create,
            cv2.TrackerGOTURN_create, #버그로 오류 발생 안하는게 좋음
            cv2.TrackerCSRT_create,
            cv2.TrackerMOSSE_create]
trackerIdx = 0  # 트랙커 생성자 함수 선택 인덱스
tracker1 = None
tracker2 = None
isFirst = True

video_src = 0 # 비디오 파일과 카메라 선택 
video_src = "C:/Users/admin/Downloads/movies/cropped_traffic2.mp4"
cap = cv2.VideoCapture(video_src)
fps = cap.get(cv2.CAP_PROP_FPS) # 프레임 수 구하기
delay = int(1000/fps)
win_name = 'Tracking APIs'
ROIs=0
crop_imgs= [] 


param_c = set_blob_param('color')
param_s = set_blob_param('shape')
k = cv2.getStructuringElement(cv2.MORPH_RECT, (2, 2))   # 모폴로지 연산 필터 
shape_list = []
color_list = [] 
w = 800; h = 800      

while cap.isOpened():
    global fps, delay,k
    #global tl_flag #, shape_list, color_list #위의 것들을 추가해야하는지 고민
    #fps = cap.get(cv2.CAP_PROP_FPS) 
    #delay = int(1000/fps)
    #param_c = set_blob_param('color')
    #param_s = set_blob_param('shape')
    #k = cv2.getStructuringElement(cv2.MORPH_RECT, (2, 2))   # 모폴로지 연산 필터 

    
    ret, frame = cap.read()
    
    frame = imutils.resize(frame, width = 800)  # resize1#counter to save image with different name
    if not ret:
        print('Cannot read video file')
        break
    img_draw = frame.copy()
    if tracker1 is None and tracker2 is None: # 트랙커 생성 안된 경우
        cv2.putText(img_draw, "Press the Space to set ROI", \
            (100,80), cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2,cv2.LINE_AA)
    else:
        ok1, bbox1 = tracker1.update(frame)   # 새로운 프레임에서 추적 위치 찾기 
        ok2, bbox2 = tracker2.update(frame)   # 새로운 프레임에서 추적 위치 찾기 
        (x1,y1,w1,h1) = bbox1
        #print('bbox1',bbox1)
        (x2,y2,w2,h2) = bbox2
        #print('bbox2',bbox2)
        if ok1 and ok2: # 추적 성공
            cv2.rectangle(img_draw, (int(x1), int(y1)), (int(x1 + w1), int(y1 + h1)), \
                          (0,255,0), 2, 1) #img_draw
            cv2.rectangle(img_draw, (int(x2), int(y2)), (int(x2 + w2), int(y2 + h2)), \
                          (0,0,255), 2, 1) #img_draw

            #if사람 객체 roi가 횡단보도 객체roi와 겹친다면 횡단보도 보행자로 인식
            if spot_check(bbox1, bbox2)>0: #최소한 꼭지점 하나영역이 겹친다면 
                cv2.putText(img_draw, "STOP!", (100,80), cv2.FONT_HERSHEY_SIMPLEX, 2,(0,0,255),2,cv2.LINE_AA)  
                shape_list = subtract_shape(img_draw)
                #print('shape_list', shape_list) 
                color_list = subtract_color(img_draw, 'green')
                #print('color_list', color_list)
                tl_flag = False 
                for a1, a2, b1, b2 in color_list:
                    for x1, x2, y1, y2 in shape_list:
                        if ((a1 >= x1 and a1 <= x2) and (b1 >= y1 and b1 <= y2)) and tl_flag == False:
                            cv2.putText(img_draw, 'Car_Traffic Light Detected!', (100, 120), cv2.FONT_HERSHEY_TRIPLEX, 1,(255, 255, 255))
                            tl_flag = True 

            else:
                cv2.putText(img_draw, "", (100,80), cv2.FONT_HERSHEY_SIMPLEX, 2,(0,0,255),2,cv2.LINE_AA)
        else : # 추적 실패
            cv2.putText(img_draw, "Tracking fail.", (100,80), \
                        cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2,cv2.LINE_AA)
    trackerName = tracker1.__class__.__name__
    cv2.putText(img_draw, str(trackerIdx) + ":"+trackerName , (100,20), \
                 cv2.FONT_HERSHEY_SIMPLEX, 0.75, (0,0,255),2,cv2.LINE_AA)

    cv2.imshow(win_name, img_draw)
    key = cv2.waitKey(delay) & 0xff
    # 스페이스 바 또는 비디오 파일 최초 실행 
    if (video_src != 0 and isFirst):#key == ord(' ') or (video_src != 0 and isFirst): 
        isFirst = False
        ##
        hogdef = cv2.HOGDescriptor()
        hogdef.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())
        hogdaim = cv2.HOGDescriptor((48,96), (16,16), (8,8), (8,8), 9)
        hogdaim.setSVMDetector(cv2.HOGDescriptor_getDaimlerPeopleDetector())
        cap = cv2.VideoCapture(video_src)
        while cap.isOpened():
            global ROIs, crop_imgs
            ret, img = cap.read()
            if img is None:
                break
            img2 = img.copy()
            if ret :
                # resize
                img = imutils.resize(img, width = 800)  # resize1#counter to save image with different name
                # default 디텍터로 보행자 검출
                found, _ = hogdef.detectMultiScale(img)
                for (x, y, w, h) in found:
                    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 255), 2)
                cv2.putText(img, 'Detector:%s'%('Default'), (10, 50), cv2.FONT_HERSHEY_DUPLEX,1, (0, 255, 0),1)
                cv2.imshow(win_name, img)
                # daimler 디텍터로 보행자 검출
                key = cv2.waitKey(1)
                if key == 27:
                    break
                if key == 32: # 스페이스
                    ROIs = cv2.selectROIs(win_name,img)
                    crop_imgs= [] 
                    for rect in ROIs:
                        x1=rect[0]
                        y1=rect[1]
                        x2=rect[2]
                        y2=rect[3]
                        crop_imgs.append((x1,y1,x2,y2))
                    cv2.waitKey()
            else:
                break
        if len(crop_imgs) != 0:         # 위치 설정 값 있는 경우
            tracker1 = trackers[trackerIdx]()    #트랙커 객체 생성 
            isInit1 = tracker1.init(frame, crop_imgs[0]) #roi1
            tracker2 = trackers[trackerIdx]()    #트랙커 객체 생성
            isInit2 = tracker2.init(frame, crop_imgs[1]) #roi2
    elif key in range(48, 56): # 0~7 숫자 입력  #근데 안될 수 있는게 있을 수도 있음
        trackerIdx = key-48     # 선택한 숫자로 트랙커 인덱스 수정
        if bbox1 is not None and bbox2 is not None:
            tracker1 = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성 
            isInit1 = tracker1.init(frame, bbox1) # 이전 추적 위치로 추적 위치 초기화
            tracker2 = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성 
            isInit2 = tracker2.init(frame, bbox2) # 이전 추적 위치로 추적 위치 초기화
    elif key == 27 : 
        break
else:
    print( "Could not open video")
cap.release()
cv2.destroyAllWindows()

# %%
#세가지 기능을 합친 코드
#차량 신호등이 초록색일 때 횡단보도 보행자 검출
#현재 코드는 2번 기준
"""
검출조건#######################################

차량 신호등에서의 초록불일때를 검출할 때가 시간이 오래 걸려서
1번. if 횡단보도 보행자일 때
   if 차량 신호등이 초록불일때
      텍스트 출력
     
조건으로 하거나
     
2번. if 차량 신호등이 초록불일때
   if 횡단보도 보행자일 때
      텍스트 출력
     
하는데 출력시간은 동일

다만 횡단보도 보행자 출력을 먼저했을 때 눈에 보이는 텍스트가 더 먼저 검출되서
(횡단보도 보행자 출력은 바로바로 나옴)
이후에 차량용 신호등이 초록불일 때 텍스트가 늦게 출력됨 
따라서 1기준으로 하는것이 좋아보임     

사용방법######################################

원하는 시점에 spacebar로 화면 1차 정지
드래그 1번째 ROI 등록 + spacebar
드래그 2번째 ROI 등록 + spacebar
(반드시 ROI는 두개만 등록하도록 한다 그 이상 지정하면 error)
esc
esc

이슈사항#######################################
-재동님이 사용했던 영상 이미지기준 코드를 사용했는데 신호등 영역이 다르게 잡혀서 임의로 제가 수정해서 신호등 영역의 범위 int()부분을 제가 수정
-사용한 영상은 cropped_traffic2.mp4 영상을 사용
-check_location함수를 제외하고 함수 그대로 안의 인자코드만 수정했고
 check_location함수만 해체해서 코드에 이식 
 자세한 내용은 1번째 조건부여, 2번째 조건부여 주석 확인
    
"""

import cv2
import numpy as np
import imutils  # resize1
import cv2
import numpy as np

#신호등
def set_blob_param(r_type: str):
    # BLOB 필터 생성하기 
    params = cv2.SimpleBlobDetector_Params()
    
    params.minThreshold = 10
    params.maxThreshold = 240
    params.thresholdStep = 3
    params.filterByArea = False
    params.filterByColor = False
    params.filterByCircularity = True
    params.filterByConvexity = False 
    params.filterByInertia = False 
    
    if r_type == 'color':
        # 경계 값 조정
        params.minCircularity = 0.8
        params.maxCircularity = 1     
    elif r_type == 'shape':
        params.filterByArea = True 
        params.minArea = 100
        params.maxArea = 250
        
        params.filterByColor = False
#         params.blobColor = 0
        
        params.minCircularity = 0.4
        params.maxCircularity = 0.8
    
    return params 

# 신호등으로 추정되는 영역 검출 
def subtract_shape(img):
    global k, h, w   # 모폴로지 연산 필터 
    
    img_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    roi_s = img_gray[int((0.2)*w):int((3) * w), int((0.2)*h): int((3)*h)]

    ret, th = cv2.threshold(roi_s, 55, 255, cv2.THRESH_BINARY)
    dst_s = cv2.morphologyEx(th, cv2.MORPH_OPEN, k)   # 모폴로지 열기 연산 
    #필터 확인
    edge_s = cv2.Laplacian(dst_s, -2)
    detector = cv2.SimpleBlobDetector_create(param_s)
    
    s_keypoints = detector.detect(edge_s)
    img_draw_s = cv2.drawKeypoints(roi_s, s_keypoints, None, None, cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS) 
            
    global shape_list 
    
    for s_keypoint in s_keypoints:
        roi_cx, roi_cy = map(int, s_keypoint.pt)
        cx, cy = int(roi_cx + h * (1/5)), int(roi_cy + w * (1/5))
        cv2.putText(img_gray, '!', (cx, cy), cv2.FONT_HERSHEY_TRIPLEX, 1,(255, 255, 255))
        size = int(s_keypoint.size)
        shape_list.append([cx, cx2, cy, cy2])
    cv2.imshow('gray_gray', img_gray) 
    return shape_list  

###########
# 신호등 색상에 해당되는 영역 검출 
def subtract_color(img, color):
    global k, w, h   # 모폴로지 연산 필터 
    
    lower_green = np.array([50, 50, 80]); upper_green = np.array([90, 255, 255])
    lower_red = np.array([-10, 50, 50]);  upper_red = np.array([10, 255, 255])
    lower_yellow = np.array([11, 50, 50]); upper_yellow = np.array([30, 255, 255])
    
    img_hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    roi_c = img_hsv[int((0.2)*w):int((3) * w), int((0.2)*h): int((3)*h)]

    if color == 'red_yellow':
        mask1 = cv2.inRange(roi_c, lower_red, upper_red)
        mask2 = cv2.inRange(roi_c, lower_yellow, upper_yellow)
        
        mask = cv2.bitwise_or(mask1, mask2)   # 색상 부분 추출 
    elif color == 'green':
        mask = cv2.inRange(roi_c, lower_green, upper_green)   
        
    img_mask = cv2.bitwise_and(roi_c, roi_c, mask=mask)
    edge_c = cv2.Laplacian(img_mask, -1)
    dst_c = cv2.morphologyEx(edge_c, cv2.MORPH_OPEN, k)   # 모폴로지 닫기 연산 

    detector = cv2.SimpleBlobDetector_create(param_c)
    c_keypoints = detector.detect(edge_c)
    img_draw_c = cv2.drawKeypoints(roi_c, c_keypoints, None, None, cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
    
    global color_list 
    
    for c_keypoint in c_keypoints:
        roi_cx, roi_cy = map(int, c_keypoint.pt)
        cx, cy = int(roi_cx + h * (1/5)), int(roi_cy + w * (1/5))
        cv2.putText(img_hsv, '!', (cx, cy), cv2.FONT_HERSHEY_TRIPLEX, 1,(255, 255, 255))
        size = int(c_keypoint.size)
        cx2, cy2 = cx + size // 2, cy + size // 2 
        color_list.append([cx, cx2, cy, cy2])
    
        cv2.imshow('img_hsv', img_hsv)    
        
    return color_list
                
##########################################################################
##겹치는 사각형 영역의 꼭지점 수 검출 함수
def spot_check(rect1, rect2):
    #좀더 좌측 상단에 있는 시작점을 검출해 이것을 기준으로 함
    #x좌표를 기준으로 검출
    if rect1[0] < rect2[0]:
        standard_rect = rect1
        other_rect= rect2
    else:
        standard_rect = rect2
        other_rect= rect1
    #standard 사각형 기준    
                                                           #list(range(1,3)) >>> [1,2]
    #range(          x좌표,           x좌표+가로길이(너비)+range는 미만으로 수를 잡으므로 +1 
    xrange= range(int(standard_rect[0]),int(standard_rect[0])+int(standard_rect[2])+1) 
    #range(          y좌표,           y좌표+세로길이(높이)+range는 미만으로 수를 잡으므로 +1 
    yrange= range(int(standard_rect[1]),int(standard_rect[1])+int(standard_rect[3])+1)   
    
    #겹치는지 확인하기 위한 비교대상이 되는 사각형(other_rect) 기준
    min_check_x=int(other_rect[0])                #x의 최소값: check_x
    max_check_x=int(other_rect[0]+other_rect[2])  #x의 최대값:check_x+check_w
    min_check_y=int(other_rect[1])                #y의 최소값: check_y   
    max_check_y=int(other_rect[1]+other_rect[3])  #y의 최대값:check_y+check_h 
    
    #검출된 겹치는 꼭지점 개수 초기화
    total_points=0

    #좌측상단 꼭지점 확인
    if min_check_x in xrange and min_check_y in yrange:
        total_points+=1

    #우측상단 꼭지점 확인
    if max_check_x in xrange and min_check_y in yrange:
        total_points+=1

    #좌측하단 꼭지점 확인
    if max_check_y in yrange and min_check_x in xrange:
        total_points+=1

    #우측하단 꼭지점 확인
    if max_check_x in xrange and max_check_y in yrange:
        total_points+=1
    
    return total_points


###############################################################################################################################

##겹치는 사각형 영역의 꼭지점 수 검출 함수
def spot_check(rect1, rect2):
    #좀더 좌측 상단에 있는 시작점을 검출해 이것을 기준으로 함
    #x좌표를 기준으로 검출
    if int(rect1[0]) < int(rect2[0]):
        standard_rect = rect1
        other_rect= rect2
    else:
        standard_rect = rect2
        other_rect= rect1
    #standard 사각형 기준    
                                                           #list(range(1,3)) >>> [1,2]
    #range(          x좌표,           x좌표+가로길이(너비)+range는 미만으로 수를 잡으므로 +1 
    xrange= range(int(standard_rect[0]),int(standard_rect[0])+int(standard_rect[2])+1) 
    #range(          y좌표,           y좌표+세로길이(높이)+range는 미만으로 수를 잡으므로 +1 
    yrange= range(int(standard_rect[1]),int(standard_rect[1])+int(standard_rect[3])+1)   
    
    #겹치는지 확인하기 위한 비교대상이 되는 사각형(other_rect) 기준
    min_check_x=int(other_rect[0])                #x의 최소값: check_x
    max_check_x=int(other_rect[0])+int(other_rect[2])  #x의 최대값:check_x+check_w
    min_check_y=int(other_rect[1])                #y의 최소값: check_y   
    max_check_y=int(other_rect[1])+int(other_rect[3])  #y의 최대값:check_y+check_h 
    
    #검출된 겹치는 꼭지점 개수 초기화
    total_points=0

    #좌측상단 꼭지점 확인
    if min_check_x in xrange and min_check_y in yrange:
        total_points+=1

    #우측상단 꼭지점 확인
    if max_check_x in xrange and min_check_y in yrange:
        total_points+=1

    #좌측하단 꼭지점 확인
    if max_check_y in yrange and min_check_x in xrange:
        total_points+=1

    #우측하단 꼭지점 확인
    if max_check_x in xrange and max_check_y in yrange:
        total_points+=1
    
    return total_points

###############################################################################################################################
##횡단보도와 사람객체 roi 추적 API
#디폴트 에이다 부스트를 이용한 검출 
#영상의 길이가 멀어질 수록 잘 검출이 안됨 
#사각은 정면보다 특히나 검출이 더 안됨
#트랙커 객체 생성자 함수 리스트 
trackers = [cv2.TrackerBoosting_create,
            cv2.TrackerMIL_create,
            cv2.TrackerKCF_create,
            cv2.TrackerTLD_create,
            cv2.TrackerMedianFlow_create,
            cv2.TrackerGOTURN_create, #버그로 오류 발생 안하는게 좋음
            cv2.TrackerCSRT_create,
            cv2.TrackerMOSSE_create]
trackerIdx = 0  # 트랙커 생성자 함수 선택 인덱스
tracker1 = None
tracker2 = None
isFirst = True

video_src = 0 # 비디오 파일과 카메라 선택 
video_src = "C:/Users/admin/Downloads/movies/cropped_traffic2.mp4"
cap = cv2.VideoCapture(video_src)
fps = cap.get(cv2.CAP_PROP_FPS) # 프레임 수 구하기
delay = int(1000/fps)
win_name = 'Tracking APIs'
ROIs=0
crop_imgs= [] 

param_c = set_blob_param('color')
param_s = set_blob_param('shape')
k = cv2.getStructuringElement(cv2.MORPH_RECT, (2, 2))   # 모폴로지 연산 필터 
shape_list = []
color_list = [] 
w = 800; h = 800      

while cap.isOpened():
    global fps, delay,k    
    ret, frame = cap.read()
    
    frame = imutils.resize(frame, width = 800)  # resize1
    
    if not ret:
        print('Cannot read video file')
        break
    img_draw = frame.copy()
    if tracker1 is None and tracker2 is None: # 트랙커 생성 안된 경우
        cv2.putText(img_draw, "Press the Space to set ROI", \
            (100,80), cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2,cv2.LINE_AA)
    else:
        ok1, bbox1 = tracker1.update(frame)   # 새로운 프레임에서 추적 위치 찾기 
        ok2, bbox2 = tracker2.update(frame)   # 새로운 프레임에서 추적 위치 찾기 
        (x1,y1,w1,h1) = bbox1
        #print('bbox1',bbox1)
        (x2,y2,w2,h2) = bbox2
        #print('bbox2',bbox2)
                
        if ok1 and ok2: # 추적 성공
            cv2.rectangle(img_draw, (int(x1), int(y1)), (int(x1 + w1), int(y1 + h1)), \
                          (0,255,0), 2, 1) #img_draw
            cv2.rectangle(img_draw, (int(x2), int(y2)), (int(x2 + w2), int(y2 + h2)), \
                          (0,0,255), 2, 1) #img_draw
         #2번째 조건부여
        
         #차량신호등이 초록색인 때 판단 
            shape_list = subtract_shape(img_draw)
            #print('shape_list', shape_list) 
            color_list = subtract_color(img_draw, 'green')
            #print('color_list', color_list)
            tl_flag = False 
            for a1, a2, b1, b2 in color_list:
                for x1, x2, y1, y2 in shape_list:
                    #if사람 객체 roi가 횡단보도 객체roi와 겹친다면 횡단보도 보행자로 인식            
                    if ((a1 >= x1 and a1 <= x2) and (b1 >= y1 and b1 <= y2)) and tl_flag == False and spot_check(bbox1, bbox2)>0: #횡단보도 보행자 검출
                        cv2.putText(img_draw, "STOP!", (100,80), cv2.FONT_HERSHEY_SIMPLEX, 2,(0,0,255),2,cv2.LINE_AA)                      
                        cv2.putText(img_draw, 'Car_Traffic Light Detected!', (100, 120), cv2.FONT_HERSHEY_TRIPLEX, 1,(255, 255, 255))
                        tl_flag = True             
                    else:
                        cv2.putText(img_draw, "", (100,80), cv2.FONT_HERSHEY_SIMPLEX, 2,(0,0,255),2,cv2.LINE_AA)
        else : # 추적 실패
            cv2.putText(img_draw, "Tracking fail.", (100,80), \
                        cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2,cv2.LINE_AA)
    trackerName = tracker1.__class__.__name__
    cv2.putText(img_draw, str(trackerIdx) + ":"+trackerName , (100,20), \
                 cv2.FONT_HERSHEY_SIMPLEX, 0.75, (0,0,255),2,cv2.LINE_AA)

    cv2.imshow(win_name, img_draw)
    key = cv2.waitKey(delay) & 0xff
    # 스페이스 바 또는 비디오 파일 최초 실행 
    if (video_src != 0 and isFirst):#key == ord(' ') or (video_src != 0 and isFirst): 
        isFirst = False
        ##
        hogdef = cv2.HOGDescriptor()
        hogdef.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())
        hogdaim = cv2.HOGDescriptor((48,96), (16,16), (8,8), (8,8), 9)
        hogdaim.setSVMDetector(cv2.HOGDescriptor_getDaimlerPeopleDetector())
        cap = cv2.VideoCapture(video_src)
        while cap.isOpened():
            global ROIs, crop_imgs
            ret, img = cap.read()
            if img is None:
                break
            img2 = img.copy()
            if ret :
                # resize
                img = imutils.resize(img, width = 800)  # resize1#counter to save image with different name
                # default 디텍터로 보행자 검출
                found, _ = hogdef.detectMultiScale(img)
                for (x, y, w, h) in found:
                    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 255), 2)
                cv2.putText(img, 'Detector:%s'%('Default'), (10, 50), cv2.FONT_HERSHEY_DUPLEX,1, (0, 255, 0),1)
                cv2.imshow(win_name, img)
                # daimler 디텍터로 보행자 검출
                key = cv2.waitKey(1)
                if key == 27:
                    break
                if key == 32: # 스페이스
                    ROIs = cv2.selectROIs(win_name,img)
                    crop_imgs= [] 
                    for rect in ROIs:
                        x1=rect[0]
                        y1=rect[1]
                        x2=rect[2]
                        y2=rect[3]
                        crop_imgs.append((x1,y1,x2,y2))
                    cv2.waitKey()
            else:
                break
        if len(crop_imgs) != 0:         # 위치 설정 값 있는 경우
            tracker1 = trackers[trackerIdx]()    #트랙커 객체 생성 
            isInit1 = tracker1.init(frame, crop_imgs[0]) #roi1
            tracker2 = trackers[trackerIdx]()    #트랙커 객체 생성
            isInit2 = tracker2.init(frame, crop_imgs[1]) #roi2
    elif key in range(48, 56): # 0~7 숫자 입력  #근데 안될 수 있는게 있을 수도 있음
        trackerIdx = key-48     # 선택한 숫자로 트랙커 인덱스 수정
        if bbox1 is not None and bbox2 is not None:
            tracker1 = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성 
            isInit1 = tracker1.init(frame, bbox1) # 이전 추적 위치로 추적 위치 초기화
            tracker2 = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성 
            isInit2 = tracker2.init(frame, bbox2) # 이전 추적 위치로 추적 위치 초기화
    elif key == 27 : 
        break
else:
    print( "Could not open video")
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22540/2954736854.py in <module>
#     303
#     304          #차량신호등이 초록색인 때 판단
# --> 305             shape_list = subtract_shape(img_draw)
#     306             #print('shape_list', shape_list)
#     307             color_list = subtract_color(img_draw, 'green')
#
# ~\AppData\Local\Temp/ipykernel_22540/2954736854.py in subtract_shape(img)
#     101         cv2.putText(img_gray, '!', (cx, cy), cv2.FONT_HERSHEY_TRIPLEX, 1,(255, 255, 255))
#     102         size = int(s_keypoint.size)
# --> 103         shape_list.append([cx, cx2, cy, cy2])
#     104     cv2.imshow('gray_gray', img_gray)
#     105     return shape_list
#
# NameError: name 'cx2' is not defined

# %%
#세가지 기능을 합친 코드
#차량 신호등이 초록색일 때 횡단보도 보행자 검출
#현재 코드는 1번 기준

import cv2
import numpy as np
import imutils  # resize1
import cv2
import numpy as np

#신호등
def set_blob_param(r_type: str):
    # BLOB 필터 생성하기 
    params = cv2.SimpleBlobDetector_Params()
    
    params.minThreshold = 10
    params.maxThreshold = 240
    params.thresholdStep = 3
    params.filterByArea = False
    params.filterByColor = False
    params.filterByCircularity = True
    params.filterByConvexity = False 
    params.filterByInertia = False 
    
    if r_type == 'color':
        # 경계 값 조정
        params.minCircularity = 0.8
        params.maxCircularity = 1     
    elif r_type == 'shape':
        params.filterByArea = True 
        params.minArea = 100
        params.maxArea = 250
        
        params.filterByColor = False
#         params.blobColor = 0
        
        params.minCircularity = 0.4
        params.maxCircularity = 0.8
    
    return params 

# 신호등으로 추정되는 영역 검출 
def subtract_shape(img):
    global k, h, w   # 모폴로지 연산 필터 
    
    img_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#    roi_s = img_gray[int((1/5)*w):int((4/5) * w), int((1/5)*h): int((4/5)*h)]
    roi_s = img_gray[int((1/5)*w):int((4/5) * w), int((1/5)*h): int((4/5)*h)]

    ret, th = cv2.threshold(roi_s, 55, 255, cv2.THRESH_BINARY)
    cv2.imshow('th',th)
    dst_s = cv2.morphologyEx(th, cv2.MORPH_OPEN, k)   # 모폴로지 열기 연산 
    #필터 확인
    edge_s = cv2.Laplacian(dst_s, -2)
    detector = cv2.SimpleBlobDetector_create(param_s)
    
    s_keypoints = detector.detect(edge_s)
    img_draw_s = cv2.drawKeypoints(roi_s, s_keypoints, None, None, cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS) 
            
    global shape_list 
    
    for s_keypoint in s_keypoints:
        roi_cx, roi_cy = map(int, s_keypoint.pt)
        cx, cy = int(roi_cx + h * (1/5)), int(roi_cy + w * (1/5))
#        cx, cy = int(roi_cx + h * (1/13)), int(roi_cy + w * (1/13))
        
        cv2.putText(img_gray, '!', (cx, cy), cv2.FONT_HERSHEY_TRIPLEX, 1,(255, 255, 255))
        size = int(s_keypoint.size)
        cx2, cy2 = cx + size // 2, cy + size // 2    
        shape_list.append([cx, cx2, cy, cy2])
    cv2.imshow('img_gray',img_gray)
    return shape_list  

###########
# 신호등 색상에 해당되는 영역 검출 
def subtract_color(img, color):
    global k, w, h   # 모폴로지 연산 필터 
    
    lower_green = np.array([50, 50, 80]); upper_green = np.array([90, 255, 255])
    lower_red = np.array([-10, 50, 50]);  upper_red = np.array([10, 255, 255])
    lower_yellow = np.array([11, 50, 50]); upper_yellow = np.array([30, 255, 255])
    
    img_hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    roi_c = img_hsv[int((1/5)*w):int((4/5) * w), int((1/5)*h): int((4/5)*h)]
    #roi_c = img_hsv[int((1/13)*w):int((2/5) * w), int((1/13)*h): int((2/5)*h)]
        
    if color == 'red_yellow':
        mask1 = cv2.inRange(roi_c, lower_red, upper_red)
        mask2 = cv2.inRange(roi_c, lower_yellow, upper_yellow)
        
        mask = cv2.bitwise_or(mask1, mask2)   # 색상 부분 추출 
    elif color == 'green':
        mask = cv2.inRange(roi_c, lower_green, upper_green)   
        
    img_mask = cv2.bitwise_and(roi_c, roi_c, mask=mask)
    edge_c = cv2.Laplacian(img_mask, -1)
    dst_c = cv2.morphologyEx(edge_c, cv2.MORPH_OPEN, k)   # 모폴로지 닫기 연산 

    detector = cv2.SimpleBlobDetector_create(param_c)
    c_keypoints = detector.detect(edge_c)
    img_draw_c = cv2.drawKeypoints(roi_c, c_keypoints, None, None, cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
    
    global color_list 
    
    for c_keypoint in c_keypoints:
        roi_cx, roi_cy = map(int, c_keypoint.pt)
        cx, cy = int(roi_cx + h * (1/5)), int(roi_cy + w * (1/5))
        #cx, cy = int(roi_cx + h * (2/5)), int(roi_cy + w * (2/5))
        
        cv2.putText(img_hsv, '!', (cx, cy), cv2.FONT_HERSHEY_TRIPLEX, 1,(255, 255, 255))
        size = int(c_keypoint.size)
        cx2, cy2 = cx + size // 2, cy + size // 2 
        color_list.append([cx, cx2, cy, cy2])
    
        cv2.imshow('img_hsv', img_hsv)    
        
    return color_list
                
##########################################################################
##겹치는 사각형 영역의 꼭지점 수 검출 함수
def spot_check(rect1, rect2):
    #좀더 좌측 상단에 있는 시작점을 검출해 이것을 기준으로 함
    #x좌표를 기준으로 검출
    if rect1[0] < rect2[0]:
        standard_rect = rect1
        other_rect= rect2
    else:
        standard_rect = rect2
        other_rect= rect1
    #standard 사각형 기준    
                                                           #list(range(1,3)) >>> [1,2]
    #range(          x좌표,           x좌표+가로길이(너비)+range는 미만으로 수를 잡으므로 +1 
    xrange= range(int(standard_rect[0]),int(standard_rect[0])+int(standard_rect[2])+1) 
    #range(          y좌표,           y좌표+세로길이(높이)+range는 미만으로 수를 잡으므로 +1 
    yrange= range(int(standard_rect[1]),int(standard_rect[1])+int(standard_rect[3])+1)   
    
    #겹치는지 확인하기 위한 비교대상이 되는 사각형(other_rect) 기준
    min_check_x=int(other_rect[0])                #x의 최소값: check_x
    max_check_x=int(other_rect[0]+other_rect[2])  #x의 최대값:check_x+check_w
    min_check_y=int(other_rect[1])                #y의 최소값: check_y   
    max_check_y=int(other_rect[1]+other_rect[3])  #y의 최대값:check_y+check_h 
    
    #검출된 겹치는 꼭지점 개수 초기화
    total_points=0

    #좌측상단 꼭지점 확인
    if min_check_x in xrange and min_check_y in yrange:
        total_points+=1

    #우측상단 꼭지점 확인
    if max_check_x in xrange and min_check_y in yrange:
        total_points+=1

    #좌측하단 꼭지점 확인
    if max_check_y in yrange and min_check_x in xrange:
        total_points+=1

    #우측하단 꼭지점 확인
    if max_check_x in xrange and max_check_y in yrange:
        total_points+=1
    
    return total_points


###############################################################################################################################

##겹치는 사각형 영역의 꼭지점 수 검출 함수
def spot_check(rect1, rect2):
    #좀더 좌측 상단에 있는 시작점을 검출해 이것을 기준으로 함
    #x좌표를 기준으로 검출
    if int(rect1[0]) < int(rect2[0]):
        standard_rect = rect1
        other_rect= rect2
    else:
        standard_rect = rect2
        other_rect= rect1
    #standard 사각형 기준    
                                                           #list(range(1,3)) >>> [1,2]
    #range(          x좌표,           x좌표+가로길이(너비)+range는 미만으로 수를 잡으므로 +1 
    xrange= range(int(standard_rect[0]),int(standard_rect[0])+int(standard_rect[2])+1) 
    #range(          y좌표,           y좌표+세로길이(높이)+range는 미만으로 수를 잡으므로 +1 
    yrange= range(int(standard_rect[1]),int(standard_rect[1])+int(standard_rect[3])+1)   
    
    #겹치는지 확인하기 위한 비교대상이 되는 사각형(other_rect) 기준
    min_check_x=int(other_rect[0])                #x의 최소값: check_x
    max_check_x=int(other_rect[0])+int(other_rect[2])  #x의 최대값:check_x+check_w
    min_check_y=int(other_rect[1])                #y의 최소값: check_y   
    max_check_y=int(other_rect[1])+int(other_rect[3])  #y의 최대값:check_y+check_h 
    
    #검출된 겹치는 꼭지점 개수 초기화
    total_points=0

    #좌측상단 꼭지점 확인
    if min_check_x in xrange and min_check_y in yrange:
        total_points+=1

    #우측상단 꼭지점 확인
    if max_check_x in xrange and min_check_y in yrange:
        total_points+=1

    #좌측하단 꼭지점 확인
    if max_check_y in yrange and min_check_x in xrange:
        total_points+=1

    #우측하단 꼭지점 확인
    if max_check_x in xrange and max_check_y in yrange:
        total_points+=1
    
    return total_points

###############################################################################################################################
##횡단보도와 사람객체 roi 추적 API
#디폴트 에이다 부스트를 이용한 검출 
#영상의 길이가 멀어질 수록 잘 검출이 안됨 
#사각은 정면보다 특히나 검출이 더 안됨
#트랙커 객체 생성자 함수 리스트 
trackers = [cv2.TrackerBoosting_create,
            cv2.TrackerMIL_create,
            cv2.TrackerKCF_create,
            cv2.TrackerTLD_create,
            cv2.TrackerMedianFlow_create,
            cv2.TrackerGOTURN_create, #버그로 오류 발생 안하는게 좋음
            cv2.TrackerCSRT_create,
            cv2.TrackerMOSSE_create]
trackerIdx = 0  # 트랙커 생성자 함수 선택 인덱스
tracker1 = None
tracker2 = None
isFirst = True

video_src = 0 # 비디오 파일과 카메라 선택 
video_src = "./cropped_traffic2.mp4"
cap = cv2.VideoCapture(video_src)
fps = cap.get(cv2.CAP_PROP_FPS) # 프레임 수 구하기
delay = int(1000/fps)
win_name = 'Tracking APIs'
ROIs=0
crop_imgs= [] 

param_c = set_blob_param('color')
param_s = set_blob_param('shape')
k = cv2.getStructuringElement(cv2.MORPH_RECT, (2, 2))   # 모폴로지 연산 필터 
shape_list = []
color_list = [] 
w = 800; h = 800      

while cap.isOpened():
    global fps, delay, k    
    ret, frame = cap.read()
    
    frame = imutils.resize(frame, width = 800)  # resize1
    #frame = cv2.resize(img, (800,800))
    
    if not ret:
        print('Cannot read video file')
        break
    img_draw = frame.copy()
    if tracker1 is None and tracker2 is None: # 트랙커 생성 안된 경우
        cv2.putText(img_draw, "Press the Space to set ROI", \
            (100,80), cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2,cv2.LINE_AA)
    else:
        ok1, bbox1 = tracker1.update(frame)   # 새로운 프레임에서 추적 위치 찾기 
        ok2, bbox2 = tracker2.update(frame)   # 새로운 프레임에서 추적 위치 찾기 
        (x1,y1,w1,h1) = bbox1
        #print('bbox1',bbox1)
        (x2,y2,w2,h2) = bbox2
        #print('bbox2',bbox2)
                
        if ok1 and ok2: # 추적 성공
            cv2.rectangle(img_draw, (int(x1), int(y1)), (int(x1 + w1), int(y1 + h1)), \
                          (255,0, 0), 2, 1) #img_draw
            cv2.rectangle(img_draw, (int(x2), int(y2)), (int(x2 + w2), int(y2 + h2)), \
                          (0,0,255), 2, 1) #img_draw
            #1번째 조건부여   
            #if사람 객체 roi가 횡단보도 객체roi와 겹친다면 횡단보도 보행자로 인식
            if spot_check(bbox1, bbox2)>0: #최소한 꼭지점 하나영역이 겹친다면 
                cv2.putText(img_draw, "STOP!", (100,80), cv2.FONT_HERSHEY_SIMPLEX, 2,(0,0,255),2,cv2.LINE_AA)  
                shape_list = subtract_shape(img_draw)
                #print('shape_list', shape_list) 
                color_list = subtract_color(img_draw, 'green')
                #print('color_list', color_list)
                tl_flag = False 
                for a1, a2, b1, b2 in color_list:
                    for x1, x2, y1, y2 in shape_list:
                        if ((a1 >= x1 and a1 <= x2) and (b1 >= y1 and b1 <= y2)) and tl_flag == False:
                            cv2.putText(img_draw, 'Pedestrian_Traffic Light Detected!', (100, 120), cv2.FONT_HERSHEY_TRIPLEX, 1,(255, 255, 255))
                            tl_flag = True 

            else:
                cv2.putText(img_draw, "", (100,80), cv2.FONT_HERSHEY_SIMPLEX, 2,(0,0,255),2,cv2.LINE_AA)
                
        else : # 추적 실패
            cv2.putText(img_draw, "Tracking fail.", (100,80), \
                        cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2,cv2.LINE_AA)
    trackerName = tracker1.__class__.__name__
    cv2.putText(img_draw, str(trackerIdx) + ":"+trackerName , (100,20), \
                 cv2.FONT_HERSHEY_SIMPLEX, 0.75, (0,0,255),2,cv2.LINE_AA)

    cv2.imshow(win_name, img_draw)
    key = cv2.waitKey(delay) & 0xff
    # 스페이스 바 또는 비디오 파일 최초 실행 
    if (video_src != 0 and isFirst):#key == ord(' ') or (video_src != 0 and isFirst): 
        isFirst = False
        ##
        hogdef = cv2.HOGDescriptor()
        hogdef.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())
        hogdaim = cv2.HOGDescriptor((48,96), (16,16), (8,8), (8,8), 9)
        hogdaim.setSVMDetector(cv2.HOGDescriptor_getDaimlerPeopleDetector())
        cap = cv2.VideoCapture(video_src)
        while cap.isOpened():
            global ROIs, crop_imgs
            ret, img = cap.read()
            if img is None:
                break
            img2 = img.copy()
            if ret :
                # resize
                img = imutils.resize(img, width = 800)  # resize1#counter to save image with different name
                # default 디텍터로 보행자 검출
                found, _ = hogdef.detectMultiScale(img)
                for (x0, y0, w0, h0) in found:
                    cv2.rectangle(img, (x0, y0), (x0 + w0, y0 + h0), (0, 255, 255), 2)
                cv2.putText(img, 'Detector:%s'%('Default'), (10, 50), cv2.FONT_HERSHEY_DUPLEX,1, (0, 255, 0),1)
                cv2.imshow(win_name, img)
                # daimler 디텍터로 보행자 검출
                key = cv2.waitKey(1)
                if key == 27:
                    break
                if key == 32: # 스페이스
                    ROIs = cv2.selectROIs(win_name,img)
                    crop_imgs= [] 
                    for rect in ROIs:
                        x1=rect[0]
                        y1=rect[1]
                        x2=rect[2]
                        y2=rect[3]
                        crop_imgs.append((x1,y1,x2,y2))
                    cv2.waitKey()
            else:
                break
        if len(crop_imgs) != 0:         # 위치 설정 값 있는 경우
            tracker1 = trackers[trackerIdx]()    #트랙커 객체 생성 
            isInit1 = tracker1.init(frame, crop_imgs[0]) #roi1
            tracker2 = trackers[trackerIdx]()    #트랙커 객체 생성
            isInit2 = tracker2.init(frame, crop_imgs[1]) #roi2
    elif key in range(48, 56): # 0~7 숫자 입력  #근데 안될 수 있는게 있을 수도 있음
        trackerIdx = key-48     # 선택한 숫자로 트랙커 인덱스 수정
        if bbox1 is not None and bbox2 is not None:
            tracker1 = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성 
            isInit1 = tracker1.init(frame, bbox1) # 이전 추적 위치로 추적 위치 초기화
            tracker2 = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성 
            isInit2 = tracker2.init(frame, bbox2) # 이전 추적 위치로 추적 위치 초기화
    elif key == 27 : 
        break
else:
    print( "Could not open video")
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_616/3755147580.py in <module>
#     232 cap = cv2.VideoCapture(video_src)
#     233 fps = cap.get(cv2.CAP_PROP_FPS) # 프레임 수 구하기
# --> 234 delay = int(1000/fps)
#     235 win_name = 'Tracking APIs'
#     236 ROIs=0
#
# ZeroDivisionError: float division by zero

# %%
###3차 수정
import cv2
import numpy as np
import imutils  # resize1
import cv2
import numpy as np
#신호등
def set_blob_param(r_type: str):
    # BLOB 필터 생성하기 
    params = cv2.SimpleBlobDetector_Params()
    
    params.minThreshold = 10
    params.maxThreshold = 255
    params.thresholdStep = 10
    params.filterByArea = False
    params.filterByColor = False
    params.filterByCircularity = True
    params.filterByConvexity = False 
    params.filterByInertia = False 
    
    if r_type == 'color':
        # 경계 값 조정
        params.minCircularity = 0.8
        params.maxCircularity = 1     
    elif r_type == 'shape':
        params.filterByArea = True 
        params.minArea = 100
        params.maxArea = 250
        
        params.filterByColor = False
#         params.blobColor = 0
        
        params.minCircularity = 0.4
        params.maxCircularity = 0.8
    
    return params 
# 신호등으로 추정되는 영역 검출 
def subtract_shape(img):
    global k, h, w   # 모폴로지 연산 필터 
    
    img_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # roi_s = img_gray[int((1/5)*w):int((4/5) * w), int((1/5)*h): int((4/5)*h)]
    roi_s = img_gray[int((1/5)*w):int((3/5) * w), int((1/5)*h): int((3/5)*h)]
    blur = cv2.GaussianBlur(roi_s, (3, 3), 0)
​
    # ret, th = cv2.threshold(roi_s, 55, 255, cv2.THRESH_BINARY)
    _, t_otsu = cv2.threshold(blur, -1, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
​
    cv2.imshow('th',t_otsu)
    dst_s = cv2.morphologyEx(t_otsu, cv2.MORPH_OPEN, k)   # 모폴로지 열기 연산 
    #필터 확인
    edge_s = cv2.Laplacian(dst_s, -2)
    detector = cv2.SimpleBlobDetector_create(param_s)
    
    s_keypoints = detector.detect(edge_s)
    img_draw_s = cv2.drawKeypoints(roi_s, s_keypoints, None, None, cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS) 
            
    global shape_list 
    
    for s_keypoint in s_keypoints:
        roi_cx, roi_cy = map(int, s_keypoint.pt)
        cx, cy = int(roi_cx + h * (1/5)), int(roi_cy + w * (1/5))
#        cx, cy = int(roi_cx + h * (1/13)), int(roi_cy + w * (1/13))
        
        cv2.putText(img_gray, '!', (cx, cy), cv2.FONT_HERSHEY_TRIPLEX, 1,(255, 255, 255))
        size = int(s_keypoint.size)
        cx2, cy2 = cx + size // 2, cy + size // 2    
        shape_list.append([cx, cx2, cy, cy2])
    cv2.imshow('img_gray',img_gray)
    return shape_list  
###########
# 신호등 색상에 해당되는 영역 검출 
def subtract_color(img, color):
    global k, w, h   # 모폴로지 연산 필터 
    
    lower_green = np.array([50, 50, 80]); upper_green = np.array([90, 255, 255])
    lower_red = np.array([-10, 30, 30]);  upper_red = np.array([10, 255, 255])
    lower_yellow = np.array([11, 50, 50]); upper_yellow = np.array([30, 255, 255])
    
    img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
​
    roi_c = img_hsv[int((1/5)*w):int((3/5) * w), int((1/5)*h): int((3/5)*h)]
    #roi_c = img_hsv[int((1/13)*w):int((2/5) * w), int((1/13)*h): int((2/5)*h)]
        
    if color == 'red':
        mask = cv2.inRange(roi_c, lower_red, upper_red)
    elif color == 'green':
        mask = cv2.inRange(roi_c, lower_green, upper_green)   
    elif color == 'yellow':
        mask = cv2.inRange(roi_c, lower_yellow, upper_yellow) 
        
    img_mask = cv2.bitwise_and(roi_c, roi_c, mask=mask)
    edge_c = cv2.Laplacian(img_mask, -1)
    # dst_c = cv2.morphologyEx(edge_c, cv2.MORPH_OPEN, k) 적용 x (검출률 저하)
    detector = cv2.SimpleBlobDetector_create(param_c)
    c_keypoints = detector.detect(edge_c)
    img_draw_c = cv2.drawKeypoints(roi_c, c_keypoints, None, None, cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
    # cv2.imshow('img_draw_c', img_draw_c)
​
    global color_list 
    
    for c_keypoint in c_keypoints:
        roi_cx, roi_cy = map(int, c_keypoint.pt)
        cx, cy = int(roi_cx + h * (1/5)), int(roi_cy + w * (1/5))
        #cx, cy = int(roi_cx + h * (2/5)), int(roi_cy + w * (2/5))
        
        cv2.putText(img_hsv, '!', (cx, cy), cv2.FONT_HERSHEY_TRIPLEX, 1,(255, 255, 255))
        size = int(c_keypoint.size)
        cx2, cy2 = cx + size // 2, cy + size // 2 
        color_list.append([cx, cx2, cy, cy2])
    
    cv2.imshow('img_hsv', img_hsv)        
    return color_list
                
##########################################################################
##겹치는 사각형 영역의 꼭지점 수 검출 함수
def spot_check(rect1, rect2):
    #좀더 좌측 상단에 있는 시작점을 검출해 이것을 기준으로 함
    #x좌표를 기준으로 검출
    if rect1[0] < rect2[0]:
        standard_rect = rect1
        other_rect= rect2
    else:
        standard_rect = rect2
        other_rect= rect1
    #standard 사각형 기준    
                                                           #list(range(1,3)) >>> [1,2]
    #range(          x좌표,           x좌표+가로길이(너비)+range는 미만으로 수를 잡으므로 +1 
    xrange= range(int(standard_rect[0]),int(standard_rect[0])+int(standard_rect[2])+1) 
    #range(          y좌표,           y좌표+세로길이(높이)+range는 미만으로 수를 잡으므로 +1 
    yrange= range(int(standard_rect[1]),int(standard_rect[1])+int(standard_rect[3])+1)   
    
    #겹치는지 확인하기 위한 비교대상이 되는 사각형(other_rect) 기준
    min_check_x=int(other_rect[0])                #x의 최소값: check_x
    max_check_x=int(other_rect[0]+other_rect[2])  #x의 최대값:check_x+check_w
    min_check_y=int(other_rect[1])                #y의 최소값: check_y   
    max_check_y=int(other_rect[1]+other_rect[3])  #y의 최대값:check_y+check_h 
    
    #검출된 겹치는 꼭지점 개수 초기화
    total_points=0
    #좌측상단 꼭지점 확인
    if min_check_x in xrange and min_check_y in yrange:
        total_points+=1
    #우측상단 꼭지점 확인
    if max_check_x in xrange and min_check_y in yrange:
        total_points+=1
    #좌측하단 꼭지점 확인
    if max_check_y in yrange and min_check_x in xrange:
        total_points+=1
    #우측하단 꼭지점 확인
    if max_check_x in xrange and max_check_y in yrange:
        total_points+=1
    
    return total_points
###############################################################################################################################
##겹치는 사각형 영역의 꼭지점 수 검출 함수
def spot_check(rect1, rect2):
    #좀더 좌측 상단에 있는 시작점을 검출해 이것을 기준으로 함
    #x좌표를 기준으로 검출
    if int(rect1[0]) < int(rect2[0]):
        standard_rect = rect1
        other_rect= rect2
    else:
        standard_rect = rect2
        other_rect= rect1
    #standard 사각형 기준    
                                                           #list(range(1,3)) >>> [1,2]
    #range(          x좌표,           x좌표+가로길이(너비)+range는 미만으로 수를 잡으므로 +1 
    xrange= range(int(standard_rect[0]),int(standard_rect[0])+int(standard_rect[2])+1) 
    #range(          y좌표,           y좌표+세로길이(높이)+range는 미만으로 수를 잡으므로 +1 
    yrange= range(int(standard_rect[1]),int(standard_rect[1])+int(standard_rect[3])+1)   
    
    #겹치는지 확인하기 위한 비교대상이 되는 사각형(other_rect) 기준
    min_check_x=int(other_rect[0])                #x의 최소값: check_x
    max_check_x=int(other_rect[0])+int(other_rect[2])  #x의 최대값:check_x+check_w
    min_check_y=int(other_rect[1])                #y의 최소값: check_y   
    max_check_y=int(other_rect[1])+int(other_rect[3])  #y의 최대값:check_y+check_h 
    
    #검출된 겹치는 꼭지점 개수 초기화
    total_points=0
    #좌측상단 꼭지점 확인
    if min_check_x in xrange and min_check_y in yrange:
        total_points+=1
    #우측상단 꼭지점 확인
    if max_check_x in xrange and min_check_y in yrange:
        total_points+=1
    #좌측하단 꼭지점 확인
    if max_check_y in yrange and min_check_x in xrange:
        total_points+=1
    #우측하단 꼭지점 확인
    if max_check_x in xrange and max_check_y in yrange:
        total_points+=1
    
    return total_points
###############################################################################################################################
##횡단보도와 사람객체 roi 추적 API
#디폴트 에이다 부스트를 이용한 검출 
#영상의 길이가 멀어질 수록 잘 검출이 안됨 
#사각은 정면보다 특히나 검출이 더 안됨
#트랙커 객체 생성자 함수 리스트 
trackers = [cv2.TrackerBoosting_create,
            cv2.TrackerMIL_create,
            cv2.TrackerKCF_create,
            cv2.TrackerTLD_create,
            cv2.TrackerMedianFlow_create,
            cv2.TrackerGOTURN_create, #버그로 오류 발생 안하는게 좋음
            cv2.TrackerCSRT_create,
            cv2.TrackerMOSSE_create]
trackerIdx = 0  # 트랙커 생성자 함수 선택 인덱스
tracker1 = None
tracker2 = None
isFirst = True
video_src = 0 # 비디오 파일과 카메라 선택 
video_src = "./cropped_traffic2.mp4"
cap = cv2.VideoCapture(video_src)
fps = cap.get(cv2.CAP_PROP_FPS) # 프레임 수 구하기
delay = int(1000/fps)
win_name = 'Tracking APIs'
ROIs=0
crop_imgs= [] 
param_c = set_blob_param('color')
param_s = set_blob_param('shape')
k = cv2.getStructuringElement(cv2.MORPH_RECT, (2, 2))   # 모폴로지 연산 필터 
shape_list = []
color_list = [] 
w = 800; h = 800      
color_flag = 'green'
​
while cap.isOpened():
    global fps, delay, k    
    ret, frame = cap.read()
    
    frame = imutils.resize(frame, width = 800)  # resize1
    #frame = cv2.resize(img, (800,800))
    
    if not ret:
        print('Cannot read video file')
        break
    img_draw = frame.copy()
    if tracker1 is None and tracker2 is None: # 트랙커 생성 안된 경우
        cv2.putText(img_draw, "Press the Space to set ROI", \
            (100,80), cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2,cv2.LINE_AA)
    else:
        ok1, bbox1 = tracker1.update(frame)   # 새로운 프레임에서 추적 위치 찾기 
        ok2, bbox2 = tracker2.update(frame)   # 새로운 프레임에서 추적 위치 찾기 
        (x1,y1,w1,h1) = bbox1
        #print('bbox1',bbox1)
        (x2,y2,w2,h2) = bbox2
        #print('bbox2',bbox2)
                
        if ok1 and ok2: # 추적 성공
            cv2.rectangle(img_draw, (int(x1), int(y1)), (int(x1 + w1), int(y1 + h1)), \
                          (255,0, 0), 2, 1) #img_draw
            cv2.rectangle(img_draw, (int(x2), int(y2)), (int(x2 + w2), int(y2 + h2)), \
                          (0,0,255), 2, 1) #img_draw
            #1번째 조건부여   
            #if사람 객체 roi가 횡단보도 객체roi와 겹친다면 횡단보도 보행자로 인식
            if spot_check(bbox1, bbox2)>0: #최소한 꼭지점 하나영역이 겹친다면 
                cv2.putText(img_draw, "STOP!", (100,80), cv2.FONT_HERSHEY_SIMPLEX, 2,(0,0,255),2,cv2.LINE_AA)  
                shape_list = subtract_shape(img_draw)
                #print('shape_list', shape_list) 
                color_list = subtract_color(img_draw, color_flag)
                #print('color_list', color_list)
                tl_flag = False 
                for a1, a2, b1, b2 in color_list:
                    for x1, x2, y1, y2 in shape_list:
                        if ((a1 >= x1 and a1 <= x2) and (b1 >= y1 and b1 <= y2)) and tl_flag == False:
                            cv2.putText(img_draw, f'{color_flag} Light Detected!', (100, 120), cv2.FONT_HERSHEY_TRIPLEX, 1,(255, 255, 255))
                            tl_flag = True 
            else:
                cv2.putText(img_draw, "", (100,80), cv2.FONT_HERSHEY_SIMPLEX, 2,(0,0,255),2,cv2.LINE_AA)
                
        else : # 추적 실패
            cv2.putText(img_draw, "Tracking fail.", (100,80), \
                        cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2,cv2.LINE_AA)
    trackerName = tracker1.__class__.__name__
    cv2.putText(img_draw, str(trackerIdx) + ":"+trackerName , (100,20), \
                 cv2.FONT_HERSHEY_SIMPLEX, 0.75, (0,0,255),2,cv2.LINE_AA)
    cv2.imshow(win_name, img_draw)
    key = cv2.waitKey(delay) & 0xff
    # 스페이스 바 또는 비디오 파일 최초 실행 
    if (video_src != 0 and isFirst):#key == ord(' ') or (video_src != 0 and isFirst): 
        isFirst = False
        ##
        hogdef = cv2.HOGDescriptor()
        hogdef.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())
        hogdaim = cv2.HOGDescriptor((48,96), (16,16), (8,8), (8,8), 9)
        hogdaim.setSVMDetector(cv2.HOGDescriptor_getDaimlerPeopleDetector())
        cap = cv2.VideoCapture(video_src)
        while cap.isOpened():
            global ROIs, crop_imgs
            ret, img = cap.read()
            if img is None:
                break
            img2 = img.copy()
            if ret :
                # resize
                img = imutils.resize(img, width = 800)  # resize1#counter to save image with different name
                # default 디텍터로 보행자 검출
                found, _ = hogdef.detectMultiScale(img)
                for (x0, y0, w0, h0) in found:
                    cv2.rectangle(img, (x0, y0), (x0 + w0, y0 + h0), (0, 255, 255), 2)
                cv2.putText(img, 'Detector:%s'%('Default'), (10, 50), cv2.FONT_HERSHEY_DUPLEX,1, (0, 255, 0),1)
                cv2.imshow(win_name, img)
                # daimler 디텍터로 보행자 검출
                key = cv2.waitKey(1)
                if key == 27:
                    break
                if key == 32: # 스페이스
                    ROIs = cv2.selectROIs(win_name,img)
                    crop_imgs= [] 
                    for rect in ROIs:
                        x1=rect[0]
                        y1=rect[1]
                        x2=rect[2]
                        y2=rect[3]
                        crop_imgs.append((x1,y1,x2,y2))
                    cv2.waitKey()
            else:
                break
        if len(crop_imgs) != 0:         # 위치 설정 값 있는 경우
            tracker1 = trackers[trackerIdx]()    #트랙커 객체 생성 
            isInit1 = tracker1.init(frame, crop_imgs[0]) #roi1
            tracker2 = trackers[trackerIdx]()    #트랙커 객체 생성
            isInit2 = tracker2.init(frame, crop_imgs[1]) #roi2
    elif key in range(48, 56): # 0~7 숫자 입력  #근데 안될 수 있는게 있을 수도 있음
        trackerIdx = key-48     # 선택한 숫자로 트랙커 인덱스 수정
        if bbox1 is not None and bbox2 is not None:
            tracker1 = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성 
            isInit1 = tracker1.init(frame, bbox1) # 이전 추적 위치로 추적 위치 초기화
            tracker2 = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성 
            isInit2 = tracker2.init(frame, bbox2) # 이전 추적 위치로 추적 위치 초기화
    elif key == 27 : 
        break
else:
    print( "Could not open video")
cap.release()
cv2.destroyAllWindows()
# Out:
#   File "C:\Users\admin\AppData\Local\Temp/ipykernel_22540/2747400882.py", line 45
#     ​
#     ^
# SyntaxError: invalid non-printable character U+200B

# %%
#
#사각형 겹침 상태 확인
img_test = cv2.imread('./img/blank_500.jpg') 
#배율 지정으로 도화지 늘리기
img_test = cv2.resize(img_test, None, None, 3, 2, cv2.INTER_CUBIC)

rect1 =(212, 200, 480, 363)
rect2 =(527, 145, 60, 90)

#연두색 큰 사각형
cv2.rectangle(img_test, (rect1[0], rect1[1]), (rect1[0]+rect1[2], rect1[1]+rect1[3]),(0,255,0), 2, 1) 
#빨간 작은 사각형 
cv2.rectangle(img_test, (rect2[0], rect2[1]), (rect2[0]+rect2[2], rect2[1]+rect2[3]),(0,0,255), 2, 1) 

cv2.imshow('img_blank', img_test)
cv2.waitKey()
cv2.destroyAllWindows()

########################################################################################################################
#꼭지점 수 구하기 (spot_check 함수사용)
rect1 =(212, 200, 480, 363)
rect2 =(527, 145, 60, 90)

print(rect1, rect2)
spot_check(rect1, rect2)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
#겹치는 사각형 예외처리하기
#꼭지점으로 검출이 안되는 경우라면 
"""
(662,30)부터(662,336)구간에 (550,95)부터(1077,95)까지 값 중 하나가 겹치는 것이 있다면
여기서 한쪽의 y값은 고정되어 있음
#어느 줄을 기준으로 하느냐에 따라 x값이 고정될 수 있음 다만 여기선 y값을 고정하는 기준을 사용
따라서 (?,95)좌표가 존재하는지 확인하면 됨
따라서 x좌표만 구간내 존재여부를 확인하면 됨

 ㅡ  
 ㅡ   이렇게 검출하던지  | | 이렇게 검줄
   
인덱싱 구간을 줄이기 위해
rect1의 높이와 rect2의 너비 중에서 더 짧은 쪽을 구분

#여기때문에 맨처음은 반드시 횡단보도를 설정해야함 이후에 사람들 설정!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

#(보류)높이보다 너비가 넓은 직사각형을 rect1로 간주(가로방향으로 누워져있는 직사각형)
#(보류)너비보다 높이가 넓은 직사각형을 rect2로 간주
       (  x,  y,   w,  h)
rect1 =(550, 95, 527, 85) #횡단보도
rect2 =(662, 30, 69, 306)

(보류)def check_rect():
    if rect1[2]=>rect[3]:
        lay_down_rect=rect1
    else:
        stand_rect=rect2

#값이 있는지 검색범위를 지정하기 위해 
#rect1(횡단보도)의 너비와 rect2의 높이 비교

#x좌표 기준 index
def check_rect(rect1, rect2):
    if rect1[2]>rect2[3]
        rect_index_range=range(int(rect2[1]), int(rect2[1])+(rect2[3]))
    elif rect2[2]>rect1[3]
        rect_index_range=range(int(rect1[0]), int(rect1[0])+(rect1[2]))
    return rect_index_range


#상단의 빨간 박스예시 기준
 위의 코드에서는 rect2의 높이가 더 짧게 나왔으므로 rect2의 높이가 검색범위가 됨.
 
#존재하는지 찾고자 하는 좌표는
rect1의 (x,y)인데

실제 좌표를 봤을 때 겹치는 부분이 있다면
rect1의 좌표와 rect2의 좌표만으로 고정된 좌표가 존재
4개의 고정된 좌표가 나오므로
해당 좌표중 하나만 이라도 두 도형에서 검출된다면 이는 겹친부분이 있다는 의미
"""

#####################################################################
#사각형 겹침 상태 확인
img_test = cv2.imread('./img/blank_500.jpg') 
#배율 지정으로 도화지 늘리기
img_test = cv2.resize(img_test, None, None, 3, 2, cv2.INTER_CUBIC)

rect1=(550,95,527,85)
rect2=(662,30,69,306)

#연두색 큰 사각형
cv2.rectangle(img_test, (rect1[0], rect1[1]), (rect1[0]+rect1[2], rect1[1]+rect1[3]),(0,255,0), 2, 1) 
#빨간 작은 사각형 
cv2.rectangle(img_test, (rect2[0], rect2[1]), (rect2[0]+rect2[2], rect2[1]+rect2[3]),(0,0,255), 2, 1) 

cv2.imshow('img_blank', img_test)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
#생략없이 출력
import numpy as np
np.set_printoptions(threshold=np.inf, linewidth=np.inf)

# %%
test_rect=cv2.rectangle(img_test, (rect1[0], rect1[1]), (rect1[0]+rect1[2], rect1[1]+rect1[3]),(0,255,0), 2, 1) 
print(test_rect.shape)
# Out:
# (1000, 1500, 3)

# %%
#십자가모양 겹치는 샘플로 기준잡고 해봄

##횡단보도 ROI와 사람의 ROI가 겹치면 횡단보도 근처에서 걷고 있는것으로 인식

#횡단보도는 세로보다 가로가 더 길음
rect1 =(550, 95, 527, 85) #횡단보도 #가로가 더 길은 직사각형
#걷는 사람은 반드시 가로보다 세로가 더 길음
rect2 =(662, 30, 69, 306)

def spot_check(rect1, rect2):
    rect1=rect1
    rect2=rect2    
    #가로와 세로길이를 비교해 가로가 더 길으면 횡단보도(기준 직사각형)
    #너비>높이
    if rect1[2] > rect1[3]:
        standard_rect = rect1
        other_rect= rect2
    #가로보다 세로가 더 길다면 사람 ROI
    #높이>너비
    else:
        standard_rect = rect2
        other_rect= rect1
        
    #standard 사각형 기준    
    #겹친다고 예상되는 고정좌표 뽑기
    #      (          662,              95)   
    point1=(other_rect[0],standard_rect[1]) #좌측상단
    #      (                731= 662+69,               95) 
    point2=(other_rect[0]+other_rect[2], standard_rect[1]) #우측상단
    #      (          662,                        180=95+85)
    point3=(other_rect[0],standard_rect[1]+standard_rect[3]) #좌측하단 
    #      (                 731=662+69,                   180=95+85)
    point4=(other_rect[0]+other_rect[2], standard_rect[1]+standard_rect[3]) #우측하단

    #point1과 point3의 y축으로 겹칠것이라고 예상하는 범위를 특정할 수 있음
    #point2와 point4의 y축으로 겹칠것이라고 예상하는 범위를 특정할 수 있음
    
    #제한된 예상범위의 point1로부터 point2 사이의 x축 구간
    x_top_range=range(other_rect[0],standard_rect[0]) #y축은 standard_rect[1] #95로 동일
    #제한된 예상범위의 point3으로부터 point4 사이의 x축 구간
    x_bottom_range=range(other_rect[0], other_rect[0]+other_rect[2]) #y축은 standard_rect[1]+standard_rect[3] #180으로 동일
    
    #사람ROI가 겹친다고 예상된다고 생각되는 roi에 존재하는지 탐색
    #즉 예상 범위가 사람 ROI 범위에 포함되는지 확인
    
    #고정좌표이프로 겹친다고 생각되는 범위 point1과 point3의 x축은 사람 roi와 동일하게 되어 있음.
    #point2와 point4의 x축 또한 위와 동일.
    #따라서 y축의 범위만 검토하면 됨
    #기준이 되는 사람 ROI에 횡단보도 roi가 일부 겹치는지 확인하기 위해 
    
    expected_min_point=standard_rect[1] #겹칠거라고 생각되는 point1의 y좌표 #95
    expected_max_point=standard_rect[1]+standard_rect[3]  #겹칠거라고 생각되는 point3의 y좌표 #  

    #실제 사람 roi_y 범위
    y_other_rect_range=range(other_rect[1],other_rect[1]+other_rect[3])

    if expected_min_point in y_other_rect_range:
        #겹침
        return 1
    elif expected_max_point in y_other_rect_range:
        #겹침
        return 1

# %%
#십자가모양 겹치는 샘플로 기준잡고 해봄

##횡단보도 ROI와 사람의 ROI가 겹치면 횡단보도 근처에서 걷고 있는것으로 인식

#횡단보도는 세로보다 가로가 더 길음
rect1 =(550, 95, 527, 85) #횡단보도 #가로가 더 길은 직사각형
#걷는 사람은 반드시 가로보다 세로가 더 길음
rect2 =(662, 30, 69, 306)

def spot_check(rect1, rect2):
    #가로와 세로길이를 비교해 가로가 더 길으면 횡단보도(기준 직사각형)
    #너비>높이
    if rect1[2] > rect1[3]:
        standard_rect = rect1
        other_rect= rect2
    #가로보다 세로가 더 길다면 사람 ROI
    #높이>너비
    else:
        standard_rect = rect2
        other_rect= rect1
    
    print('standard_rect ', standard_rect)
    print('other_rect ',other_rect)    
    
    #standard 사각형 기준    
    #겹친다고 예상되는 고정좌표 뽑기
    point1=(other_rect[0],standard_rect[1]) #좌측상단
    point2=(other_rect[0]+other_rect[2], standard_rect[1]) #우측상단
    point3=(other_rect[0],standard_rect[1]+standard_rect[3]) #좌측하단 
    point4=(other_rect[0]+other_rect[2], standard_rect[1]+standard_rect[3]) #우측하단
    print('points ',point1, point2, point3, point4)
    
    #제한된 예상범위의 point1로부터 point2 사이의 x축 구간
    x_top_range=range(other_rect[0],other_rect[0]+other_rect[2]) #y축은 standard_rect[1] #95로 동일
    print(x_top_range)
    
    #제한된 예상범위의 point3으로부터 point4 사이의 x축 구간
    x_bottom_range=range(other_rect[0], other_rect[0]+other_rect[2]) #y축은 standard_rect[1]+standard_rect[3] #180으로 동일
    print(x_bottom_range)
    
    
    expected_ymin_point=standard_rect[1] #겹칠거라고 생각되는 point1의 y좌표 #95
    expected_ymax_point=standard_rect[1]+standard_rect[3]  #겹칠거라고 생각되는 point3의 y좌표 #  

    expected_xmin_point=other_rect[0] #겹칠거라고 생각되는 point1의 y좌표 #95
    expected_xmax_point=other_rect[0]+other_rect[2]  #겹칠거라고 생각되는 point3의 y좌표 #  
    
    #실제 사람 standard_rectard_standard_rectard_rectard_rectard_rectard_rectard_rectard_rectard_recty 범위
    y_other_rect_range=range(other_rect[1],other_rect[1]+other_rect[3])
    #실제 횡단보도_x 범위
    x_standard_rectstandard_rectard_rectard_recstandard_rectrectard_rectard_recte=range(standard_rect[0], standard_rect[0]+standard_rect[2])

    if expected_ymin_point in y_other_rect_range or expected_ymax_point in y_other_rect_range:
        #가로 기준으로도 부합하는지 확인
        if expected_xmin_point in y_other_rect_range or expected_xmax_point in y_other_rect_range:   
            answer=1
            return answer
    
    

result=spot_check(rect1, rect2)    
print(result)
# Out:
# standard_rect  (550, 95, 527, 85)
# other_rect  (662, 30, 69, 306)
# points  (662, 95) (731, 95) (662, 180) (731, 180)
# range(662, 731)
# range(662, 731)
# None

# %%
#십자가모양 겹치는 샘플로 기준잡고 해봄

##횡단보도 ROI와 사람의 ROI가 겹치면 횡단보도 근처에서 걷고 있는것으로 인식

#횡단보도는 세로보다 가로가 더 길음
rect1 =(550, 95, 527, 85) #횡단보도 #가로가 더 길은 직사각형
#걷는 사람은 반드시 가로보다 세로가 더 길음
rect2 =(662, 30, 69, 306)

def spot_check(rect1, rect2):
    #가로와 세로길이를 비교해 가로가 더 길으면 횡단보도(기준 직사각형)
    #너비>높이
    if rect1[2] > rect1[3]:
        standard_rect = rect1
        other_rect= rect2
    #가로보다 세로가 더 길다면 사람 ROI
    #높이>너비
    else:
        standard_rect = rect2
        other_rect= rect1
    
    print('standard_rect ', standard_rect)
    print('other_rect ',other_rect)    
    
    #standard 사각형 기준    
    #겹친다고 예상되는 고정좌표 뽑기
    point1=(other_rect[0],standard_rect[1]) #좌측상단
    point2=(other_rect[0]+other_rect[2], standard_rect[1]) #우측상단
    point3=(other_rect[0],standard_rect[1]+standard_rect[3]) #좌측하단 
    point4=(other_rect[0]+other_rect[2], standard_rect[1]+standard_rect[3]) #우측하단
    print('points ',point1, point2, point3, point4)
    
    #중점은 겹칠것이라고 고정된 좌표중 최소한 하나라도 두 사각형 모두에 포함된다면 
    #겹친다고 판단해도 된다는 것임
    
    #횡단보도 roi 기준 겹치는 영역 꼭지점 존재 확인

    total_point=0
    
    #좌측 상단
    if int(point1[1]) in range(int(rect2[1]), int(rect2[1])+int(rect2[3])+1) and int(point1[0]) in range(int(rect1[0]),int(rect1[0])+int(rect1[2])):
        total_point+=1
        #print('1st:',total_point)
    #우측상단
    if int(point2[1]) in range(int(rect2[1]), int(rect2[1])+int(rect2[3])+1) and int(point2[0]) in range(int(rect1[0]),int(rect1[0])+int(rect1[2])):
        total_point+=1
        #print(int(point2[1]), 'in range(',int(rect2[1]), int(rect2[1])+int(rect2[3])+1,')', 'and', int(point2[0]), 'in range(', int(rect1[0]),int(rect1[0])+int(rect1[2]),')',)
        #print('2nd:',total_point)
    #좌측하단
    if int(point3[1]) in range(int(rect2[1]), int(rect2[1])+int(rect2[3])+1) and int(point3[0]) in range(int(rect1[0]),int(rect1[0])+int(rect1[2])):
        total_point+=1
        #print('3rd:',total_point)
    #우측상단
    if int(point4[1]) in range(int(rect2[1]), int(rect2[1])+int(rect2[3])+1) and int(point4[0]) in range(int(rect1[0]),int(rect1[0])+int(rect1[2])):
        total_point+=1
        #print('4th:',total_point)
    #print('total_point', total_point)
    return total_point
    #사람 roi 기준 겹치는 영역 꼭지점 존재 확인    

result=spot_check(rect1, rect2)    
print(result)
# Out:
# standard_rect  (550, 95, 527, 85)
# other_rect  (662, 30, 69, 306)
# points  (662, 95) (731, 95) (662, 180) (731, 180)
# 4

# %%
#사각형 겹침 상태 확인2

img_test = cv2.imread('./img/blank_500.jpg') 
#배율 지정으로 도화지 늘리기
img_test = cv2.resize(img_test, None, None, 3, 2, cv2.INTER_CUBIC)

rect1 =(212, 200, 480, 363)
rect2 =(527, 145, 60, 90)

#연두색 큰 사각형
cv2.rectangle(img_test, (rect1[0], rect1[1]), (rect1[0]+rect1[2], rect1[1]+rect1[3]),(0,255,0), 2, 1) 
#빨간 작은 사각형 
cv2.rectangle(img_test, (rect2[0], rect2[1]), (rect2[0]+rect2[2], rect2[1]+rect2[3]),(0,0,255), 2, 1) 

cv2.imshow('img_blank', img_test)
cv2.waitKey()
cv2.destroyAllWindows()

########################################################################################################################
#꼭지점 수 구하기 (spot_check 함수사용)
rect1 =(212, 200, 480, 363)
rect2 =(527, 145, 60, 90)

print(rect1, rect2)
print(spot_check(rect1, rect2))
print(spot_check(rect1, rect2)>0)
spot_check(rect1, rect2)
# Out:
# (212, 200, 480, 363) (527, 145, 60, 90)
# standard_rect  (212, 200, 480, 363)
# other_rect  (527, 145, 60, 90)
# points  (527, 200) (587, 200) (527, 563) (587, 563)
# 2
# standard_rect  (212, 200, 480, 363)
# other_rect  (527, 145, 60, 90)
# points  (527, 200) (587, 200) (527, 563) (587, 563)
# True
# standard_rect  (212, 200, 480, 363)
# other_rect  (527, 145, 60, 90)
# points  (527, 200) (587, 200) (527, 563) (587, 563)
# 2

# %%
#사각형 겹침 상태 확인3
img_test = cv2.imread('./img/blank_500.jpg') 
#배율 지정으로 도화지 늘리기
img_test = cv2.resize(img_test, None, None, 3, 2, cv2.INTER_CUBIC)

rect1 =(380, 120, 610, 150)
rect2 =(750, 500, 240, 290)

#연두색 큰 사각형
cv2.rectangle(img_test, (rect1[0], rect1[1]), (rect1[0]+rect1[2], rect1[1]+rect1[3]),(0,255,0), 2, 1) 
#빨간 작은 사각형 
cv2.rectangle(img_test, (rect2[0], rect2[1]), (rect2[0]+rect2[2], rect2[1]+rect2[3]),(0,0,255), 2, 1) 

cv2.imshow('img_blank', img_test)
cv2.waitKey()
cv2.destroyAllWindows()

########################################################################################################################
#꼭지점 수 구하기 (spot_check 함수사용)
rect1 =(380, 120, 610, 150)
rect2 =(750, 500, 240, 290)

print(rect1, rect2)
spot_check(rect1, rect2)

#성공
# Out:
# (380, 120, 610, 150) (750, 500, 240, 290)
# standard_rect  (380, 120, 610, 150)
# other_rect  (750, 500, 240, 290)
# points  (750, 120) (990, 120) (750, 270) (990, 270)
# 0

# %%
#사각형 겹침 상태 확인4
img_test = cv2.imread('./img/blank_500.jpg') 
#배율 지정으로 도화지 늘리기
img_test = cv2.resize(img_test, None, None, 3, 2, cv2.INTER_CUBIC)

rect1 =(355, 140, 385, 130)
rect2 =(455, 75, 100, 160)

#연두색 큰 사각형
cv2.rectangle(img_test, (rect1[0], rect1[1]), (rect1[0]+rect1[2], rect1[1]+rect1[3]),(0,255,0), 2, 1) 
#빨간 작은 사각형 
cv2.rectangle(img_test, (rect2[0], rect2[1]), (rect2[0]+rect2[2], rect2[1]+rect2[3]),(0,0,255), 2, 1) 

cv2.imshow('img_blank', img_test)
cv2.waitKey()
cv2.destroyAllWindows()

########################################################################################################################
#꼭지점 수 구하기 (spot_check 함수사용)
rect1 =(355, 140, 385, 130)
rect2 =(455, 75, 180, 160)

print(rect1, rect2)
spot_check(rect1, rect2)

#성공
# Out:
# (355, 140, 385, 130) (455, 75, 180, 160)
# standard_rect  (355, 140, 385, 130)
# other_rect  (455, 75, 180, 160)
# points  (455, 140) (635, 140) (455, 270) (635, 270)
# 2

# %%
#반드시 횡단보도가 사람보다 우선적으로 설정되어야 함을 여기서 파악함

#사각형 겹침 상태 확인5
img_test = cv2.imread('./img/blank_500.jpg') 
#배율 지정으로 도화지 늘리기
img_test = cv2.resize(img_test, None, None, 3, 2, cv2.INTER_CUBIC)

rect2 =(219, 78, 45, 102)
rect1 =(225, 310, 169, 38)

#연두색 큰 사각형
cv2.rectangle(img_test, (rect1[0], rect1[1]), (rect1[0]+rect1[2], rect1[1]+rect1[3]),(0,255,0), 2, 1) 
#빨간 작은 사각형 
cv2.rectangle(img_test, (rect2[0], rect2[1]), (rect2[0]+rect2[2], rect2[1]+rect2[3]),(0,0,255), 2, 1) 

cv2.imshow('img_blank', img_test)
cv2.waitKey()
cv2.destroyAllWindows()

########################################################################################################################
#꼭지점 수 구하기 (spot_check 함수사용)
rect2 =(219, 78, 45, 102)
rect1 =(225, 310, 169, 38)

print(rect1, rect2)
spot_check(rect1, rect2)

#성공
# Out:
# (225, 310, 169, 38) (219, 78, 45, 102)
# points  (219, 310) (264, 310) (219, 348) (264, 348)
# 0

# %%
#위에서 제시한 roi 기준을 재동님이 참고해서 추가적으로 수정한 최종코드1
#단 반드시 사람보다 횡단보도를 우선 설정해야 함!!!!!!

import cv2
import numpy as np
import imutils  # resize1
import cv2
import numpy as np
#신호등
def set_blob_param(r_type: str):
    # BLOB 필터 생성하기 
    params = cv2.SimpleBlobDetector_Params()
    
    params.minThreshold = 10
    params.maxThreshold = 255
    params.thresholdStep = 10
    params.filterByArea = False
    params.filterByColor = False
    params.filterByCircularity = True
    params.filterByConvexity = False 
    params.filterByInertia = False 
    
    if r_type == 'color':
        # 경계 값 조정
        params.minCircularity = 0.8
        params.maxCircularity = 1     
    elif r_type == 'shape':
        params.filterByArea = True 
        params.minArea = 100
        params.maxArea = 250
        
        params.filterByColor = False
#         params.blobColor = 0
        
        params.minCircularity = 0.4
        params.maxCircularity = 0.8
    
    return params 
# 신호등으로 추정되는 영역 검출 
def subtract_shape(img):
    global k, h, w   # 모폴로지 연산 필터 
    
    img_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # roi_s = img_gray[int((1/5)*w):int((4/5) * w), int((1/5)*h): int((4/5)*h)]
    roi_s = img_gray[int((1/5)*w):int((3/5) * w), int((1/5)*h): int((3/5)*h)]
    blur = cv2.GaussianBlur(roi_s, (3, 3), 0)

    # ret, th = cv2.threshold(roi_s, 55, 255, cv2.THRESH_BINARY)
    _, t_otsu = cv2.threshold(blur, -1, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)

    cv2.imshow('th',t_otsu)
    dst_s = cv2.morphologyEx(t_otsu, cv2.MORPH_OPEN, k)   # 모폴로지 열기 연산 
    #필터 확인
    edge_s = cv2.Laplacian(dst_s, -2)
    detector = cv2.SimpleBlobDetector_create(param_s)
    
    s_keypoints = detector.detect(edge_s)
    img_draw_s = cv2.drawKeypoints(roi_s, s_keypoints, None, None, cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS) 
            
    global shape_list 
    
    for s_keypoint in s_keypoints:
        roi_cx, roi_cy = map(int, s_keypoint.pt)
        cx, cy = int(roi_cx + h * (1/5)), int(roi_cy + w * (1/5))
#        cx, cy = int(roi_cx + h * (1/13)), int(roi_cy + w * (1/13))
        
        cv2.putText(img_gray, '!', (cx, cy), cv2.FONT_HERSHEY_TRIPLEX, 1,(255, 255, 255))
        size = int(s_keypoint.size)
        cx2, cy2 = cx + size // 2, cy + size // 2    
        shape_list.append([cx, cx2, cy, cy2])
    cv2.imshow('img_gray',img_gray)
    return shape_list  
###########
# 신호등 색상에 해당되는 영역 검출 
def subtract_color(img, color):
    global k, w, h   # 모폴로지 연산 필터 
    
    lower_green = np.array([50, 50, 80]); upper_green = np.array([90, 255, 255])
    lower_red = np.array([-10, 30, 30]);  upper_red = np.array([10, 255, 255])
    lower_yellow = np.array([11, 50, 50]); upper_yellow = np.array([30, 255, 255])
    
    img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

    roi_c = img_hsv[int((1/5)*w):int((3/5) * w), int((1/5)*h): int((3/5)*h)]
    #roi_c = img_hsv[int((1/13)*w):int((2/5) * w), int((1/13)*h): int((2/5)*h)]
        
    if color == 'red':
        mask = cv2.inRange(roi_c, lower_red, upper_red)
    elif color == 'green':
        mask = cv2.inRange(roi_c, lower_green, upper_green)   
    elif color == 'yellow':
        mask = cv2.inRange(roi_c, lower_yellow, upper_yellow) 
        
    img_mask = cv2.bitwise_and(roi_c, roi_c, mask=mask)
    edge_c = cv2.Laplacian(img_mask, -1)
    # dst_c = cv2.morphologyEx(edge_c, cv2.MORPH_OPEN, k) 적용 x (검출률 저하)
    detector = cv2.SimpleBlobDetector_create(param_c)
    c_keypoints = detector.detect(edge_c)
    img_draw_c = cv2.drawKeypoints(roi_c, c_keypoints, None, None, cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
    # cv2.imshow('img_draw_c', img_draw_c)

    global color_list 
    
    for c_keypoint in c_keypoints:
        roi_cx, roi_cy = map(int, c_keypoint.pt)
        cx, cy = int(roi_cx + h * (1/5)), int(roi_cy + w * (1/5))
        #cx, cy = int(roi_cx + h * (2/5)), int(roi_cy + w * (2/5))
        
        cv2.putText(img_hsv, '!', (cx, cy), cv2.FONT_HERSHEY_TRIPLEX, 1,(255, 255, 255))
        size = int(c_keypoint.size)
        cx2, cy2 = cx + size // 2, cy + size // 2 
        color_list.append([cx, cx2, cy, cy2])
    
    cv2.imshow('img_hsv', img_hsv)        
    return color_list
                
##########################################################################
def spot_check(bbox1, bbox2):
    #가로와 세로길이를 비교해 가로가 더 길으면 횡단보도(기준 직사각형)
    #너비>높이
    if bbox1[2] > bbox1[3]:
        standard_rect = bbox1
        other_rect= bbox2
    #가로보다 세로가 더 길다면 사람 ROI
    #높이>너비
    else:
        standard_rect = bbox2
        other_rect= bbox1
    
    #print('standard_rect ', standard_rect)
    #print('other_rect ',other_rect)    
    
    #standard 사각형 기준    
    #겹친다고 예상되는 고정좌표 뽑기
    point1=(other_rect[0],standard_rect[1]) #좌측상단
    point2=(other_rect[0]+other_rect[2], standard_rect[1]) #우측상단
    point3=(other_rect[0],standard_rect[1]+standard_rect[3]) #좌측하단 
    point4=(other_rect[0]+other_rect[2], standard_rect[1]+standard_rect[3]) #우측하단
    print('points ',point1, point2, point3, point4)
    
    #중점은 겹칠것이라고 고정된 좌표중 최소한 하나라도 두 사각형 모두에 포함된다면 
    #겹친다고 판단해도 된다는 것임
    
    #횡단보도 roi 기준 겹치는 영역 꼭지점 존재 확인

    total_point=0
    
    #좌측 상단
    if int(point1[1]) in range(int(bbox2[1]), int(bbox2[1])+int(bbox2[3])+1) and int(point1[0]) in range(int(bbox1[0]),int(bbox1[0])+int(bbox1[2])):
        total_point+=1
        #print('1st:',total_point)
    #우측상단
    if int(point2[1]) in range(int(bbox2[1]), int(bbox2[1])+int(bbox2[3])+1) and int(point2[0]) in range(int(bbox1[0]),int(bbox1[0])+int(bbox1[2])):
        total_point+=1
        #print(int(point2[1]), 'in range(',int(rect2[1]), int(rect2[1])+int(rect2[3])+1,')', 'and', int(point2[0]), 'in range(', int(rect1[0]),int(rect1[0])+int(rect1[2]),')',)
        #print('2nd:',total_point)
    #좌측하단
    if int(point3[1]) in range(int(bbox2[1]), int(bbox2[1])+int(bbox2[3])+1) and int(point3[0]) in range(int(bbox1[0]),int(bbox1[0])+int(bbox1[2])):
        total_point+=1
        #print('3rd:',total_point)
    #우측상단
    if int(point4[1]) in range(int(bbox2[1]), int(bbox2[1])+int(bbox2[3])+1) and int(point4[0]) in range(int(bbox1[0]),int(bbox1[0])+int(bbox1[2])):
        total_point+=1
        #print('4th:',total_point)
    #print('total_point', total_point)
    return total_point   
    
###############################################################################################################################
##횡단보도와 사람객체 roi 추적 API
#디폴트 에이다 부스트를 이용한 검출 
#영상의 길이가 멀어질 수록 잘 검출이 안됨 
#사각은 정면보다 특히나 검출이 더 안됨
#트랙커 객체 생성자 함수 리스트 
trackers = [cv2.TrackerBoosting_create,
            cv2.TrackerMIL_create,
            cv2.TrackerKCF_create,
            cv2.TrackerTLD_create,
            cv2.TrackerMedianFlow_create,
            cv2.TrackerGOTURN_create, #버그로 오류 발생 안하는게 좋음
            cv2.TrackerCSRT_create,
            cv2.TrackerMOSSE_create]
trackerIdx = 0  # 트랙커 생성자 함수 선택 인덱스
tracker1 = None
tracker2 = None
isFirst = True
video_src = 0 # 비디오 파일과 카메라 선택 
video_src = "C:/Users/admin/Downloads/movies/cropped_traffic2.mp4"
cap = cv2.VideoCapture(video_src)
fps = cap.get(cv2.CAP_PROP_FPS) # 프레임 수 구하기
delay = int(1000/fps)
win_name = 'Tracking APIs'
ROIs=0
crop_imgs= [] 
param_c = set_blob_param('color')
param_s = set_blob_param('shape')
k = cv2.getStructuringElement(cv2.MORPH_RECT, (2, 2))   # 모폴로지 연산 필터 
shape_list = []
color_list = [] 
w = 800; h = 800      
color_flag = 'green'

while cap.isOpened():
    global fps, delay, k    
    ret, frame = cap.read()
    
    frame = imutils.resize(frame, width = 800)  # resize1
    #frame = cv2.resize(img, (800,800))
    
    if not ret:
        print('Cannot read video file')
        break
    img_draw = frame.copy()
    if tracker1 is None and tracker2 is None: # 트랙커 생성 안된 경우
        cv2.putText(img_draw, "Press the Space to set ROI", \
            (100,80), cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2,cv2.LINE_AA)
    else:
        ok1, bbox1 = tracker1.update(frame)   # 새로운 프레임에서 추적 위치 찾기 
        ok2, bbox2 = tracker2.update(frame)   # 새로운 프레임에서 추적 위치 찾기 
        (x1,y1,w1,h1) = bbox1
        #print('bbox1',bbox1)
        (x2,y2,w2,h2) = bbox2
        #print('bbox2',bbox2)
                
        if ok1 and ok2: # 추적 성공
            cv2.rectangle(img_draw, (int(x1), int(y1)), (int(x1 + w1), int(y1 + h1)), \
                          (255,0, 0), 2, 1) #img_draw
            cv2.rectangle(img_draw, (int(x2), int(y2)), (int(x2 + w2), int(y2 + h2)), \
                          (0,0,255), 2, 1) #img_draw
            #1번째 조건부여   
            #if사람 객체 roi가 횡단보도 객체roi와 겹친다면 횡단보도 보행자로 인식
            if spot_check(bbox1, bbox2)>0: #최소한 꼭지점 하나영역이 겹친다면 
                print('spot_check(bbox1, bbox2)',bbox1, bbox2, spot_check(bbox1, bbox2))
                cv2.putText(img_draw, "STOP!", (100,80), cv2.FONT_HERSHEY_SIMPLEX, 2,(0,0,255),2,cv2.LINE_AA)  
                shape_list = subtract_shape(img_draw)
                #print('shape_list', shape_list) 
                color_list = subtract_color(img_draw, color_flag)
                #print('color_list', color_list)
                tl_flag = False 
                for a1, a2, b1, b2 in color_list:
                    for x1, x2, y1, y2 in shape_list:
                        if ((a1 >= x1 and a1 <= x2) and (b1 >= y1 and b1 <= y2)) and tl_flag == False:
                            cv2.putText(img_draw, f'{color_flag} Light Detected!', (100, 120), cv2.FONT_HERSHEY_TRIPLEX, 1,(255, 255, 255))
                            tl_flag = True 
            else:
                cv2.putText(img_draw, "", (100,80), cv2.FONT_HERSHEY_SIMPLEX, 2,(0,0,255),2,cv2.LINE_AA)
                
        else : # 추적 실패
            cv2.putText(img_draw, "Tracking fail.", (100,80), \
                        cv2.FONT_HERSHEY_SIMPLEX, 0.75,(0,0,255),2,cv2.LINE_AA)
    trackerName = tracker1.__class__.__name__
    cv2.putText(img_draw, str(trackerIdx) + ":"+trackerName , (100,20), \
                 cv2.FONT_HERSHEY_SIMPLEX, 0.75, (0,0,255),2,cv2.LINE_AA)
    cv2.imshow(win_name, img_draw)
    key = cv2.waitKey(delay) & 0xff
    # 스페이스 바 또는 비디오 파일 최초 실행 
    if (video_src != 0 and isFirst):#key == ord(' ') or (video_src != 0 and isFirst): 
        isFirst = False
        ##
        hogdef = cv2.HOGDescriptor()
        hogdef.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())
        hogdaim = cv2.HOGDescriptor((48,96), (16,16), (8,8), (8,8), 9)
        hogdaim.setSVMDetector(cv2.HOGDescriptor_getDaimlerPeopleDetector())
        cap = cv2.VideoCapture(video_src)
        while cap.isOpened():
            global ROIs, crop_imgs
            ret, img = cap.read()
            if img is None:
                break
            img2 = img.copy()
            if ret :
                # resize
                img = imutils.resize(img, width = 800)  # resize1#counter to save image with different name
                # default 디텍터로 보행자 검출
                found, _ = hogdef.detectMultiScale(img)
                for (x0, y0, w0, h0) in found:
                    cv2.rectangle(img, (x0, y0), (x0 + w0, y0 + h0), (0, 255, 255), 2)
                cv2.putText(img, 'Detector:%s'%('Default'), (10, 50), cv2.FONT_HERSHEY_DUPLEX,1, (0, 255, 0),1)
                cv2.imshow(win_name, img)
                # daimler 디텍터로 보행자 검출
                key = cv2.waitKey(1)
                if key == 27:
                    break
                if key == 32: # 스페이스
                    ROIs = cv2.selectROIs(win_name,img)
                    crop_imgs= [] 
                    for rect in ROIs:
                        x1=rect[0]
                        y1=rect[1]
                        x2=rect[2]
                        y2=rect[3]
                        crop_imgs.append((x1,y1,x2,y2))
                    cv2.waitKey()
            else:
                break
        if len(crop_imgs) != 0:         # 위치 설정 값 있는 경우
            tracker1 = trackers[trackerIdx]()    #트랙커 객체 생성 
            isInit1 = tracker1.init(frame, crop_imgs[0]) #roi1
            tracker2 = trackers[trackerIdx]()    #트랙커 객체 생성
            isInit2 = tracker2.init(frame, crop_imgs[1]) #roi2
    elif key in range(48, 56): # 0~7 숫자 입력  #근데 안될 수 있는게 있을 수도 있음
        trackerIdx = key-48     # 선택한 숫자로 트랙커 인덱스 수정
        if bbox1 is not None and bbox2 is not None:
            tracker1 = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성 
            isInit1 = tracker1.init(frame, bbox1) # 이전 추적 위치로 추적 위치 초기화
            tracker2 = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성 
            isInit2 = tracker2.init(frame, bbox2) # 이전 추적 위치로 추적 위치 초기화
    elif key == 27 : 
        break
else:
    print( "Could not open video")
cap.release()
cv2.destroyAllWindows()
# Out:
# points  (196.0, 315.0) (210.0, 315.0) (196.0, 352.0) (210.0, 352.0)
# points  (196.0, 315.0) (210.0, 315.0) (196.0, 352.0) (210.0, 352.0)
# spot_check(bbox1, bbox2) (125.0, 315.0, 198.0, 37.0) (196.0, 292.0, 14.0, 60.0) 4
# points  (196.0, 316.0) (210.0, 316.0) (196.0, 353.0) (210.0, 353.0)
# points  (196.0, 316.0) (210.0, 316.0) (196.0, 353.0) (210.0, 353.0)
# spot_check(bbox1, bbox2) (129.0, 316.0, 198.0, 37.0) (196.0, 292.0, 14.0, 60.0) 2
# points  (196.0, 315.0) (210.0, 315.0) (196.0, 352.0) (210.0, 352.0)
# points  (196.0, 315.0) (210.0, 315.0) (196.0, 352.0) (210.0, 352.0)
# spot_check(bbox1, bbox2) (129.0, 315.0, 198.0, 37.0) (196.0, 295.0, 14.0, 60.0) 4
# points  (196.0, 313.0) (210.0, 313.0) (196.0, 350.0) (210.0, 350.0)
# points  (196.0, 313.0) (210.0, 313.0) (196.0, 350.0) (210.0, 350.0)
# spot_check(bbox1, bbox2) (127.0, 313.0, 198.0, 37.0) (196.0, 291.0, 14.0, 60.0) 4
# points  (196.0, 313.0) (210.0, 313.0) (196.0, 350.0) (210.0, 350.0)
# points  (196.0, 313.0) (210.0, 313.0) (196.0, 350.0) (210.0, 350.0)
# spot_check(bbox1, bbox2) (127.0, 313.0, 198.0, 37.0) (196.0, 291.0, 14.0, 60.0) 4
# points  (196.0, 311.0) (210.0, 311.0) (196.0, 348.0) (210.0, 348.0)
# points  (196.0, 311.0) (210.0, 311.0) (196.0, 348.0) (210.0, 348.0)
# spot_check(bbox1, bbox2) (127.0, 311.0, 198.0, 37.0) (196.0, 289.0, 14.0, 60.0) 4
# points  (197.0, 309.0) (211.0, 309.0) (197.0, 346.0) (211.0, 346.0)
# points  (197.0, 309.0) (211.0, 309.0) (197.0, 346.0) (211.0, 346.0)
# spot_check(bbox1, bbox2) (129.0, 309.0, 198.0, 37.0) (197.0, 287.0, 14.0, 60.0) 4
# points  (197.0, 309.0) (211.0, 309.0) (197.0, 346.0) (211.0, 346.0)
# points  (197.0, 309.0) (211.0, 309.0) (197.0, 346.0) (211.0, 346.0)
# spot_check(bbox1, bbox2) (113.0, 309.0, 198.0, 37.0) (197.0, 287.0, 14.0, 60.0) 4
# points  (197.0, 309.0) (211.0, 309.0) (197.0, 346.0) (211.0, 346.0)
# points  (197.0, 309.0) (211.0, 309.0) (197.0, 346.0) (211.0, 346.0)
# spot_check(bbox1, bbox2) (113.0, 309.0, 198.0, 37.0) (197.0, 287.0, 14.0, 60.0) 4
# points  (197.0, 309.0) (211.0, 309.0) (197.0, 346.0) (211.0, 346.0)
# points  (197.0, 309.0) (211.0, 309.0) (197.0, 346.0) (211.0, 346.0)
# spot_check(bbox1, bbox2) (111.0, 309.0, 198.0, 37.0) (197.0, 287.0, 14.0, 60.0) 4
# points  (198.0, 308.0) (212.0, 308.0) (198.0, 345.0) (212.0, 345.0)
# points  (198.0, 308.0) (212.0, 308.0) (198.0, 345.0) (212.0, 345.0)
# spot_check(bbox1, bbox2) (159.0, 308.0, 198.0, 37.0) (198.0, 287.0, 14.0, 60.0) 4
# points  (198.0, 308.0) (212.0, 308.0) (198.0, 345.0) (212.0, 345.0)
# points  (198.0, 308.0) (212.0, 308.0) (198.0, 345.0) (212.0, 345.0)
# spot_check(bbox1, bbox2) (159.0, 308.0, 198.0, 37.0) (198.0, 286.0, 14.0, 60.0) 4
# points  (198.0, 309.0) (212.0, 309.0) (198.0, 346.0) (212.0, 346.0)
# points  (198.0, 309.0) (212.0, 309.0) (198.0, 346.0) (212.0, 346.0)
# spot_check(bbox1, bbox2) (157.0, 309.0, 198.0, 37.0) (198.0, 286.0, 14.0, 60.0) 4
# points  (198.0, 309.0) (212.0, 309.0) (198.0, 346.0) (212.0, 346.0)
# points  (198.0, 309.0) (212.0, 309.0) (198.0, 346.0) (212.0, 346.0)
# spot_check(bbox1, bbox2) (157.0, 309.0, 198.0, 37.0) (198.0, 286.0, 14.0, 60.0) 4
# points  (198.0, 308.0) (212.0, 308.0) (198.0, 345.0) (212.0, 345.0)
# points  (198.0, 308.0) (212.0, 308.0) (198.0, 345.0) (212.0, 345.0)
# spot_check(bbox1, bbox2) (157.0, 308.0, 198.0, 37.0) (198.0, 286.0, 14.0, 60.0) 4
# points  (197.0, 309.0) (211.0, 309.0) (197.0, 346.0) (211.0, 346.0)
# points  (197.0, 309.0) (211.0, 309.0) (197.0, 346.0) (211.0, 346.0)
# spot_check(bbox1, bbox2) (157.0, 309.0, 198.0, 37.0) (197.0, 287.0, 14.0, 60.0) 4
# points  (197.0, 310.0) (211.0, 310.0) (197.0, 347.0) (211.0, 347.0)
# points  (197.0, 310.0) (211.0, 310.0) (197.0, 347.0) (211.0, 347.0)
# spot_check(bbox1, bbox2) (157.0, 310.0, 198.0, 37.0) (197.0, 287.0, 14.0, 60.0) 4
# points  (197.0, 309.0) (211.0, 309.0) (197.0, 346.0) (211.0, 346.0)
# points  (197.0, 309.0) (211.0, 309.0) (197.0, 346.0) (211.0, 346.0)
# spot_check(bbox1, bbox2) (157.0, 309.0, 198.0, 37.0) (197.0, 287.0, 14.0, 60.0) 4
# points  (197.0, 310.0) (211.0, 310.0) (197.0, 347.0) (211.0, 347.0)
# points  (197.0, 310.0) (211.0, 310.0) (197.0, 347.0) (211.0, 347.0)
# spot_check(bbox1, bbox2) (157.0, 310.0, 198.0, 37.0) (197.0, 288.0, 14.0, 60.0) 4
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1620/565326704.py in <module>
#     302         if bbox1 is not None and bbox2 is not None:
#     303             tracker1 = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성
# --> 304             isInit1 = tracker1.init(frame, bbox1) # 이전 추적 위치로 추적 위치 초기화
#     305             tracker2 = trackers[trackerIdx]() # 선택한 숫자의 트랙커 객체 생성
#     306             isInit2 = tracker2.init(frame, bbox2) # 이전 추적 위치로 추적 위치 초기화
#
# error: OpenCV(3.4.11) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-neg5amx3\opencv\modules\imgproc\src\phasecorr.cpp:602: error: (-215:Assertion failed) winSize.width > 1 && winSize.height > 1 in function 'cv::createHanningWindow'

# %%
#tkinter

# %%
#영상 재생은 여기참조
#https://blog.daum.net/geoscience/1502

# 모듈 호출
import tkinter as tk # Tkinter
from PIL import ImageTk, Image # Pillow
import cv2 as cv # OpenCV
import os

# GUI 설계
win = tk.Tk() # 인스턴스 생성

win.title("블랙박스 기준 횡단보도에서의 무단횡단 보행자 검출 영상") # 제목 표시줄 추가
win.geometry("920x640+50+50") # 지오메트리: 너비x높이+x좌표+y좌표
win.resizable(False, False) # x축, y축 크기 조정 비활성화
win.mainloop() #GUI 시작
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26104/276690691.py in <module>
#      14 win.geometry("920x640+50+50") # 지오메트리: 너비x높이+x좌표+y좌표
#      15 win.resizable(False, False) # x축, y축 크기 조정 비활성화
# ---> 16 win.mainloop() #GUI 시작
#
# ~\Anaconda3\envs\SSAC\lib\tkinter\__init__.py in mainloop(self, n)
#    1427     def mainloop(self, n=0):
#    1428         """Call the mainloop of Tk."""
# -> 1429         self.tk.mainloop(n)
#    1430
#    1431     def quit(self):
#
# KeyboardInterrupt:

# %%
win.mainloop() #GUI 시작
window = Tk()
photo=PhotoImage(file='./')
w=Label(window, image=photo).pack(side='right')
message=""" 
비고
횡단보도ROI 지정후 사람 ROI를 지정해주세요.
맨처음 나오는 노란 박스는 사람 객체라고 인식된 부분입니다.

사용방법
~
"""
w.photo=photo
abel=Canvas(Window, text='횡단보도ROI 지정후 사람 ROI를 지정해주세요')
label.pack()
w.pack()
window.mainloop()
